# %% [markdown]
# # 7. Analysis of Participant Characteristics in Exercise Studies
#
# This Jupyter Notebook provides a comprehensive analysis of participant characteristics across various exercise studies. The analysis encompasses both demographic and exercise bout data, as well as metrics of glycemic control derived from continuous glucose monitoring (CGM) data.
#
# ### Structure of the Notebook:
#
# 1. Import Packages and Upload Data
#         The necessary Python packages are imported for data processing, statistical analyses, and visualization.
#         Raw data files are uploaded from specified directories, and an initial dataset df is created, which is further enhanced with the addition of id_key and race data from DEXI and DEXIP studies.
#         Appropriate data directories for different studies are specified.
#
# 2. Data Dictionary
#         The data is described in terms of its structure and content.
#         Data types, missing values, and basic statistics (min, max, quartiles) for numeric columns are calculated.
#         Unique values and categories for categorical columns are identified.
#
# 3. Statistical Analysis of Demographic and Exercise Bout Data
#         Lists of categorical and numeric variables related to exercise bouts and demographics are defined.
#         Summary statistics, including medians and interquartile ranges, are computed for each study as well as for all studies combined.
#
# 4. Metrics of Glycemic Control
#         Glycemic metrics for each study (T1-DEXI, T1-DEXIP, EXT-101, EXT-edu) are calculated using the metrics.all_standard_metrics function.
#         Results from individual studies are combined into a single dataset all_metrics.
#         Summary statistics for these metrics are again computed for each study and for the combined dataset.
#
# 5. Compilation and Presentation of Results
#         The results from the demographic/exercise bout data analysis and the glycemic control metrics analysis are combined.
#         A final table, ci_table, is created, which provides a comparative overview of the results across all studies.
#         This table is then saved to a CSV file for external use.
#
# ### Data Sources:
#
# Demographics Data: demographics_df.csv
# ID Key for DEXIP Study: id_key_dexip.csv
# Race Data for DEXI and DEXIP Studies: dexi_race.csv, dexip_race.csv
# CGM Data for Various Studies: Located in specified directories for each study.
#
# ### Objective:
#
# The goal of this analysis is to provide a clear understanding of the participant characteristics across the different studies, focusing on demographics, exercise bout information, and glycemic control metrics. This consolidated view aids in drawing meaningful insights and comparisons between studies and helps identify patterns or trends related to exercise and glycemia.

# %% [markdown]
# ## 7.0 Import packages and upload data

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta
from functools import reduce
import preprocess_helper
import sys
path = "../../diametrics"
sys.path.append(path)
import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
# Directories
directory_101 = '../../data/tidy_data/extod_101/'
directory_edu = '../../data/tidy_data/extod_edu/'
directory_helm = '../../data/tidy_data/helmsley/'
directory_dexip = '../../data/tidy_data/dexip/'

# %%
# Upload df 
df = pd.read_csv('../../data/tidy_data/demographics_df.csv')

# %%
df.shape
# Out:
# (16490, 414)

# %% [markdown]
# # Upload ID key and merge with df
# id_key = pd.read_csv('../1_preprocessing/id_key_dexip.csv').drop_duplicates()
# df = df.merge(id_key, on='bout_id', how='inner')

# %% [markdown]
# id_key

# %% [markdown]
# ## 7.1. Data dictionary

# %%
# Convert ordinal variables to str
cols_to_convert = ['intensity', 'day_of_week'] #'season', 
for col in cols_to_convert:
    df[col] = df[col].astype(str)

# %%
# Calculate relevant info for data dictionary
numeric_dict = {}
categorical_dict = {}

for column in df.columns:
    missing_values = df[column].isnull().sum()

    if df[column].dtype in ['int64', 'float64']:  # Numeric columns
        numeric_dict[column] = {
            'data_type': str(df[column].dtype),
            'missing_values': missing_values,
            'min': df[column].min(),
            'Q1': df[column].quantile(0.25),
            'Q2': df[column].median(),
            'Q3': df[column].quantile(0.75),
            'max': df[column].max()
        }
    else:  # Categorical columns
        categorical_dict[column] = {
            'data_type': str(df[column].dtype),
            'unique_values': df[column].nunique(),
            'missing_values': missing_values,
            'categories': df[column].unique()#.tolist()
        }

# %%
# Save categorical data
cat_data = pd.DataFrame(categorical_dict).T
cat_data.to_csv('../../results/data_dictionary/categorical_data.csv')

# %%
cat_data
# Out:
#                  data_type unique_values missing_values  \
# ID                  object           835              0
# start_datetime      object         16373              0
# finish_datetime     object         16387              0
# intensity           object             4              0
# type_of_exercise    object           328              0
# day_of_week         object             7              0
# time_of_day         object             3              0
# form_of_exercise    object             3              0
# study               object             4              0
# bout_id             object         16471              0
# y                     bool             2              0
# sex                 object             2              0
# race                object             7            891
# insulin_modality    object             3             11
# stratify            object          1356              0
#
#                                                          categories
# ID                [dexip_100, dexip_101, dexip_102, dexip_103, d...
# start_datetime    [2021-08-10 13:06:00, 2021-08-10 15:32:22, 202...
# finish_datetime   [2021-08-10 13:26:00, 2021-08-10 15:47:22, 202...
# intensity                                      [0.0, 1.0, 2.0, nan]
# type_of_exercise  [Walking, Running/Jogging, Video Games, WALKIN...
# day_of_week                                   [1, 2, 3, 4, 5, 6, 0]
# time_of_day                           [afternoon, evening, morning]
# form_of_exercise                                    [aer, mix, ana]
# study                               [dexip, ext_101, ext_edu, helm]
# bout_id           [dexip_100_20210610130600, dexip_100_202132101...
# y                                                     [False, True]
# sex                                                  [male, female]
# race              [ASIAN, WHITE, MULTIPLE, NOT REPORTED, UNKNOWN...
# insulin_modality                      [mdi, pump, closed_loop, nan]
# stratify          [dexip_100_False, dexip_100_True, dexip_101_Fa...

# %%
num_data = pd.DataFrame(numeric_dict).T

# %%
num_data.to_csv('../../results/data_dictionary/numeric_data.csv')

# %% [markdown]
# ## 7.2. Statistical analysis

# %% [markdown]
# ### 7.2.1. Demographic and exercise bout data

# %%
# Categorical variables relating to exercise bout
cat_bout = ['intensity',
               'day_of_week',
               'time_of_day',
               'form_of_exercise',
               ]

# Numeric variables relating to exercise bout
numeric_bout = ['duration',
    'start_glc',
    'start_roc',]

# %%
# Categorical variables relating to demographics
cat_demo = [
    'sex',
    'insulin_modality',
    'race'
]

# Numeric variables relating to demographics
numeric_demo = [
    'age',
    'hba1c',
    'bmi',
    'years_since_diagnosis',
    ]

# %%
# Calculate relevant info for each study
overview = df.groupby('study').apply(lambda group: preprocess_helper.overview_results(group,  numeric_demo, cat_demo, numeric_bout, cat_bout))
overview = overview.reset_index().drop(columns='level_1')
# Out:
#    index         ID       start_datetime      finish_datetime intensity  \
# 0      0  dexip_100  2021-08-10 13:06:00  2021-08-10 13:26:00       0.0
# 1      1  dexip_100  2021-08-10 15:32:22  2021-08-10 15:47:22       0.0
# 2      2  dexip_100  2021-08-10 19:11:00  2021-08-10 19:36:00       0.0
# 3      3  dexip_100  2021-08-11 12:58:00  2021-08-11 13:13:00       0.0
# 4      4  dexip_100  2021-08-11 16:35:00  2021-08-11 16:50:00       0.0
#
#   type_of_exercise  month  day day_of_week time_of_day  ...  \
# 0          Walking      8   10           1   afternoon  ...
# 1  Running/Jogging      8   10           1   afternoon  ...
# 2      Video Games      8   10           1     evening  ...
# 3  Running/Jogging      8   11           2   afternoon  ...
# 4  Running/Jogging      8   11           2   afternoon  ...
#
#    glc__fourier_entropy__bins_5 glc__fourier_entropy__bins_10  \
# 0                      0.955700                      1.153742
# 1                      0.410116                      0.796312
# 2                      1.153742                      1.153742
# 3                      0.955700                      0.955700
# 4                      1.153742                      1.153742
#
#    glc__fourier_entropy__bins_100  \
# 0                        1.153742
# 1                        1.153742
# 2                        1.475076
# 3                        1.475076
# 4                        1.475076
#
#   glc__permutation_entropy__dimension_3__tau_1  \
# 0                                     0.943348
# 1                                     1.088900
# 2                                     0.801819
# 3                                     1.088900
# 4                                     1.168282
#
#   glc__permutation_entropy__dimension_4__tau_1  \
# 0                                     1.214890
# 1                                     1.303092
# 2                                     1.002718
# 3                                     1.581094
# 4                                     1.427061
#
#    glc__permutation_entropy__dimension_5__tau_1  \
# 0                                      1.494175
# 1                                      1.386294
# 2                                      1.073543
# 3                                      1.906155
# 4                                      1.667462
#
#    glc__permutation_entropy__dimension_6__tau_1  \
# 0                                      1.747868
# 1                                      1.475076
# 2                                      1.153742
# 3                                      1.945910
# 4                                      1.747868
#
#    glc__permutation_entropy__dimension_7__tau_1  \
# 0                                      1.791759
# 1                                      1.560710
# 2                                      1.242453
# 3                                      1.791759
# 4                                      1.791759
#
#    glc__mean_n_absolute_max__number_of_maxima_7         stratify
# 0                                      7.675714  dexip_100_False
# 1                                      8.041429  dexip_100_False
# 2                                      6.325714  dexip_100_False
# 3                                      6.970000  dexip_100_False
# 4                                      6.254286  dexip_100_False
#
# [5 rows x 414 columns]
# duration
# start_glc
# start_roc
# intensity
# day_of_week
# time_of_day
# form_of_exercise
#       index            ID       start_datetime      finish_datetime intensity  \
# 3137   4536  ext_101_3001  2018-05-19 11:25:00  2018-05-19 12:36:00       1.0
# 3138   4538  ext_101_3001  2018-06-03 18:45:00  2018-06-03 20:01:00       nan
# 3139   4540  ext_101_3001  2018-06-13 13:20:00  2018-06-13 14:15:00       1.0
# 3140   4541  ext_101_3001  2018-06-16 14:45:00  2018-06-16 15:40:00       nan
# 3141   4543  ext_101_3001  2018-07-06 12:10:00  2018-07-06 12:44:00       nan
#
#      type_of_exercise  month  day day_of_week time_of_day  ...  \
# 3137              run      5   19           5     morning  ...
# 3138            cycle      6    3           6     evening  ...
# 3139              run      6   13           2   afternoon  ...
# 3140              run      6   16           5   afternoon  ...
# 3141              run      7    6           4   afternoon  ...
#
#       glc__fourier_entropy__bins_5 glc__fourier_entropy__bins_10  \
# 3137                      1.098612                      1.098612
# 3138                      1.098612                      1.098612
# 3139                     -0.000000                     -0.000000
# 3140                      0.636514                      1.098612
# 3141                      1.098612                      1.098612
#
#       glc__fourier_entropy__bins_100  \
# 3137                        1.098612
# 3138                        1.098612
# 3139                       -0.000000
# 3140                        1.098612
# 3141                        1.098612
#
#      glc__permutation_entropy__dimension_3__tau_1  \
# 3137                                     0.693147
# 3138                                    -0.000000
# 3139                                          NaN
# 3140                                     0.693147
# 3141                                    -0.000000
#
#      glc__permutation_entropy__dimension_4__tau_1  \
# 3137                                         -0.0
# 3138                                         -0.0
# 3139                                          NaN
# 3140                                         -0.0
# 3141                                         -0.0
#
#       glc__permutation_entropy__dimension_5__tau_1  \
# 3137                                           NaN
# 3138                                           NaN
# 3139                                           NaN
# 3140                                           NaN
# 3141                                           NaN
#
#       glc__permutation_entropy__dimension_6__tau_1  \
# 3137                                           NaN
# 3138                                           NaN
# 3139                                           NaN
# 3140                                           NaN
# 3141                                           NaN
#
#       glc__permutation_entropy__dimension_7__tau_1  \
# 3137                                           NaN
# 3138                                           NaN
# 3139                                           NaN
# 3140                                           NaN
# 3141                                           NaN
#
#       glc__mean_n_absolute_max__number_of_maxima_7            stratify
# 3137                                           NaN  ext_101_3001_False
# 3138                                           NaN  ext_101_3001_False
# 3139                                           NaN  ext_101_3001_False
# 3140                                           NaN  ext_101_3001_False
# 3141                                           NaN  ext_101_3001_False
#
# [5 rows x 414 columns]
# duration
# start_glc
# start_roc
# intensity
# day_of_week
# time_of_day
# form_of_exercise
#       index            ID       start_datetime      finish_datetime intensity  \
# 3596   5234  ext_edu_1001  2018-01-09 17:24:00  2018-01-09 17:58:00       2.0
# 3597   5235  ext_edu_1001  2018-01-10 17:32:00  2018-01-10 17:42:00       1.0
# 3598   5236  ext_edu_1001  2018-01-10 18:03:00  2018-01-10 19:06:00       1.0
# 3599   5237  ext_edu_1001  2018-01-11 21:09:00  2018-01-11 21:21:00       1.0
# 3600   5238  ext_edu_1001  2018-01-12 19:02:00  2018-01-12 19:31:00       2.0
#
#      type_of_exercise  month  day day_of_week time_of_day  ...  \
# 3596          Running      1    9           1     evening  ...
# 3597          Cycling      1   10           2     evening  ...
# 3598         Football      1   10           2     evening  ...
# 3599          Cycling      1   11           3     evening  ...
# 3600          Running      1   12           4     evening  ...
#
#       glc__fourier_entropy__bins_5 glc__fourier_entropy__bins_10  \
# 3596                      0.796312                      0.796312
# 3597                      1.004242                      1.549826
# 3598                      1.153742                      1.549826
# 3599                      0.410116                      0.796312
# 3600                      0.796312                      0.796312
#
#       glc__fourier_entropy__bins_100  \
# 3596                        1.153742
# 3597                        1.945910
# 3598                        1.945910
# 3599                        1.153742
# 3600                        1.945910
#
#      glc__permutation_entropy__dimension_3__tau_1  \
# 3596                                     1.418484
# 3597                                     1.695743
# 3598                                     1.609438
# 3599                                     0.639032
# 3600                                     1.359237
#
#      glc__permutation_entropy__dimension_4__tau_1  \
# 3596                                     2.043192
# 3597                                     2.197225
# 3598                                     1.889159
# 3599                                     0.683739
# 3600                                     1.831020
#
#       glc__permutation_entropy__dimension_5__tau_1  \
# 3596                                      2.079442
# 3597                                      2.079442
# 3598                                      1.906155
# 3599                                      0.735622
# 3600                                      1.906155
#
#       glc__permutation_entropy__dimension_6__tau_1  \
# 3596                                      1.945910
# 3597                                      1.945910
# 3598                                      1.945910
# 3599                                      0.796312
# 3600                                      1.945910
#
#       glc__permutation_entropy__dimension_7__tau_1  \
# 3596                                      1.791759
# 3597                                      1.791759
# 3598                                      1.791759
# 3599                                      0.867563
# 3600                                      1.791759
#
#       glc__mean_n_absolute_max__number_of_maxima_7            stratify
# 3596                                     13.875714  ext_edu_1001_False
# 3597                                     16.158571  ext_edu_1001_False
# 3598                                     15.618571  ext_edu_1001_False
# 3599                                      6.388571  ext_edu_1001_False
# 3600                                      6.182857  ext_edu_1001_False
#
# [5 rows x 414 columns]
# duration
# start_glc
# start_roc
# intensity
# day_of_week
# time_of_day
# form_of_exercise
#       index      ID       start_datetime      finish_datetime intensity  \
# 4028   6102  helm_1  2020-05-11 10:21:14  2020-05-11 10:53:14       1.0
# 4029   6103  helm_1  2020-05-12 12:47:52  2020-05-12 13:19:52       1.0
# 4030   6104  helm_1  2020-05-13 12:04:27  2020-05-13 12:45:27       1.0
# 4031   6105  helm_1  2020-05-14 09:57:57  2020-05-14 10:27:57       0.0
# 4032   6106  helm_1  2020-05-14 13:21:43  2020-05-14 13:58:43       1.0
#
#                          type_of_exercise  month  day day_of_week time_of_day  \
# 4028                          Study Video      5   11           0     morning
# 4029  Jogging/Running (Indoor or Outdoor)      5   12           1   afternoon
# 4030                             Swimming      5   13           2   afternoon
# 4031                          Study Video      5   14           3     morning
# 4032  Jogging/Running (Indoor or Outdoor)      5   14           3   afternoon
#
#       ...  glc__fourier_entropy__bins_5 glc__fourier_entropy__bins_10  \
# 4028  ...                      0.796312                      1.153742
# 4029  ...                      0.410116                      0.796312
# 4030  ...                      1.277034                      1.277034
# 4031  ...                      0.796312                      1.153742
# 4032  ...                      0.410116                      0.410116
#
#       glc__fourier_entropy__bins_100  \
# 4028                        1.475076
# 4029                        1.277034
# 4030                        1.747868
# 4031                        1.153742
# 4032                        1.475076
#
#      glc__permutation_entropy__dimension_3__tau_1  \
# 4028                                     0.940448
# 4029                                     1.088900
# 4030                                     1.220607
# 4031                                     1.088900
# 4032                                     0.940448
#
#      glc__permutation_entropy__dimension_4__tau_1  \
# 4028                                     1.303092
# 4029                                     1.581094
# 4030                                     1.676988
# 4031                                     1.581094
# 4032                                     1.002718
#
#       glc__permutation_entropy__dimension_5__tau_1  \
# 4028                                      1.386294
# 4029                                      1.906155
# 4030                                      2.079442
# 4031                                      1.906155
# 4032                                      1.073543
#
#       glc__permutation_entropy__dimension_6__tau_1  \
# 4028                                      1.475076
# 4029                                      1.945910
# 4030                                      1.945910
# 4031                                      1.945910
# 4032                                      1.153742
#
#       glc__permutation_entropy__dimension_7__tau_1  \
# 4028                                      1.560710
# 4029                                      1.791759
# 4030                                      1.791759
# 4031                                      1.791759
# 4032                                      1.242453
#
#       glc__mean_n_absolute_max__number_of_maxima_7      stratify
# 4028                                      5.405714  helm_1_False
# 4029                                      6.801429  helm_1_False
# 4030                                      8.078571  helm_1_False
# 4031                                     13.040000  helm_1_False
# 4032                                     12.317143  helm_1_False
#
# [5 rows x 414 columns]
# duration
# start_glc
# start_roc
# intensity
# day_of_week
# time_of_day
# form_of_exercise

# %%
# Calculate relevant info for all studies combined
all_studies = preprocess_helper.overview_results(df,  numeric_demo, cat_demo, numeric_bout, cat_bout)
all_studies['study'] = 'all'
all_results = all_studies.append(overview)
# Out:
#    index         ID       start_datetime      finish_datetime intensity  \
# 0      0  dexip_100  2021-08-10 13:06:00  2021-08-10 13:26:00       0.0
# 1      1  dexip_100  2021-08-10 15:32:22  2021-08-10 15:47:22       0.0
# 2      2  dexip_100  2021-08-10 19:11:00  2021-08-10 19:36:00       0.0
# 3      3  dexip_100  2021-08-11 12:58:00  2021-08-11 13:13:00       0.0
# 4      4  dexip_100  2021-08-11 16:35:00  2021-08-11 16:50:00       0.0
#
#   type_of_exercise  month  day day_of_week time_of_day  ...  \
# 0          Walking      8   10           1   afternoon  ...
# 1  Running/Jogging      8   10           1   afternoon  ...
# 2      Video Games      8   10           1     evening  ...
# 3  Running/Jogging      8   11           2   afternoon  ...
# 4  Running/Jogging      8   11           2   afternoon  ...
#
#    glc__fourier_entropy__bins_5 glc__fourier_entropy__bins_10  \
# 0                      0.955700                      1.153742
# 1                      0.410116                      0.796312
# 2                      1.153742                      1.153742
# 3                      0.955700                      0.955700
# 4                      1.153742                      1.153742
#
#    glc__fourier_entropy__bins_100  \
# 0                        1.153742
# 1                        1.153742
# 2                        1.475076
# 3                        1.475076
# 4                        1.475076
#
#   glc__permutation_entropy__dimension_3__tau_1  \
# 0                                     0.943348
# 1                                     1.088900
# 2                                     0.801819
# 3                                     1.088900
# 4                                     1.168282
#
#   glc__permutation_entropy__dimension_4__tau_1  \
# 0                                     1.214890
# 1                                     1.303092
# 2                                     1.002718
# 3                                     1.581094
# 4                                     1.427061
#
#    glc__permutation_entropy__dimension_5__tau_1  \
# 0                                      1.494175
# 1                                      1.386294
# 2                                      1.073543
# 3                                      1.906155
# 4                                      1.667462
#
#    glc__permutation_entropy__dimension_6__tau_1  \
# 0                                      1.747868
# 1                                      1.475076
# 2                                      1.153742
# 3                                      1.945910
# 4                                      1.747868
#
#    glc__permutation_entropy__dimension_7__tau_1  \
# 0                                      1.791759
# 1                                      1.560710
# 2                                      1.242453
# 3                                      1.791759
# 4                                      1.791759
#
#    glc__mean_n_absolute_max__number_of_maxima_7         stratify
# 0                                      7.675714  dexip_100_False
# 1                                      8.041429  dexip_100_False
# 2                                      6.325714  dexip_100_False
# 3                                      6.970000  dexip_100_False
# 4                                      6.254286  dexip_100_False
#
# [5 rows x 414 columns]
# duration
# start_glc
# start_roc
# intensity
# day_of_week
# time_of_day
# form_of_exercise

# %%
# Rename cols and reset index
all_results.columns = ['Feature', 'Result (Median [IQR])', 'Study']
all_results = all_results.reset_index(drop=True)

# %% [markdown]
# ### 7.2.2 Metrics of glycemic control

# %% [markdown]
# # T1-DEXI metrics
# helmsley_cgm = pd.read_csv(directory_helm + 'cgm.csv')
# helmsley_cgm['time'] = pd.to_datetime(helmsley_cgm['time'])
# helm_metrics = metrics.all_standard_metrics(helmsley_cgm)

# %% [markdown]
# # T1-DEXIP metrics
# dexip_cgm = pd.read_csv(directory_dexip + 'cgm.csv')
# dexip_cgm['time'] = pd.to_datetime(dexip_cgm['time'])
# dexip_metrics = metrics.all_standard_metrics(dexip_cgm)

# %% [markdown]
# # EXT-101 metrics
# extod_101_cgm = pd.read_csv(directory_101 + 'cgm.csv')
# extod_101_cgm['time'] = pd.to_datetime(extod_101_cgm['time'])
# ext_101_metrics = metrics.all_standard_metrics(extod_101_cgm)

# %% [markdown]
# # EXT-edu metrics
# extod_edu_cgm = pd.read_csv(directory_edu + 'cgm.csv')
# extod_edu_cgm['time'] = pd.to_datetime(extod_edu_cgm['time'])
# ext_edu_metrics = metrics.all_standard_metrics(extod_edu_cgm)

# %% [markdown]
# # Combine all studies
# all_metrics = helm_metrics.append(dexip_metrics).append(ext_edu_metrics).append(ext_101_metrics)

# %% [markdown]
# # Save the metrics
# all_metrics.to_csv('../../results/metrics_glycemic_control.csv')

# %%
all_metrics = pd.read_csv('../../results/metrics_glycemic_control.csv')

# %%
all_metrics
# Out:
#      Unnamed: 0            ID  Average glucose (mmol/L)  eA1c (%)  \
# 0             0        helm_1                  8.952967  7.259728
# 1             1     helm_1000                  7.862634  6.573983
# 2             2     helm_1004                  8.334872  6.870989
# 3             3     helm_1010                  7.465760  6.324377
# 4             4     helm_1012                  7.266100  6.198805
# ..          ...           ...                       ...       ...
# 853          37  ext_101_3043                  7.423824  6.298002
# 854          38  ext_101_3044                  7.311511  6.227365
# 855          39  ext_101_3045                  8.576277  7.022816
# 856          40  ext_101_3046                  6.940633  5.994109
# 857          41  ext_101_3047                  9.245249  7.443553
#
#      SD (mmol/L)     CV (%)  AUC (mmol h/L)      LBGI      HBGI  \
# 0       3.607006  40.288382        8.174627  0.836351  7.821003
# 1       2.237376  28.455809        7.172314  0.332605  3.676388
# 2       2.654680  31.850281        7.612339  0.800243  5.128033
# 3       3.168540  42.440956        6.760118  2.282610  4.340416
# 4       2.076445  28.577160        6.575361  0.716802  2.528263
# ..           ...        ...             ...       ...       ...
# 853     2.237951  30.145526        5.410065  0.650862  2.936287
# 854     2.613584  35.746155        5.312929  1.786254  3.313367
# 855     3.969074  46.279681        6.333879  2.439792  7.477813
# 856     3.315082  47.763393        5.119489  5.290168  3.777357
# 857     3.521429  38.089063        6.798208  0.904505  8.222142
#
#      MAGE (mmol/L)  ...  Number LV2 hypoglycemic events  \
# 0         8.225111  ...                               0
# 1         5.506297  ...                               0
# 2         6.160585  ...                               4
# 3         6.931330  ...                              18
# 4         5.060042  ...                               3
# ..             ...  ...                             ...
# 853       5.427980  ...                               4
# 854       6.443787  ...                              33
# 855       9.405907  ...                              63
# 856       7.447610  ...                             124
# 857       8.868433  ...                               6
#
#      Number prolonged hypoglycemic events  Avg. length of hypoglycemic events  \
# 0                                       0                     0 days 00:41:09
# 1                                       0                     0 days 00:30:00
# 2                                       0                     0 days 01:00:57
# 3                                       2                     0 days 00:57:30
# 4                                       0                     0 days 00:38:03
# ..                                    ...                                 ...
# 853                                     0                     0 days 01:00:27
# 854                                     0                     0 days 01:21:20
# 855                                    14                     0 days 01:28:06
# 856                                    55                     0 days 02:50:37
# 857                                     1                     0 days 01:25:26
#
#      Total time spent in hypoglycemic events  \
# 0                            0 days 17:50:00
# 1                            0 days 00:59:59
# 2                            0 days 21:20:05
# 3                            2 days 05:40:10
# 4                            0 days 11:24:57
# ..                                       ...
# 853                          1 days 23:21:00
# 854                          4 days 08:23:00
# 855                         10 days 18:25:00
# 856                         22 days 12:18:00
# 857                          0 days 19:56:00
#
#      Total number hyperglycemic events  Number LV1 hyperglycemic events  \
# 0                                   82                               53
# 1                                   47                               39
# 2                                   69                               62
# 3                                   49                               38
# 4                                   43                               40
# ..                                 ...                              ...
# 853                                175                              155
# 854                                 99                               87
# 855                                331                              198
# 856                                166                              123
# 857                                 63                               40
#
#      Number LV2 hyperglycemic events  Number prolonged hyperglycemic events  \
# 0                                 29                                     11
# 1                                  8                                      1
# 2                                  7                                      3
# 3                                 11                                      6
# 4                                  3                                      0
# ..                               ...                                    ...
# 853                               20                                      2
# 854                               12                                      1
# 855                              133                                     37
# 856                               43                                     14
# 857                               23                                     15
#
#      Avg. length of hyperglycemic events  \
# 0                        0 days 02:50:48
# 1                        0 days 02:27:02
# 2                        0 days 02:18:16
# 3                        0 days 02:34:00
# 4                        0 days 01:50:14
# ..                                   ...
# 853                      0 days 02:06:16
# 854                      0 days 02:44:18
# 855                      0 days 02:45:50
# 856                      0 days 04:27:12
# 857                      0 days 03:54:40
#
#      Total time spent in hyperglycemic events
# 0                             9 days 17:25:30
# 1                             4 days 19:10:15
# 2                             6 days 14:59:51
# 3                             5 days 05:45:43
# 4                             3 days 06:59:49
# ..                                        ...
# 853                          15 days 08:16:00
# 854                          11 days 07:06:00
# 855                          38 days 02:52:00
# 856                          30 days 19:16:00
# 857                          10 days 06:24:00
#
# [858 rows x 29 columns]

# %%
# Drop columns that won't be included in table
cols = ['Avg. length of hypoglycemic events', 
        'Total time spent in hypoglycemic events',
         'Avg. length of hyperglycemic events',
         'Total time spent in hyperglycemic events','ID',
         'Unnamed: 0' ]
all_metrics_dropped  = all_metrics.drop(columns=cols)
remaining_cols = all_metrics_dropped.columns

# %%
len(all_metrics.ID.unique())
# Out:
# 858

# %%
# Calculate mean[iqr] glycemic metrics for all participants 
all_metrics_iqr = preprocess_helper.col_iqr(all_metrics, remaining_cols)
all_metrics_iqr['Study'] = 'all'

# Calculate mean[iqr] glycemic metrics for dexi participants 
helm_metrics_iqr =  preprocess_helper.col_iqr(all_metrics[all_metrics['ID'].str.startswith('helm')], remaining_cols)
helm_metrics_iqr['Study'] = 'helm'

# Calculate mean[iqr] glycemic metrics for dexip participants 
dexip_metrics_iqr =  preprocess_helper.col_iqr(all_metrics[all_metrics['ID'].str.startswith('dexip')], remaining_cols)
dexip_metrics_iqr['Study'] = 'dexip'

# Calculate mean[iqr] glycemic metrics for edu participants 
ext_edu_metrics_iqr =  preprocess_helper.col_iqr(all_metrics[all_metrics['ID'].str.startswith('ext_edu')], remaining_cols)
ext_edu_metrics_iqr['Study'] = 'ext_edu'

# Calculate mean[iqr] glycemic metrics for 101 participants 
ext_101_metrics_iqr =  preprocess_helper.col_iqr(all_metrics[all_metrics['ID'].str.startswith('ext_101')], remaining_cols)
ext_101_metrics_iqr['Study'] = 'ext_101'
# Out:
# Average glucose (mmol/L)
# 8.3 [7.45, 9.55]
# eA1c (%)
# 6.85 [6.31, 7.64]
# SD (mmol/L)
# 2.88 [2.34, 3.57]
# CV (%)
# 34.21 [29.98, 38.42]
# AUC (mmol h/L)
# 7.43 [6.7, 8.58]
# LBGI
# 0.7 [0.37, 1.13]
# HBGI
# 5.37 [3.23, 9.04]
# MAGE (mmol/L)
# 6.98 [5.73, 8.6]
# TIR normal (%)
# 72.18 [57.2, 82.13]
# TIR normal 1 (%)
# 46.16 [33.2, 59.17]
# TIR normal 2 (%)
# 22.88 [18.81, 26.56]
# TIR level 1 hypoglycemia (%)
# 1.98 [0.84, 3.67]
# TIR level 2 hypoglycemia (%)
# 0.3 [0.08, 0.79]
# TIR level 1 hyperglycemia (%)
# 18.82 [11.78, 25.12]
# TIR level 2 hyperglycemia (%)
# 4.74 [1.43, 11.99]
# Total number hypoglycemic events
# 12.0 [5.0, 25.0]
# Number LV1 hypoglycemic events
# 10.0 [4.0, 20.0]
# Number LV2 hypoglycemic events
# 2.0 [0.0, 4.0]
# Number prolonged hypoglycemic events
# 0.0 [0.0, 0.0]
# Total number hyperglycemic events
# 39.0 [24.0, 60.0]
# Number LV1 hyperglycemic events
# 27.0 [15.25, 44.0]
# Number LV2 hyperglycemic events
# 11.0 [5.0, 18.0]
# Number prolonged hyperglycemic events
# 3.0 [1.0, 6.0]
# Average glucose (mmol/L)
# 7.94 [7.24, 8.77]
# eA1c (%)
# 6.62 [6.18, 7.14]
# SD (mmol/L)
# 2.64 [2.21, 3.15]
# CV (%)
# 32.96 [29.09, 36.87]
# AUC (mmol h/L)
# 7.21 [6.59, 7.99]
# LBGI
# 0.72 [0.42, 1.17]
# HBGI
# 4.34 [2.72, 6.64]
# MAGE (mmol/L)
# 6.46 [5.38, 7.56]
# TIR normal (%)
# 76.94 [65.94, 84.91]
# TIR normal 1 (%)
# 51.02 [39.87, 61.97]
# TIR normal 2 (%)
# 23.63 [19.59, 27.02]
# TIR level 1 hypoglycemia (%)
# 2.12 [0.99, 3.84]
# TIR level 2 hypoglycemia (%)
# 0.29 [0.09, 0.72]
# TIR level 1 hyperglycemia (%)
# 16.36 [9.99, 23.04]
# TIR level 2 hyperglycemia (%)
# 3.0 [0.89, 6.76]
# Total number hypoglycemic events
# 18.0 [8.0, 31.0]
# Number LV1 hypoglycemic events
# 16.0 [7.0, 26.0]
# Number LV2 hypoglycemic events
# 2.0 [0.0, 5.0]
# Number prolonged hypoglycemic events
# 0.0 [0.0, 0.0]
# Total number hyperglycemic events
# 53.0 [37.0, 66.0]
# Number LV1 hyperglycemic events
# 39.0 [27.0, 48.0]
# Number LV2 hyperglycemic events
# 11.0 [4.0, 20.0]
# Number prolonged hyperglycemic events
# 2.0 [0.0, 6.0]
# Average glucose (mmol/L)
# 8.78 [7.76, 10.0]
# eA1c (%)
# 7.15 [6.51, 7.92]
# SD (mmol/L)
# 3.15 [2.53, 3.77]
# CV (%)
# 34.58 [30.79, 39.23]
# AUC (mmol h/L)
# 7.96 [7.05, 9.01]
# LBGI
# 0.6 [0.27, 0.99]
# HBGI
# 6.69 [4.12, 10.12]
# MAGE (mmol/L)
# 7.56 [6.08, 9.08]
# TIR normal (%)
# 68.18 [55.81, 79.16]
# TIR normal 1 (%)
# 44.5 [30.26, 55.44]
# TIR normal 2 (%)
# 22.38 [18.1, 26.14]
# TIR level 1 hypoglycemia (%)
# 1.6 [0.56, 2.91]
# TIR level 2 hypoglycemia (%)
# 0.22 [0.04, 0.62]
# TIR level 1 hyperglycemia (%)
# 20.37 [14.26, 26.16]
# TIR level 2 hyperglycemia (%)
# 7.73 [2.7, 14.89]
# Total number hypoglycemic events
# 6.0 [2.0, 10.0]
# Number LV1 hypoglycemic events
# 5.0 [2.0, 9.0]
# Number LV2 hypoglycemic events
# 0.0 [0.0, 2.0]
# Number prolonged hypoglycemic events
# 0.0 [0.0, 0.0]
# Total number hyperglycemic events
# 24.0 [18.0, 30.0]
# Number LV1 hyperglycemic events
# 15.0 [11.0, 20.0]
# Number LV2 hyperglycemic events
# 9.0 [4.0, 13.0]
# Number prolonged hyperglycemic events
# 2.0 [0.0, 4.5]
# Average glucose (mmol/L)
# 10.28 [9.0, 11.1]
# eA1c (%)
# 8.1 [7.29, 8.61]
# SD (mmol/L)
# 4.0 [3.46, 4.73]
# CV (%)
# 37.84 [34.76, 42.71]
# AUC (mmol h/L)
# 9.28 [8.01, 9.96]
# LBGI
# 0.65 [0.33, 1.35]
# HBGI
# 11.54 [7.53, 14.51]
# MAGE (mmol/L)
# 9.35 [8.3, 10.72]
# TIR normal (%)
# 47.3 [40.19, 61.66]
# TIR normal 1 (%)
# 27.58 [22.02, 37.09]
# TIR normal 2 (%)
# 20.5 [16.72, 25.14]
# TIR level 1 hypoglycemia (%)
# 1.94 [0.77, 3.79]
# TIR level 2 hypoglycemia (%)
# 0.59 [0.13, 2.05]
# TIR level 1 hyperglycemia (%)
# 23.9 [20.04, 29.65]
# TIR level 2 hyperglycemia (%)
# 18.56 [8.92, 27.67]
# Total number hypoglycemic events
# 6.0 [3.0, 9.0]
# Number LV1 hypoglycemic events
# 3.0 [2.0, 6.25]
# Number LV2 hypoglycemic events
# 2.0 [0.0, 4.0]
# Number prolonged hypoglycemic events
# 0.0 [0.0, 0.0]
# Total number hyperglycemic events
# 25.5 [19.75, 34.25]
# Number LV1 hyperglycemic events
# 14.5 [8.0, 19.25]
# Number LV2 hyperglycemic events
# 13.0 [8.75, 16.0]
# Number prolonged hyperglycemic events
# 5.0 [2.75, 8.0]
# Average glucose (mmol/L)
# 8.8 [7.9, 9.86]
# eA1c (%)
# 7.16 [6.59, 7.83]
# SD (mmol/L)
# 3.61 [3.17, 4.23]
# CV (%)
# 40.34 [35.88, 46.18]
# AUC (mmol h/L)
# 6.51 [5.83, 7.26]
# LBGI
# 1.03 [0.58, 2.43]
# HBGI
# 7.46 [5.29, 11.25]
# MAGE (mmol/L)
# 8.29 [7.46, 9.93]
# TIR normal (%)
# 60.04 [48.62, 66.36]
# TIR normal 1 (%)
# 37.18 [29.22, 44.62]
# TIR normal 2 (%)
# 20.72 [18.86, 24.44]
# TIR level 1 hypoglycemia (%)
# 3.13 [1.4, 5.83]
# TIR level 2 hypoglycemia (%)
# 1.09 [0.44, 3.96]
# TIR level 1 hyperglycemia (%)
# 21.9 [17.75, 26.7]
# TIR level 2 hyperglycemia (%)
# 9.27 [4.86, 17.9]
# Total number hypoglycemic events
# 72.0 [27.25, 129.5]
# Number LV1 hypoglycemic events
# 43.5 [21.75, 81.75]
# Number LV2 hypoglycemic events
# 19.0 [6.25, 45.75]
# Number prolonged hypoglycemic events
# 2.0 [0.0, 8.0]
# Total number hyperglycemic events
# 210.0 [135.0, 319.5]
# Number LV1 hyperglycemic events
# 124.0 [64.75, 198.0]
# Number LV2 hyperglycemic events
# 64.5 [35.25, 130.0]
# Number prolonged hyperglycemic events
# 26.0 [10.25, 40.0]

# %%
# Combine all the studies cgm data
overview_cgm = all_metrics_iqr.append(helm_metrics_iqr).append(dexip_metrics_iqr).append(ext_edu_metrics_iqr).append(ext_101_metrics_iqr)

# Rename cols
overview_cgm.columns = ['Feature', 'Result (Median [IQR])', 'Study']

# %% [markdown]
# ### 7.2.3. Combine datasets

# %%
# Add CGM results to demographic and exercise data
all_results = all_results.append(overview_cgm)

# %%
# Display table
ci_table = all_results.pivot(columns='Feature', values='Result (Median [IQR])', index='Study').T

# %%
ci_table_ordered = ci_table[['all','helm',	'dexip',	'ext_101',	'ext_edu']].reset_index()

# %%
# Conversion function
def convert_to_mg_per_dl(value_str):
    # Conversion factor from mmol/L to mg/dL
    conversion_factor = 18.01559
    
    # Extract the main value and the range values
    main_value = float(value_str.split('[')[0].strip())
    range_values = [float(val) for val in value_str.split('[')[1].replace(']', '').split(',')]
    
    # Convert the values
    main_value_mg_per_dl = round(main_value * conversion_factor, 1)
    range_values_mg_per_dl = [round(val * conversion_factor, 1) for val in range_values]
    
    # Format the result
    result = "{} [{} , {}]".format(main_value_mg_per_dl, range_values_mg_per_dl[0], range_values_mg_per_dl[1])
    
    return result

# List of features to convert
features_to_convert = ["Average glucose (mmol/L)", "SD (mmol/L)", "start_glc"]

# Columns to apply the conversion to
cols_to_convert = ['all', 'helm', 'dexip', 'ext_101',	'ext_edu']  # Add other columns as needed

# Apply the function to the specified rows and columns
for feature in features_to_convert:
    ci_table_ordered.loc[ci_table_ordered['Feature'] == feature, cols_to_convert] = ci_table_ordered.loc[ci_table_ordered['Feature'] == feature, cols_to_convert].applymap(convert_to_mg_per_dl)

print(ci_table_ordered)
# Out:
# Study                                Feature  \
# 0                             AUC (mmol h/L)
# 1                   Average glucose (mmol/L)
# 2                                     CV (%)
# 3                                       HBGI
# 4                                       LBGI
# 5                              MAGE (mmol/L)
# 6            Number LV1 hyperglycemic events
# 7             Number LV1 hypoglycemic events
# 8            Number LV2 hyperglycemic events
# 9             Number LV2 hypoglycemic events
# 10     Number prolonged hyperglycemic events
# 11      Number prolonged hypoglycemic events
# 12                               SD (mmol/L)
# 13             TIR level 1 hyperglycemia (%)
# 14              TIR level 1 hypoglycemia (%)
# 15             TIR level 2 hyperglycemia (%)
# 16              TIR level 2 hypoglycemia (%)
# 17                            TIR normal (%)
# 18                          TIR normal 1 (%)
# 19                          TIR normal 2 (%)
# 20         Total number hyperglycemic events
# 21          Total number hypoglycemic events
# 22                                       age
# 23                                       bmi
# 24                          bouts per person
# 25                               day_of_week
# 26                                  duration
# 27                                  eA1c (%)
# 28                          form_of_exercise
# 29                                     hba1c
# 30                          insulin_modality
# 31                                 intensity
# 32                           number of bouts
# 33                    number of participants
# 34              percentage bouts end in hypo
# 35                                      race
# 36                                       sex
# 37                                 start_glc
# 38                                 start_roc
# 39                               time_of_day
# 40                     years_since_diagnosis
#
# Study                                                all  \
# 0                                       7.43 [6.7, 8.58]
# 1                                  149.5 [134.2 , 172.0]
# 2                                   34.21 [29.98, 38.42]
# 3                                      5.37 [3.23, 9.04]
# 4                                       0.7 [0.37, 1.13]
# 5                                       6.98 [5.73, 8.6]
# 6                                     27.0 [15.25, 44.0]
# 7                                       10.0 [4.0, 20.0]
# 8                                       11.0 [5.0, 18.0]
# 9                                         2.0 [0.0, 4.0]
# 10                                        3.0 [1.0, 6.0]
# 11                                        0.0 [0.0, 0.0]
# 12                                    51.9 [42.2 , 64.3]
# 13                                  18.82 [11.78, 25.12]
# 14                                     1.98 [0.84, 3.67]
# 15                                    4.74 [1.43, 11.99]
# 16                                      0.3 [0.08, 0.79]
# 17                                   72.18 [57.2, 82.13]
# 18                                   46.16 [33.2, 59.17]
# 19                                  22.88 [18.81, 26.56]
# 20                                     39.0 [24.0, 60.0]
# 21                                      12.0 [5.0, 25.0]
# 22                                     27.0 [16.0, 42.0]
# 23                                  23.72 [21.28, 26.33]
# 24                                     17.0 [10.0, 26.0]
# 25     3    2516
# 4    2398
# 1    2385
# 5    2344
# 6    2...
# 26                                     30.0 [22.0, 48.0]
# 27                                     6.85 [6.31, 7.64]
# 28     aer    10653
# mix     4076
# ana     1761
# Name: f...
# 29                                   50.82 [44.26, 57.0]
# 30     closed_loop    359
# pump           279
# mdi     ...
# 31     0.0    7172
# 1.0    7019
# 2.0    2098
# nan     20...
# 32                                                 16490
# 33                                                   834
# 34                                              0.093996
# 35     WHITE                             672
# MULTIPLE...
# 36     female    509
# male      325
# Name: sex, dtype: ...
# 37                                 141.1 [111.2 , 181.2]
# 38                                     0.0 [-1.81, 1.64]
# 39     afternoon    5694
# morning      5611
# evening   ...
# 40                                      12.0 [9.0, 21.0]
#
# Study                                               helm  \
# 0                                      7.21 [6.59, 7.99]
# 1                                  143.0 [130.4 , 158.0]
# 2                                   32.96 [29.09, 36.87]
# 3                                      4.34 [2.72, 6.64]
# 4                                      0.72 [0.42, 1.17]
# 5                                      6.46 [5.38, 7.56]
# 6                                      39.0 [27.0, 48.0]
# 7                                       16.0 [7.0, 26.0]
# 8                                       11.0 [4.0, 20.0]
# 9                                         2.0 [0.0, 5.0]
# 10                                        2.0 [0.0, 6.0]
# 11                                        0.0 [0.0, 0.0]
# 12                                    47.6 [39.8 , 56.7]
# 13                                   16.36 [9.99, 23.04]
# 14                                     2.12 [0.99, 3.84]
# 15                                      3.0 [0.89, 6.76]
# 16                                     0.29 [0.09, 0.72]
# 17                                  76.94 [65.94, 84.91]
# 18                                  51.02 [39.87, 61.97]
# 19                                  23.63 [19.59, 27.02]
# 20                                     53.0 [37.0, 66.0]
# 21                                      18.0 [8.0, 31.0]
# 22                                     33.0 [25.0, 46.0]
# 23                                  24.46 [22.71, 27.11]
# 24                                     23.0 [16.0, 31.0]
# 25     3    1864
# 4    1822
# 1    1810
# 5    1781
# 6    1...
# 26                                     30.0 [22.0, 45.0]
# 27                                     6.62 [6.18, 7.14]
# 28     aer    7650
# mix    3305
# ana    1507
# Name: form...
# 29                                   48.63 [43.17, 54.1]
# 30     closed_loop    222
# pump           187
# mdi     ...
# 31     1.0    5915
# 0.0    4888
# 2.0    1659
# Name: inte...
# 32                                                 12462
# 33                                                   496
# 34                                              0.089713
# 35     WHITE                             453
# NOT REPO...
# 36     female    362
# male      134
# Name: sex, dtype: ...
# 37                                 138.2 [110.1 , 175.1]
# 38                                     0.0 [-1.74, 1.56]
# 39     morning      4461
# afternoon    4023
# evening   ...
# 40                                     16.0 [11.0, 24.0]
#
# Study                                              dexip  \
# 0                                      7.96 [7.05, 9.01]
# 1                                  158.2 [139.8 , 180.2]
# 2                                   34.58 [30.79, 39.23]
# 3                                     6.69 [4.12, 10.12]
# 4                                       0.6 [0.27, 0.99]
# 5                                      7.56 [6.08, 9.08]
# 6                                      15.0 [11.0, 20.0]
# 7                                         5.0 [2.0, 9.0]
# 8                                        9.0 [4.0, 13.0]
# 9                                         0.0 [0.0, 2.0]
# 10                                        2.0 [0.0, 4.5]
# 11                                        0.0 [0.0, 0.0]
# 12                                    56.7 [45.6 , 67.9]
# 13                                  20.37 [14.26, 26.16]
# 14                                      1.6 [0.56, 2.91]
# 15                                     7.73 [2.7, 14.89]
# 16                                     0.22 [0.04, 0.62]
# 17                                  68.18 [55.81, 79.16]
# 18                                   44.5 [30.26, 55.44]
# 19                                   22.38 [18.1, 26.14]
# 20                                     24.0 [18.0, 30.0]
# 21                                       6.0 [2.0, 10.0]
# 22                                     14.0 [12.0, 15.0]
# 23                                  20.74 [18.59, 23.61]
# 24                                      11.0 [8.0, 16.0]
# 25     3    507
# 4    463
# 2    460
# 5    451
# 1    439
# 6...
# 26                                     35.0 [20.0, 60.0]
# 27                                     7.15 [6.51, 7.92]
# 28     aer    2287
# mix     684
# ana     166
# Name: form...
# 29                                  53.01 [44.26, 59.56]
# 30     closed_loop    137
# pump            73
# mdi     ...
# 31     0.0    1870
# 1.0     786
# 2.0     322
# nan     15...
# 32                                                  3137
# 33                                                   246
# 34                                              0.107427
# 35     WHITE                             219
# MULTIPLE...
# 36     male      142
# female    104
# Name: sex, dtype: ...
# 37                                 150.1 [114.0 , 200.2]
# 38                                    0.14 [-2.12, 2.13]
# 39     afternoon    1477
# evening       903
# morning   ...
# 40                                      10.0 [7.0, 12.0]
#
# Study                                            ext_101  \
# 0                                      6.51 [5.83, 7.26]
# 1                                  158.5 [142.3 , 177.6]
# 2                                   40.34 [35.88, 46.18]
# 3                                     7.46 [5.29, 11.25]
# 4                                      1.03 [0.58, 2.43]
# 5                                      8.29 [7.46, 9.93]
# 6                                   124.0 [64.75, 198.0]
# 7                                    43.5 [21.75, 81.75]
# 8                                    64.5 [35.25, 130.0]
# 9                                     19.0 [6.25, 45.75]
# 10                                    26.0 [10.25, 40.0]
# 11                                        2.0 [0.0, 8.0]
# 12                                    65.0 [57.1 , 76.2]
# 13                                    21.9 [17.75, 26.7]
# 14                                      3.13 [1.4, 5.83]
# 15                                     9.27 [4.86, 17.9]
# 16                                     1.09 [0.44, 3.96]
# 17                                  60.04 [48.62, 66.36]
# 18                                  37.18 [29.22, 44.62]
# 19                                  20.72 [18.86, 24.44]
# 20                                  210.0 [135.0, 319.5]
# 21                                   72.0 [27.25, 129.5]
# 22                                   45.23 [37.7, 51.08]
# 23                                  23.47 [22.22, 25.17]
# 24                                     10.5 [6.25, 18.0]
# 25     1    76
# 0    71
# 3    70
# 6    67
# 2    67
# 5    6...
# 26                                     55.0 [40.0, 60.0]
# 27                                     7.16 [6.59, 7.83]
# 28     aer    358
# mix     68
# ana     33
# Name: form_of...
# 29                                    57.0 [51.25, 61.0]
# 30     pump    19
# mdi     14
# Name: insulin_modality, ...
# 31     0.0    184
# 1.0    174
# 2.0     90
# nan     11
# Na...
# 32                                                   459
# 33                                                    34
# 34                                              0.095861
# 35                  Series([], Name: race, dtype: int64)
# 36     female    20
# male      14
# Name: sex, dtype: int64
# 37                                 158.5 [118.9 , 218.0]
# 38                                   -0.42 [-2.18, 1.33]
# 39     morning      199
# evening      187
# afternoon   ...
# 40                                  19.11 [10.15, 32.86]
#
# Study                                            ext_edu
# 0                                      9.28 [8.01, 9.96]
# 1                                  185.2 [162.1 , 200.0]
# 2                                   37.84 [34.76, 42.71]
# 3                                    11.54 [7.53, 14.51]
# 4                                      0.65 [0.33, 1.35]
# 5                                      9.35 [8.3, 10.72]
# 6                                      14.5 [8.0, 19.25]
# 7                                        3.0 [2.0, 6.25]
# 8                                      13.0 [8.75, 16.0]
# 9                                         2.0 [0.0, 4.0]
# 10                                       5.0 [2.75, 8.0]
# 11                                        0.0 [0.0, 0.0]
# 12                                    72.1 [62.3 , 85.2]
# 13                                   23.9 [20.04, 29.65]
# 14                                     1.94 [0.77, 3.79]
# 15                                   18.56 [8.92, 27.67]
# 16                                     0.59 [0.13, 2.05]
# 17                                   47.3 [40.19, 61.66]
# 18                                  27.58 [22.02, 37.09]
# 19                                   20.5 [16.72, 25.14]
# 20                                   25.5 [19.75, 34.25]
# 21                                        6.0 [3.0, 9.0]
# 22                                   47.5 [36.25, 56.75]
# 23                                  25.02 [22.81, 29.26]
# 24                                      5.0 [2.25, 11.0]
# 25     3    75
# 2    69
# 4    66
# 1    60
# 6    57
# 0    5...
# 26                                     40.0 [30.0, 60.0]
# 27                                      8.1 [7.29, 8.61]
# 28     aer    358
# ana     55
# mix     19
# Name: form_of...
# 29                                    60.0 [54.0, 65.75]
# 30        mdi    58
# Name: insulin_modality, dtype: int64
# 31     0.0    230
# 1.0    144
# nan     31
# 2.0     27
# Na...
# 32                                                   432
# 33                                                    58
# 34                                              0.118056
# 35                  Series([], Name: race, dtype: int64)
# 36     male      35
# female    23
# Name: sex, dtype: int64
# 37                                 157.5 [120.0 , 213.3]
# 38                                     0.0 [-2.12, 1.55]
# 39     morning      194
# afternoon    121
# evening     ...
# 40                                   13.98 [4.52, 23.31]

# %%
ci_table_ordered
# Out:
# Study                                Feature  \
# 0                             AUC (mmol h/L)
# 1                   Average glucose (mmol/L)
# 2                                     CV (%)
# 3                                       HBGI
# 4                                       LBGI
# 5                              MAGE (mmol/L)
# 6            Number LV1 hyperglycemic events
# 7             Number LV1 hypoglycemic events
# 8            Number LV2 hyperglycemic events
# 9             Number LV2 hypoglycemic events
# 10     Number prolonged hyperglycemic events
# 11      Number prolonged hypoglycemic events
# 12                               SD (mmol/L)
# 13             TIR level 1 hyperglycemia (%)
# 14              TIR level 1 hypoglycemia (%)
# 15             TIR level 2 hyperglycemia (%)
# 16              TIR level 2 hypoglycemia (%)
# 17                            TIR normal (%)
# 18                          TIR normal 1 (%)
# 19                          TIR normal 2 (%)
# 20         Total number hyperglycemic events
# 21          Total number hypoglycemic events
# 22                                       age
# 23                                       bmi
# 24                          bouts per person
# 25                               day_of_week
# 26                                  duration
# 27                                  eA1c (%)
# 28                          form_of_exercise
# 29                                     hba1c
# 30                          insulin_modality
# 31                                 intensity
# 32                           number of bouts
# 33                    number of participants
# 34              percentage bouts end in hypo
# 35                                      race
# 36                                       sex
# 37                                 start_glc
# 38                                 start_roc
# 39                               time_of_day
# 40                     years_since_diagnosis
#
# Study                                                all  \
# 0                                       7.43 [6.7, 8.58]
# 1                                  149.5 [134.2 , 172.0]
# 2                                   34.21 [29.98, 38.42]
# 3                                      5.37 [3.23, 9.04]
# 4                                       0.7 [0.37, 1.13]
# 5                                       6.98 [5.73, 8.6]
# 6                                     27.0 [15.25, 44.0]
# 7                                       10.0 [4.0, 20.0]
# 8                                       11.0 [5.0, 18.0]
# 9                                         2.0 [0.0, 4.0]
# 10                                        3.0 [1.0, 6.0]
# 11                                        0.0 [0.0, 0.0]
# 12                                    51.9 [42.2 , 64.3]
# 13                                  18.82 [11.78, 25.12]
# 14                                     1.98 [0.84, 3.67]
# 15                                    4.74 [1.43, 11.99]
# 16                                      0.3 [0.08, 0.79]
# 17                                   72.18 [57.2, 82.13]
# 18                                   46.16 [33.2, 59.17]
# 19                                  22.88 [18.81, 26.56]
# 20                                     39.0 [24.0, 60.0]
# 21                                      12.0 [5.0, 25.0]
# 22                                     27.0 [16.0, 42.0]
# 23                                  23.72 [21.28, 26.33]
# 24                                     17.0 [10.0, 26.0]
# 25     3    2516
# 4    2398
# 1    2385
# 5    2344
# 6    2...
# 26                                     30.0 [22.0, 48.0]
# 27                                     6.85 [6.31, 7.64]
# 28     aer    10653
# mix     4076
# ana     1761
# Name: f...
# 29                                   50.82 [44.26, 57.0]
# 30     closed_loop    359
# pump           279
# mdi     ...
# 31     0.0    7172
# 1.0    7019
# 2.0    2098
# nan     20...
# 32                                                 16490
# 33                                                   834
# 34                                              0.093996
# 35     WHITE                             672
# MULTIPLE...
# 36     female    509
# male      325
# Name: sex, dtype: ...
# 37                                 141.1 [111.2 , 181.2]
# 38                                     0.0 [-1.81, 1.64]
# 39     afternoon    5694
# morning      5611
# evening   ...
# 40                                      12.0 [9.0, 21.0]
#
# Study                                               helm  \
# 0                                      7.21 [6.59, 7.99]
# 1                                  143.0 [130.4 , 158.0]
# 2                                   32.96 [29.09, 36.87]
# 3                                      4.34 [2.72, 6.64]
# 4                                      0.72 [0.42, 1.17]
# 5                                      6.46 [5.38, 7.56]
# 6                                      39.0 [27.0, 48.0]
# 7                                       16.0 [7.0, 26.0]
# 8                                       11.0 [4.0, 20.0]
# 9                                         2.0 [0.0, 5.0]
# 10                                        2.0 [0.0, 6.0]
# 11                                        0.0 [0.0, 0.0]
# 12                                    47.6 [39.8 , 56.7]
# 13                                   16.36 [9.99, 23.04]
# 14                                     2.12 [0.99, 3.84]
# 15                                      3.0 [0.89, 6.76]
# 16                                     0.29 [0.09, 0.72]
# 17                                  76.94 [65.94, 84.91]
# 18                                  51.02 [39.87, 61.97]
# 19                                  23.63 [19.59, 27.02]
# 20                                     53.0 [37.0, 66.0]
# 21                                      18.0 [8.0, 31.0]
# 22                                     33.0 [25.0, 46.0]
# 23                                  24.46 [22.71, 27.11]
# 24                                     23.0 [16.0, 31.0]
# 25     3    1864
# 4    1822
# 1    1810
# 5    1781
# 6    1...
# 26                                     30.0 [22.0, 45.0]
# 27                                     6.62 [6.18, 7.14]
# 28     aer    7650
# mix    3305
# ana    1507
# Name: form...
# 29                                   48.63 [43.17, 54.1]
# 30     closed_loop    222
# pump           187
# mdi     ...
# 31     1.0    5915
# 0.0    4888
# 2.0    1659
# Name: inte...
# 32                                                 12462
# 33                                                   496
# 34                                              0.089713
# 35     WHITE                             453
# NOT REPO...
# 36     female    362
# male      134
# Name: sex, dtype: ...
# 37                                 138.2 [110.1 , 175.1]
# 38                                     0.0 [-1.74, 1.56]
# 39     morning      4461
# afternoon    4023
# evening   ...
# 40                                     16.0 [11.0, 24.0]
#
# Study                                              dexip  \
# 0                                      7.96 [7.05, 9.01]
# 1                                  158.2 [139.8 , 180.2]
# 2                                   34.58 [30.79, 39.23]
# 3                                     6.69 [4.12, 10.12]
# 4                                       0.6 [0.27, 0.99]
# 5                                      7.56 [6.08, 9.08]
# 6                                      15.0 [11.0, 20.0]
# 7                                         5.0 [2.0, 9.0]
# 8                                        9.0 [4.0, 13.0]
# 9                                         0.0 [0.0, 2.0]
# 10                                        2.0 [0.0, 4.5]
# 11                                        0.0 [0.0, 0.0]
# 12                                    56.7 [45.6 , 67.9]
# 13                                  20.37 [14.26, 26.16]
# 14                                      1.6 [0.56, 2.91]
# 15                                     7.73 [2.7, 14.89]
# 16                                     0.22 [0.04, 0.62]
# 17                                  68.18 [55.81, 79.16]
# 18                                   44.5 [30.26, 55.44]
# 19                                   22.38 [18.1, 26.14]
# 20                                     24.0 [18.0, 30.0]
# 21                                       6.0 [2.0, 10.0]
# 22                                     14.0 [12.0, 15.0]
# 23                                  20.74 [18.59, 23.61]
# 24                                      11.0 [8.0, 16.0]
# 25     3    507
# 4    463
# 2    460
# 5    451
# 1    439
# 6...
# 26                                     35.0 [20.0, 60.0]
# 27                                     7.15 [6.51, 7.92]
# 28     aer    2287
# mix     684
# ana     166
# Name: form...
# 29                                  53.01 [44.26, 59.56]
# 30     closed_loop    137
# pump            73
# mdi     ...
# 31     0.0    1870
# 1.0     786
# 2.0     322
# nan     15...
# 32                                                  3137
# 33                                                   246
# 34                                              0.107427
# 35     WHITE                             219
# MULTIPLE...
# 36     male      142
# female    104
# Name: sex, dtype: ...
# 37                                 150.1 [114.0 , 200.2]
# 38                                    0.14 [-2.12, 2.13]
# 39     afternoon    1477
# evening       903
# morning   ...
# 40                                      10.0 [7.0, 12.0]
#
# Study                                            ext_101  \
# 0                                      6.51 [5.83, 7.26]
# 1                                  158.5 [142.3 , 177.6]
# 2                                   40.34 [35.88, 46.18]
# 3                                     7.46 [5.29, 11.25]
# 4                                      1.03 [0.58, 2.43]
# 5                                      8.29 [7.46, 9.93]
# 6                                   124.0 [64.75, 198.0]
# 7                                    43.5 [21.75, 81.75]
# 8                                    64.5 [35.25, 130.0]
# 9                                     19.0 [6.25, 45.75]
# 10                                    26.0 [10.25, 40.0]
# 11                                        2.0 [0.0, 8.0]
# 12                                    65.0 [57.1 , 76.2]
# 13                                    21.9 [17.75, 26.7]
# 14                                      3.13 [1.4, 5.83]
# 15                                     9.27 [4.86, 17.9]
# 16                                     1.09 [0.44, 3.96]
# 17                                  60.04 [48.62, 66.36]
# 18                                  37.18 [29.22, 44.62]
# 19                                  20.72 [18.86, 24.44]
# 20                                  210.0 [135.0, 319.5]
# 21                                   72.0 [27.25, 129.5]
# 22                                   45.23 [37.7, 51.08]
# 23                                  23.47 [22.22, 25.17]
# 24                                     10.5 [6.25, 18.0]
# 25     1    76
# 0    71
# 3    70
# 6    67
# 2    67
# 5    6...
# 26                                     55.0 [40.0, 60.0]
# 27                                     7.16 [6.59, 7.83]
# 28     aer    358
# mix     68
# ana     33
# Name: form_of...
# 29                                    57.0 [51.25, 61.0]
# 30     pump    19
# mdi     14
# Name: insulin_modality, ...
# 31     0.0    184
# 1.0    174
# 2.0     90
# nan     11
# Na...
# 32                                                   459
# 33                                                    34
# 34                                              0.095861
# 35                  Series([], Name: race, dtype: int64)
# 36     female    20
# male      14
# Name: sex, dtype: int64
# 37                                 158.5 [118.9 , 218.0]
# 38                                   -0.42 [-2.18, 1.33]
# 39     morning      199
# evening      187
# afternoon   ...
# 40                                  19.11 [10.15, 32.86]
#
# Study                                            ext_edu
# 0                                      9.28 [8.01, 9.96]
# 1                                  185.2 [162.1 , 200.0]
# 2                                   37.84 [34.76, 42.71]
# 3                                    11.54 [7.53, 14.51]
# 4                                      0.65 [0.33, 1.35]
# 5                                      9.35 [8.3, 10.72]
# 6                                      14.5 [8.0, 19.25]
# 7                                        3.0 [2.0, 6.25]
# 8                                      13.0 [8.75, 16.0]
# 9                                         2.0 [0.0, 4.0]
# 10                                       5.0 [2.75, 8.0]
# 11                                        0.0 [0.0, 0.0]
# 12                                    72.1 [62.3 , 85.2]
# 13                                   23.9 [20.04, 29.65]
# 14                                     1.94 [0.77, 3.79]
# 15                                   18.56 [8.92, 27.67]
# 16                                     0.59 [0.13, 2.05]
# 17                                   47.3 [40.19, 61.66]
# 18                                  27.58 [22.02, 37.09]
# 19                                   20.5 [16.72, 25.14]
# 20                                   25.5 [19.75, 34.25]
# 21                                        6.0 [3.0, 9.0]
# 22                                   47.5 [36.25, 56.75]
# 23                                  25.02 [22.81, 29.26]
# 24                                      5.0 [2.25, 11.0]
# 25     3    75
# 2    69
# 4    66
# 1    60
# 6    57
# 0    5...
# 26                                     40.0 [30.0, 60.0]
# 27                                      8.1 [7.29, 8.61]
# 28     aer    358
# ana     55
# mix     19
# Name: form_of...
# 29                                    60.0 [54.0, 65.75]
# 30        mdi    58
# Name: insulin_modality, dtype: int64
# 31     0.0    230
# 1.0    144
# nan     31
# 2.0     27
# Na...
# 32                                                   432
# 33                                                    58
# 34                                              0.118056
# 35                  Series([], Name: race, dtype: int64)
# 36     male      35
# female    23
# Name: sex, dtype: int64
# 37                                 157.5 [120.0 , 213.3]
# 38                                     0.0 [-2.12, 1.55]
# 39     morning      194
# afternoon    121
# evening     ...
# 40                                   13.98 [4.52, 23.31]

# %%
# Save table
ci_table.to_csv('../../results/demographics_table.csv')
