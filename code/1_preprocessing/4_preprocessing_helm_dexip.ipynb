# %% [markdown]
# # 4. Preprocessing JAEB T1-DEXIP dataset

# %% [markdown]
# The goal of this notebook is to prepare the EXTOD education data for machine learning - predicting euglycemia during and around exercise.
#
# EXTOD education was a pilot study in which 106 participants were randomly allocated to either standard care or an education programme teaching them how better to manage blood glucose around exercise.
#
# The data used will be demographic, lab, clinical and physiological if available.
#
# ### Objectives:
# 1. Clean and combine the exercise diaries
# 2. Preprocess demographic data
# 3. Preprcoess lab data
# 4. Prepare CGM data

# %% [markdown]
# ## 4.0. Import packages

# %%
# Import packages and upload dataset
import pandas as pd
import numpy as np
from datetime import timedelta as time
import warnings
import preprocess_helper
import functools as ft
import sys
path = "../../diametrics"
sys.path.append(path)
import visualizations

warnings.filterwarnings('ignore')

# %%
# Set the directory
directory = '../../data/raw_data/helmsley_dexip/'

# %% [markdown]
# ## 4.1. Clean and combine exercise diaries

# %% [markdown]
# ### 4.1.1. Load files and rename columns

# %%
# Read file
exercise = pd.read_csv(directory+'pr.csv')

# %%
exercise
# Out:
#        STUDYID DOMAIN  USUBJID             SPDEVID         PRSEQ  PRGRPID  \
# 0     T1DEXI-P     PR    100.0  GARMIN STUDY WATCH  1.000000e+00        2
# 1     T1DEXI-P     PR    100.0  GARMIN STUDY WATCH  2.000000e+00        2
# 2     T1DEXI-P     PR    100.0  GARMIN STUDY WATCH  3.000000e+00        2
# 3     T1DEXI-P     PR    100.0  GARMIN STUDY WATCH  4.000000e+00        2
# 4     T1DEXI-P     PR    100.0  GARMIN STUDY WATCH  5.000000e+00        2
# ...        ...    ...      ...                 ...           ...      ...
# 6795       NaN    NaN      NaN                 NaN  3.687825e-40        1
# 6796       NaN    NaN      NaN                 NaN  3.687825e-40        1
# 6797       NaN    NaN      NaN                 NaN  3.687825e-40        1
# 6798       NaN    NaN      NaN                 NaN  3.687825e-40        1
# 6799       NaN    NaN      NaN                 NaN  3.687825e-40        1
#
#       PRLNKID    PRTRT PRCAT  PRSCAT          PRSTDTC  \
# 0        1345  RUNNING   NaN     NaN  20210810T153328
# 1        1355  RUNNING   NaN     NaN  20210811T125920
# 2        1354  RUNNING   NaN     NaN  20210811T163558
# 3        1362  RUNNING   NaN     NaN  20210812T124920
# 4        1361  RUNNING   NaN     NaN  20210812T165919
# ...       ...      ...   ...     ...              ...
# 6795        0  Walking   NaN     NaN  20211014T103500
# 6796        0  Walking   NaN     NaN  20211014T103500
# 6797        0  Walking   NaN     NaN  20211014T103500
# 6798        0  Walking   NaN     NaN  20211014T103500
# 6799        0  Walking   NaN     NaN  20211014T103500
#
#                              PREVLINT  PRTRTC  PLNEXDUR             EXCINTSY  \
# 0      20210810T153328/P0Y0M0DT0H7M9S     NaN         0                  NaN
# 1     20210811T125920/P0Y0M0DT0H6M35S     NaN         0                  NaN
# 2      20210811T163558/P0Y0M0DT0H7M7S     NaN         0                  NaN
# 3      20210812T124920/P0Y0M0DT0H7M2S     NaN         0                  NaN
# 4      20210812T165919/P0Y0M0DT0H7M7S     NaN         0                  NaN
# ...                               ...     ...       ...                  ...
# 6795                              NaN     NaN        90  Mild: Working a bit
# 6796                              NaN     NaN        90  Mild: Working a bit
# 6797                              NaN     NaN        90  Mild: Working a bit
# 6798                              NaN     NaN        90  Mild: Working a bit
# 6799                              NaN     NaN        90  Mild: Working a bit
#
#       EXCOMP  ACTWREX  EXMANUAL  PECLFLG  FITCLFLG
# 0        NaN      NaN         0        0         0
# 1        NaN      NaN         0        0         0
# 2        NaN      NaN         0        0         0
# 3        NaN      NaN         0        0         0
# 4        NaN      NaN         0        0         0
# ...      ...      ...       ...      ...       ...
# 6795     0.0      1.0         0        0         0
# 6796     0.0      1.0         0        0         0
# 6797     0.0      1.0         0        0         0
# 6798     0.0      1.0         0        0         0
# 6799     0.0      1.0         0        0         0
#
# [6800 rows x 20 columns]

# %%
# Convert the start time to datetime
exercise['PRSTDTC'] = pd.to_datetime(exercise['PRSTDTC'])

# %%
# Function to extract duration in minutes from PREVLINT
def extract_duration(row):
    if pd.isna(row['PREVLINT']):
        return 0
    duration = row['PREVLINT']

    time = duration.split('/')[1].split('T')[1]
    hours = time.split('H')[0]
    minutes = time.split('H')[1].split('M')[0]
    seconds = time.split('M')[1].split('S')[0]

    return int(hours) * 60 + int(minutes) + int(seconds) / 60

# Apply the function to the DataFrame
exercise['duration_minutes'] = exercise.apply(extract_duration, axis=1)

# %%
exercise['PLNEXDUR'].isnull().any()
# Out:
# False

# %%
# Add duration_minutes to PLNEXDUR where duration_minutes is not NaN
exercise['PLNEXDUR'] = np.where(pd.notna(exercise['duration_minutes']), exercise['PLNEXDUR'] + exercise['duration_minutes'], exercise['PLNEXDUR'])

# %%
# Select and rename columns
exdi = exercise[['USUBJID', 'PRSTDTC', 'PLNEXDUR', 'EXCINTSY', 'PRTRT']] 
exdi.columns = ['ID', 'start_datetime', 'duration', 'intensity', 'type_of_exercise']

# %%
exdi.dropna(subset=['ID'], inplace=True)
# ID as int for concatenation
exdi['ID'] = exdi['ID'].astype(int)

# %%
exdi.shape[0]
# Out:
# 6743

# %%
len(exdi.ID.unique())
# Out:
# 262

# %% [markdown]
# ### 4.1.2. Adjust date columns

# %%
# Calculate end time from start and duration 
exdi['finish_datetime'] = exdi.apply(lambda row: row['start_datetime'] + time(minutes=row['duration']), axis=1)

# %%
# Collect date information from start_datetime
exdi = preprocess_helper.date_preprocessing(exdi, 'start_datetime', False, True, True)

# %%
# Drop any instances with no id, start time or duration
exdi = exdi.dropna(subset=['ID', 'start_datetime', 'duration'])

# %%
exdi.shape[0]
# Out:
# 6743

# %%
exdi = exdi.sort_values(by=['ID', 'start_datetime', 'finish_datetime'])

# %%
# Make sure there's no 0 durations
exdi = exdi.loc[exdi['duration']>0]

# %%
exdi.shape[0]
# Out:
# 6729

# %%
exdi
# Out:
#        ID      start_datetime    duration  \
# 6134    6 2021-02-13 15:07:00   60.000000
# 6135    6 2021-02-14 19:21:00   50.000000
# 6132    6 2021-02-15 17:15:00  115.000000
# 6136    6 2021-02-16 14:00:00   45.000000
# 6137    6 2021-02-18 16:22:56   40.000000
# ...   ...                 ...         ...
# 6062  540 2021-05-21 20:20:00   20.000000
# 6065  540 2021-05-22 07:15:48    7.266667
# 6066  540 2021-05-22 11:10:04   13.916667
# 6067  540 2021-05-22 14:46:52    9.333333
# 6056  540 2021-05-22 16:44:00    7.916667
#
#                                  intensity    type_of_exercise  \
# 6134          Moderate: Working to keep up  Undefined Exercise
# 6135          Moderate: Working to keep up  Undefined Exercise
# 6132                      Low: Pretty easy      Physical Labor
# 6136          Moderate: Working to keep up  Undefined Exercise
# 6137  Heavy: Hard to keep going but did it  Undefined Exercise
# ...                                    ...                 ...
# 6062                   Mild: Working a bit     Running/Jogging
# 6065                                   NaN             WALKING
# 6066                                   NaN             WALKING
# 6067                                   NaN             WALKING
# 6056                                   NaN             RUNNING
#
#          finish_datetime  month  day  day_of_week time_of_day
# 6134 2021-02-13 16:07:00      2   13            5   afternoon
# 6135 2021-02-14 20:11:00      2   14            6     evening
# 6132 2021-02-15 19:10:00      2   15            0     evening
# 6136 2021-02-16 14:45:00      2   16            1   afternoon
# 6137 2021-02-18 17:02:56      2   18            3   afternoon
# ...                  ...    ...  ...          ...         ...
# 6062 2021-05-21 20:40:00      5   21            4     evening
# 6065 2021-05-22 07:23:04      5   22            5     morning
# 6066 2021-05-22 11:23:59      5   22            5     morning
# 6067 2021-05-22 14:56:12      5   22            5   afternoon
# 6056 2021-05-22 16:51:55      5   22            5   afternoon
#
# [6729 rows x 10 columns]

# %% [markdown]
# def handle_overlaps(group):
#     # Sort by start_datetime
#     group = group.sort_values(by='start_datetime')
#
#     non_overlapping = []
#     for _, row in group.iterrows():
#         if non_overlapping:
#             last_interval = non_overlapping[-1]
#             # Check for overlap
#             if row['start_datetime'] < last_interval['finish_datetime']:
#                 curr_duration = (row['finish_datetime'] - row['start_datetime']).seconds / 60
#                 last_duration = (last_interval['finish_datetime'] - last_interval['start_datetime']).seconds / 60
#
#                 # Decide which interval to keep
#                 if (curr_duration >= 10 and curr_duration <= 120) and (last_duration < 10 or last_duration > 120):
#                     non_overlapping[-1] = row
#                 elif (last_duration >= 10 and last_duration <= 120) and (curr_duration < 10 or curr_duration > 120):
#                     continue
#                 elif curr_duration > last_duration:
#                     non_overlapping[-1] = row
#             else:
#                 non_overlapping.append(row)
#         else:
#             non_overlapping.append(row)
#
#     return pd.DataFrame(non_overlapping)
#
# # Apply the function to each group
# exdi = exdi.groupby('ID').apply(handle_overlaps).reset_index(drop=True)

# %%
def handle_overlaps(group):
    # Sort by start_datetime
    group = group.sort_values(by='start_datetime')
    
    non_overlapping = []
    overlap_count = 0  # Counter to limit the number of printed overlaps
    for _, row in group.iterrows():
        if non_overlapping:
            last_interval = non_overlapping[-1]
            # Check for overlap
            if row['start_datetime'] < last_interval['finish_datetime']:
                # Print the overlapping intervals (limited to a few for brevity)
                if overlap_count < 5:
                    print(f"Overlap detected for ID {group['ID'].iloc[0]}:")
                    print(f"Interval 1: {last_interval['start_datetime']} to {last_interval['finish_datetime']}")
                    print(f"Interval 2: {row['start_datetime']} to {row['finish_datetime']}\n")
                    overlap_count += 1

                curr_duration = (row['finish_datetime'] - row['start_datetime']).seconds / 60
                last_duration = (last_interval['finish_datetime'] - last_interval['start_datetime']).seconds / 60
                
                # Decide which interval to keep
                if (curr_duration >= 10 and curr_duration <= 120) and (last_duration < 10 or last_duration > 120):
                    non_overlapping[-1] = row
                elif (last_duration >= 10 and last_duration <= 120) and (curr_duration < 10 or curr_duration > 120):
                    continue
                elif curr_duration > last_duration:
                    non_overlapping[-1] = row
            else:
                non_overlapping.append(row)
        else:
            non_overlapping.append(row)
    
    return pd.DataFrame(non_overlapping)

# Apply the function to each group
exdi = exdi.groupby('ID').apply(handle_overlaps).reset_index(drop=True)
# Out:
# Overlap detected for ID 6:
# Interval 1: 2021-02-18 16:22:56 to 2021-02-18 17:02:56
# Interval 2: 2021-02-18 17:00:00 to 2021-02-18 22:00:00
#
# Overlap detected for ID 6:
# Interval 1: 2021-02-19 11:00:00 to 2021-02-19 17:00:00
# Interval 2: 2021-02-19 11:39:23 to 2021-02-19 11:45:58
#
# Overlap detected for ID 9:
# Interval 1: 2021-11-10 16:11:47 to 2021-11-10 16:56:47
# Interval 2: 2021-11-10 16:18:05 to 2021-11-10 16:25:02
#
# Overlap detected for ID 11:
# Interval 1: 2021-04-02 08:22:00 to 2021-04-02 08:37:00
# Interval 2: 2021-04-02 08:22:58 to 2021-04-02 08:36:11
#
# Overlap detected for ID 11:
# Interval 1: 2021-04-04 15:45:00 to 2021-04-04 16:06:17
# Interval 2: 2021-04-04 15:45:00 to 2021-04-04 16:45:00
#
# Overlap detected for ID 11:
# Interval 1: 2021-04-04 15:45:00 to 2021-04-04 16:45:00
# Interval 2: 2021-04-04 16:13:23 to 2021-04-04 16:21:07
#
# Overlap detected for ID 11:
# Interval 1: 2021-04-06 16:30:00 to 2021-04-06 17:00:00
# Interval 2: 2021-04-06 16:38:36 to 2021-04-06 16:45:08
#
# Overlap detected for ID 11:
# Interval 1: 2021-04-06 16:30:00 to 2021-04-06 17:00:00
# Interval 2: 2021-04-06 16:47:43 to 2021-04-06 16:56:12
#
# Overlap detected for ID 13:
# Interval 1: 2022-01-10 12:45:00 to 2022-01-10 14:00:00
# Interval 2: 2022-01-10 12:51:07 to 2022-01-10 12:58:13
#
# Overlap detected for ID 13:
# Interval 1: 2022-01-15 18:30:00 to 2022-01-15 19:35:00
# Interval 2: 2022-01-15 18:33:52 to 2022-01-15 18:36:14
#
# Overlap detected for ID 13:
# Interval 1: 2022-01-15 18:30:00 to 2022-01-15 19:35:00
# Interval 2: 2022-01-15 18:37:36 to 2022-01-15 18:40:06
#
# Overlap detected for ID 13:
# Interval 1: 2022-01-15 18:30:00 to 2022-01-15 19:35:00
# Interval 2: 2022-01-15 19:16:55 to 2022-01-15 19:19:40
#
# Overlap detected for ID 16:
# Interval 1: 2022-03-19 15:30:00 to 2022-03-19 16:30:00
# Interval 2: 2022-03-19 15:36:50 to 2022-03-19 15:39:38
#
# Overlap detected for ID 16:
# Interval 1: 2022-03-19 15:30:00 to 2022-03-19 16:30:00
# Interval 2: 2022-03-19 15:53:26 to 2022-03-19 15:56:41
#
# Overlap detected for ID 16:
# Interval 1: 2022-03-19 15:30:00 to 2022-03-19 16:30:00
# Interval 2: 2022-03-19 15:57:30 to 2022-03-19 16:00:17
#
# Overlap detected for ID 16:
# Interval 1: 2022-03-19 15:30:00 to 2022-03-19 16:30:00
# Interval 2: 2022-03-19 16:10:40 to 2022-03-19 16:16:31
#
# Overlap detected for ID 16:
# Interval 1: 2022-03-20 15:25:00 to 2022-03-20 16:40:00
# Interval 2: 2022-03-20 16:16:26 to 2022-03-20 16:22:33
#
# Overlap detected for ID 18:
# Interval 1: 2021-08-01 09:40:00 to 2021-08-01 11:00:00
# Interval 2: 2021-08-01 09:51:44 to 2021-08-01 10:00:17
#
# Overlap detected for ID 18:
# Interval 1: 2021-08-01 09:40:00 to 2021-08-01 11:00:00
# Interval 2: 2021-08-01 10:23:20 to 2021-08-01 10:39:41
#
# Overlap detected for ID 18:
# Interval 1: 2021-08-01 18:35:00 to 2021-08-01 18:55:00
# Interval 2: 2021-08-01 18:51:58 to 2021-08-01 18:58:11
#
# Overlap detected for ID 18:
# Interval 1: 2021-08-07 16:00:00 to 2021-08-07 16:45:00
# Interval 2: 2021-08-07 16:34:45 to 2021-08-07 16:41:28
#
# Overlap detected for ID 19:
# Interval 1: 2021-10-02 12:56:00 to 2021-10-02 13:51:00
# Interval 2: 2021-10-02 13:12:34 to 2021-10-02 13:14:33
#
# Overlap detected for ID 23:
# Interval 1: 2021-10-08 15:08:47 to 2021-10-08 16:13:47
# Interval 2: 2021-10-08 15:15:56 to 2021-10-08 15:26:49
#
# Overlap detected for ID 23:
# Interval 1: 2021-10-08 15:08:47 to 2021-10-08 16:13:47
# Interval 2: 2021-10-08 16:10:11 to 2021-10-08 16:19:35
#
# Overlap detected for ID 23:
# Interval 1: 2021-10-10 20:27:00 to 2021-10-10 21:07:00
# Interval 2: 2021-10-10 20:29:54 to 2021-10-10 21:01:17
#
# Overlap detected for ID 23:
# Interval 1: 2021-10-11 21:40:45 to 2021-10-11 21:55:41
# Interval 2: 2021-10-11 21:41:42 to 2021-10-11 22:11:42
#
# Overlap detected for ID 23:
# Interval 1: 2021-10-14 20:15:00 to 2021-10-14 21:30:00
# Interval 2: 2021-10-14 20:34:08 to 2021-10-14 20:43:37
#
# Overlap detected for ID 24:
# Interval 1: 2020-12-18 17:50:43 to 2020-12-18 18:05:43
# Interval 2: 2020-12-18 18:00:23 to 2020-12-18 18:08:09
#
# Overlap detected for ID 24:
# Interval 1: 2020-12-19 10:30:15 to 2020-12-19 11:45:15
# Interval 2: 2020-12-19 10:36:33 to 2020-12-19 11:26:17
#
# Overlap detected for ID 24:
# Interval 1: 2020-12-19 10:30:15 to 2020-12-19 11:45:15
# Interval 2: 2020-12-19 11:26:25 to 2020-12-19 11:45:13
#
# Overlap detected for ID 24:
# Interval 1: 2020-12-20 13:39:40 to 2020-12-20 14:24:40
# Interval 2: 2020-12-20 13:48:19 to 2020-12-20 14:32:54
#
# Overlap detected for ID 24:
# Interval 1: 2020-12-20 16:39:28 to 2020-12-20 18:00:53
# Interval 2: 2020-12-20 16:40:00 to 2020-12-20 17:50:00
#
# Overlap detected for ID 25:
# Interval 1: 2021-01-30 10:37:00 to 2021-01-30 11:37:00
# Interval 2: 2021-01-30 10:54:22 to 2021-01-30 11:15:52
#
# Overlap detected for ID 25:
# Interval 1: 2021-02-01 11:46:00 to 2021-02-01 11:56:00
# Interval 2: 2021-02-01 11:46:05 to 2021-02-01 11:52:42
#
# Overlap detected for ID 25:
# Interval 1: 2021-02-02 14:00:00 to 2021-02-02 15:00:00
# Interval 2: 2021-02-02 14:16:06 to 2021-02-02 14:27:27
#
# Overlap detected for ID 25:
# Interval 1: 2021-02-02 14:00:00 to 2021-02-02 15:00:00
# Interval 2: 2021-02-02 14:34:59 to 2021-02-02 14:48:14
#
# Overlap detected for ID 25:
# Interval 1: 2021-02-04 15:31:50 to 2021-02-04 16:06:50
# Interval 2: 2021-02-04 15:47:37 to 2021-02-04 15:56:43
#
# Overlap detected for ID 26:
# Interval 1: 2021-06-18 08:10:00 to 2021-06-18 08:40:00
# Interval 2: 2021-06-18 08:33:55 to 2021-06-18 08:40:59
#
# Overlap detected for ID 29:
# Interval 1: 2022-02-26 18:00:00 to 2022-02-26 20:00:00
# Interval 2: 2022-02-26 18:02:44 to 2022-02-26 18:05:19
#
# Overlap detected for ID 29:
# Interval 1: 2022-03-05 18:00:00 to 2022-03-05 20:00:00
# Interval 2: 2022-03-05 18:08:13 to 2022-03-05 18:09:43
#
# Overlap detected for ID 29:
# Interval 1: 2022-03-07 17:00:00 to 2022-03-07 20:30:00
# Interval 2: 2022-03-07 17:07:03 to 2022-03-07 17:10:50
#
# Overlap detected for ID 29:
# Interval 1: 2022-03-07 17:00:00 to 2022-03-07 20:30:00
# Interval 2: 2022-03-07 19:34:20 to 2022-03-07 19:35:58
#
# Overlap detected for ID 33:
# Interval 1: 2022-04-04 15:20:00 to 2022-04-04 17:20:00
# Interval 2: 2022-04-04 16:52:51 to 2022-04-04 16:56:15
#
# Overlap detected for ID 34:
# Interval 1: 2020-12-11 17:23:00 to 2020-12-11 17:38:00
# Interval 2: 2020-12-11 17:23:57 to 2020-12-11 17:36:57
#
# Overlap detected for ID 35:
# Interval 1: 2021-11-13 09:00:00 to 2021-11-13 10:45:00
# Interval 2: 2021-11-13 10:32:40 to 2021-11-13 10:38:58
#
# Overlap detected for ID 35:
# Interval 1: 2021-11-14 17:55:00 to 2021-11-14 19:10:00
# Interval 2: 2021-11-14 18:17:46 to 2021-11-14 18:31:20
#
# Overlap detected for ID 35:
# Interval 1: 2021-11-14 17:55:00 to 2021-11-14 19:10:00
# Interval 2: 2021-11-14 18:33:18 to 2021-11-14 18:42:40
#
# Overlap detected for ID 35:
# Interval 1: 2021-11-14 17:55:00 to 2021-11-14 19:10:00
# Interval 2: 2021-11-14 18:48:40 to 2021-11-14 18:55:26
#
# Overlap detected for ID 37:
# Interval 1: 2022-01-13 08:50:00 to 2022-01-13 09:20:00
# Interval 2: 2022-01-13 09:12:52 to 2022-01-13 09:57:16
#
# Overlap detected for ID 37:
# Interval 1: 2022-01-13 15:00:00 to 2022-01-13 17:00:00
# Interval 2: 2022-01-13 15:20:20 to 2022-01-13 15:22:36
#
# Overlap detected for ID 37:
# Interval 1: 2022-01-13 15:00:00 to 2022-01-13 17:00:00
# Interval 2: 2022-01-13 15:24:14 to 2022-01-13 15:27:12
#
# Overlap detected for ID 37:
# Interval 1: 2022-01-13 15:00:00 to 2022-01-13 17:00:00
# Interval 2: 2022-01-13 15:30:43 to 2022-01-13 15:50:43
#
# Overlap detected for ID 37:
# Interval 1: 2022-01-13 15:00:00 to 2022-01-13 17:00:00
# Interval 2: 2022-01-13 15:51:00 to 2022-01-13 16:53:07
#
# Overlap detected for ID 40:
# Interval 1: 2021-08-08 09:06:00 to 2021-08-08 09:21:00
# Interval 2: 2021-08-08 09:08:32 to 2021-08-08 09:26:11
#
# Overlap detected for ID 40:
# Interval 1: 2021-08-08 14:55:00 to 2021-08-08 15:10:00
# Interval 2: 2021-08-08 14:55:02 to 2021-08-08 15:14:12
#
# Overlap detected for ID 40:
# Interval 1: 2021-08-08 16:15:00 to 2021-08-08 16:35:00
# Interval 2: 2021-08-08 16:17:09 to 2021-08-08 16:36:43
#
# Overlap detected for ID 40:
# Interval 1: 2021-08-10 09:45:00 to 2021-08-10 10:05:00
# Interval 2: 2021-08-10 09:51:49 to 2021-08-10 10:12:07
#
# Overlap detected for ID 40:
# Interval 1: 2021-08-11 08:00:00 to 2021-08-11 08:10:00
# Interval 2: 2021-08-11 08:04:56 to 2021-08-11 08:14:08
#
# Overlap detected for ID 44:
# Interval 1: 2021-06-08 15:30:00 to 2021-06-08 17:00:00
# Interval 2: 2021-06-08 15:42:31 to 2021-06-08 15:47:49
#
# Overlap detected for ID 44:
# Interval 1: 2021-06-08 15:30:00 to 2021-06-08 17:00:00
# Interval 2: 2021-06-08 15:52:04 to 2021-06-08 15:55:10
#
# Overlap detected for ID 46:
# Interval 1: 2021-10-24 08:55:00 to 2021-10-24 09:25:00
# Interval 2: 2021-10-24 09:14:11 to 2021-10-24 09:20:06
#
# Overlap detected for ID 46:
# Interval 1: 2021-10-27 08:55:00 to 2021-10-27 09:25:00
# Interval 2: 2021-10-27 09:05:46 to 2021-10-27 09:08:25
#
# Overlap detected for ID 46:
# Interval 1: 2021-10-27 08:55:00 to 2021-10-27 09:25:00
# Interval 2: 2021-10-27 09:16:00 to 2021-10-27 09:18:22
#
# Overlap detected for ID 47:
# Interval 1: 2021-09-18 16:30:00 to 2021-09-18 18:15:00
# Interval 2: 2021-09-18 17:32:49 to 2021-09-18 17:44:51
#
# Overlap detected for ID 47:
# Interval 1: 2021-09-18 16:30:00 to 2021-09-18 18:15:00
# Interval 2: 2021-09-18 17:46:46 to 2021-09-18 17:54:52
#
# Overlap detected for ID 47:
# Interval 1: 2021-09-21 18:30:00 to 2021-09-21 20:00:00
# Interval 2: 2021-09-21 19:54:09 to 2021-09-21 20:05:32
#
# Overlap detected for ID 47:
# Interval 1: 2021-09-22 19:30:00 to 2021-09-22 20:15:00
# Interval 2: 2021-09-22 19:37:30 to 2021-09-22 20:06:36
#
# Overlap detected for ID 47:
# Interval 1: 2021-09-22 19:30:00 to 2021-09-22 20:15:00
# Interval 2: 2021-09-22 20:07:57 to 2021-09-22 20:21:00
#
# Overlap detected for ID 55:
# Interval 1: 2021-11-06 15:31:00 to 2021-11-06 17:01:00
# Interval 2: 2021-11-06 16:07:58 to 2021-11-06 16:18:26
#
# Overlap detected for ID 55:
# Interval 1: 2021-11-06 15:31:00 to 2021-11-06 17:01:00
# Interval 2: 2021-11-06 16:31:07 to 2021-11-06 16:43:21
#
# Overlap detected for ID 58:
# Interval 1: 2022-02-14 13:28:20 to 2022-02-14 13:39:25
# Interval 2: 2022-02-14 13:30:00 to 2022-02-14 13:40:00
#
# Overlap detected for ID 58:
# Interval 1: 2022-02-14 17:42:50 to 2022-02-14 18:41:43
# Interval 2: 2022-02-14 17:45:00 to 2022-02-14 18:15:00
#
# Overlap detected for ID 58:
# Interval 1: 2022-02-15 15:00:00 to 2022-02-15 15:30:00
# Interval 2: 2022-02-15 15:03:02 to 2022-02-15 15:08:54
#
# Overlap detected for ID 58:
# Interval 1: 2022-02-16 13:40:00 to 2022-02-16 14:25:00
# Interval 2: 2022-02-16 14:01:31 to 2022-02-16 14:03:19
#
# Overlap detected for ID 58:
# Interval 1: 2022-02-23 13:45:00 to 2022-02-23 14:30:00
# Interval 2: 2022-02-23 13:54:10 to 2022-02-23 13:56:52
#
# Overlap detected for ID 63:
# Interval 1: 2022-07-03 14:26:23 to 2022-07-03 14:33:45
# Interval 2: 2022-07-03 14:30:00 to 2022-07-03 14:50:00
#
# Overlap detected for ID 63:
# Interval 1: 2022-07-03 15:00:00 to 2022-07-03 17:00:00
# Interval 2: 2022-07-03 15:29:10 to 2022-07-03 15:37:45
#
# Overlap detected for ID 63:
# Interval 1: 2022-07-04 15:00:00 to 2022-07-04 17:00:00
# Interval 2: 2022-07-04 15:44:56 to 2022-07-04 15:55:11
#
# Overlap detected for ID 63:
# Interval 1: 2022-07-04 15:00:00 to 2022-07-04 17:00:00
# Interval 2: 2022-07-04 16:03:04 to 2022-07-04 16:10:30
#
# Overlap detected for ID 63:
# Interval 1: 2022-07-07 14:20:00 to 2022-07-07 16:30:00
# Interval 2: 2022-07-07 15:44:05 to 2022-07-07 16:00:49
#
# Overlap detected for ID 65:
# Interval 1: 2021-06-15 14:45:00 to 2021-06-15 15:00:00
# Interval 2: 2021-06-15 14:55:01 to 2021-06-15 14:57:41
#
# Overlap detected for ID 65:
# Interval 1: 2021-06-20 07:00:00 to 2021-06-20 07:25:00
# Interval 2: 2021-06-20 07:13:00 to 2021-06-20 07:20:01
#
# Overlap detected for ID 65:
# Interval 1: 2021-06-20 17:30:00 to 2021-06-20 18:50:00
# Interval 2: 2021-06-20 17:51:24 to 2021-06-20 17:54:04
#
# Overlap detected for ID 68:
# Interval 1: 2021-10-30 12:35:00 to 2021-10-30 12:50:00
# Interval 2: 2021-10-30 12:48:39 to 2021-10-30 12:56:33
#
# Overlap detected for ID 68:
# Interval 1: 2021-11-02 13:04:51 to 2021-11-02 13:08:56
# Interval 2: 2021-11-02 13:05:00 to 2021-11-02 13:15:00
#
# Overlap detected for ID 69:
# Interval 1: 2022-05-13 13:15:00 to 2022-05-13 14:00:00
# Interval 2: 2022-05-13 13:47:10 to 2022-05-13 13:55:22
#
# Overlap detected for ID 71:
# Interval 1: 2021-08-09 10:19:00 to 2021-08-09 10:34:00
# Interval 2: 2021-08-09 10:29:53 to 2021-08-09 10:31:56
#
# Overlap detected for ID 71:
# Interval 1: 2021-08-24 11:17:00 to 2021-08-24 12:07:00
# Interval 2: 2021-08-24 11:17:55 to 2021-08-24 12:08:04
#
# Overlap detected for ID 71:
# Interval 1: 2021-08-24 12:51:00 to 2021-08-24 13:26:00
# Interval 2: 2021-08-24 12:51:22 to 2021-08-24 13:26:53
#
# Overlap detected for ID 71:
# Interval 1: 2021-08-25 10:30:00 to 2021-08-25 12:30:00
# Interval 2: 2021-08-25 11:19:41 to 2021-08-25 11:50:00
#
# Overlap detected for ID 71:
# Interval 1: 2021-08-25 12:30:00 to 2021-08-25 14:00:00
# Interval 2: 2021-08-25 13:59:18 to 2021-08-25 14:16:38
#
# Overlap detected for ID 73:
# Interval 1: 2022-05-30 15:05:00 to 2022-05-30 15:35:00
# Interval 2: 2022-05-30 15:29:57 to 2022-05-30 15:36:48
#
# Overlap detected for ID 75:
# Interval 1: 2021-10-17 12:10:00 to 2021-10-17 13:45:00
# Interval 2: 2021-10-17 12:10:00 to 2021-10-17 13:45:00
#
# Overlap detected for ID 75:
# Interval 1: 2021-10-21 12:50:00 to 2021-10-21 13:25:00
# Interval 2: 2021-10-21 13:04:05 to 2021-10-21 13:13:18
#
# Overlap detected for ID 76:
# Interval 1: 2022-01-31 15:30:00 to 2022-01-31 15:50:00
# Interval 2: 2022-01-31 15:36:15 to 2022-01-31 15:44:58
#
# Overlap detected for ID 76:
# Interval 1: 2022-01-31 15:59:55 to 2022-01-31 16:22:22
# Interval 2: 2022-01-31 16:00:00 to 2022-01-31 16:20:00
#
# Overlap detected for ID 76:
# Interval 1: 2022-02-01 15:09:04 to 2022-02-01 15:35:09
# Interval 2: 2022-02-01 15:10:00 to 2022-02-01 15:40:00
#
# Overlap detected for ID 76:
# Interval 1: 2022-02-02 09:40:00 to 2022-02-02 10:40:00
# Interval 2: 2022-02-02 09:48:29 to 2022-02-02 09:58:20
#
# Overlap detected for ID 76:
# Interval 1: 2022-02-02 09:40:00 to 2022-02-02 10:40:00
# Interval 2: 2022-02-02 09:58:49 to 2022-02-02 10:18:43
#
# Overlap detected for ID 80:
# Interval 1: 2022-03-17 17:00:00 to 2022-03-17 17:15:00
# Interval 2: 2022-03-17 17:06:07 to 2022-03-17 17:20:14
#
# Overlap detected for ID 83:
# Interval 1: 2022-07-07 19:07:00 to 2022-07-07 19:32:00
# Interval 2: 2022-07-07 19:13:29 to 2022-07-07 19:19:27
#
# Overlap detected for ID 84:
# Interval 1: 2022-04-28 08:00:00 to 2022-04-28 08:20:00
# Interval 2: 2022-04-28 08:09:22 to 2022-04-28 08:19:34
#
# Overlap detected for ID 84:
# Interval 1: 2022-04-28 15:58:15 to 2022-04-28 16:00:13
# Interval 2: 2022-04-28 16:00:00 to 2022-04-28 17:00:00
#
# Overlap detected for ID 84:
# Interval 1: 2022-04-28 16:00:00 to 2022-04-28 17:00:00
# Interval 2: 2022-04-28 16:15:04 to 2022-04-28 16:17:19
#
# Overlap detected for ID 84:
# Interval 1: 2022-04-29 16:15:00 to 2022-04-29 18:15:00
# Interval 2: 2022-04-29 16:20:41 to 2022-04-29 16:23:35
#
# Overlap detected for ID 84:
# Interval 1: 2022-04-30 16:00:00 to 2022-04-30 17:00:00
# Interval 2: 2022-04-30 16:02:58 to 2022-04-30 16:05:21
#
# Overlap detected for ID 88:
# Interval 1: 2021-07-27 07:25:00 to 2021-07-27 08:35:00
# Interval 2: 2021-07-27 07:44:16 to 2021-07-27 07:54:44
#
# Overlap detected for ID 88:
# Interval 1: 2021-07-28 07:00:00 to 2021-07-28 08:35:00
# Interval 2: 2021-07-28 07:27:24 to 2021-07-28 07:32:00
#
# Overlap detected for ID 88:
# Interval 1: 2021-07-28 16:10:00 to 2021-07-28 17:15:00
# Interval 2: 2021-07-28 17:06:39 to 2021-07-28 17:17:32
#
# Overlap detected for ID 88:
# Interval 1: 2021-07-29 07:01:00 to 2021-07-29 08:31:00
# Interval 2: 2021-07-29 07:25:13 to 2021-07-29 07:30:13
#
# Overlap detected for ID 88:
# Interval 1: 2021-07-31 14:15:03 to 2021-07-31 14:36:36
# Interval 2: 2021-07-31 14:20:00 to 2021-07-31 15:50:00
#
# Overlap detected for ID 91:
# Interval 1: 2021-08-18 18:37:00 to 2021-08-18 18:57:00
# Interval 2: 2021-08-18 18:37:15 to 2021-08-18 19:00:27
#
# Overlap detected for ID 91:
# Interval 1: 2021-08-22 20:58:00 to 2021-08-22 21:13:00
# Interval 2: 2021-08-22 21:00:58 to 2021-08-22 21:13:42
#
# Overlap detected for ID 92:
# Interval 1: 2022-09-09 14:15:00 to 2022-09-09 14:45:00
# Interval 2: 2022-09-09 14:17:57 to 2022-09-09 14:20:16
#
# Overlap detected for ID 94:
# Interval 1: 2022-04-26 16:00:00 to 2022-04-26 16:25:00
# Interval 2: 2022-04-26 16:04:31 to 2022-04-26 16:13:13
#
# Overlap detected for ID 94:
# Interval 1: 2022-04-26 19:30:00 to 2022-04-26 19:50:00
# Interval 2: 2022-04-26 19:33:45 to 2022-04-26 19:41:04
#
# Overlap detected for ID 94:
# Interval 1: 2022-05-04 13:40:00 to 2022-05-04 14:10:00
# Interval 2: 2022-05-04 13:53:11 to 2022-05-04 14:10:11
#
# Overlap detected for ID 100:
# Interval 1: 2021-08-10 15:32:22 to 2021-08-10 15:47:22
# Interval 2: 2021-08-10 15:33:28 to 2021-08-10 15:40:37
#
# Overlap detected for ID 100:
# Interval 1: 2021-08-11 12:58:00 to 2021-08-11 13:13:00
# Interval 2: 2021-08-11 12:59:20 to 2021-08-11 13:05:55
#
# Overlap detected for ID 100:
# Interval 1: 2021-08-11 16:35:00 to 2021-08-11 16:50:00
# Interval 2: 2021-08-11 16:35:58 to 2021-08-11 16:43:05
#
# Overlap detected for ID 100:
# Interval 1: 2021-08-12 12:49:00 to 2021-08-12 13:04:00
# Interval 2: 2021-08-12 12:49:20 to 2021-08-12 12:56:22
#
# Overlap detected for ID 100:
# Interval 1: 2021-08-12 16:48:00 to 2021-08-12 17:03:00
# Interval 2: 2021-08-12 16:59:19 to 2021-08-12 17:06:26
#
# Overlap detected for ID 102:
# Interval 1: 2021-09-08 10:45:00 to 2021-09-08 11:10:00
# Interval 2: 2021-09-08 10:54:34 to 2021-09-08 11:08:40
#
# Overlap detected for ID 102:
# Interval 1: 2021-09-10 15:30:00 to 2021-09-10 16:15:00
# Interval 2: 2021-09-10 15:58:42 to 2021-09-10 16:04:49
#
# Overlap detected for ID 103:
# Interval 1: 2021-06-25 15:40:00 to 2021-06-25 17:40:00
# Interval 2: 2021-06-25 15:43:05 to 2021-06-25 15:55:11
#
# Overlap detected for ID 103:
# Interval 1: 2021-06-30 11:25:00 to 2021-06-30 11:50:00
# Interval 2: 2021-06-30 11:29:38 to 2021-06-30 11:41:17
#
# Overlap detected for ID 105:
# Interval 1: 2021-05-24 10:30:00 to 2021-05-24 11:30:00
# Interval 2: 2021-05-24 10:43:49 to 2021-05-24 10:57:01
#
# Overlap detected for ID 105:
# Interval 1: 2021-05-27 07:15:00 to 2021-05-27 07:30:00
# Interval 2: 2021-05-27 07:19:14 to 2021-05-27 07:30:02
#
# Overlap detected for ID 105:
# Interval 1: 2021-05-27 14:45:00 to 2021-05-27 15:45:00
# Interval 2: 2021-05-27 15:34:01 to 2021-05-27 15:36:30
#
# Overlap detected for ID 105:
# Interval 1: 2021-05-29 07:15:00 to 2021-05-29 07:30:00
# Interval 2: 2021-05-29 07:20:41 to 2021-05-29 07:29:55
#
# Overlap detected for ID 107:
# Interval 1: 2021-07-24 14:00:00 to 2021-07-24 14:30:00
# Interval 2: 2021-07-24 14:15:08 to 2021-07-24 14:24:45
#
# Overlap detected for ID 113:
# Interval 1: 2022-01-18 16:10:00 to 2022-01-18 16:35:00
# Interval 2: 2022-01-18 16:11:00 to 2022-01-18 16:17:08
#
# Overlap detected for ID 114:
# Interval 1: 2021-03-09 11:45:00 to 2021-03-09 13:15:00
# Interval 2: 2021-03-09 12:17:54 to 2021-03-09 12:26:46
#
# Overlap detected for ID 114:
# Interval 1: 2021-03-09 16:15:00 to 2021-03-09 17:00:00
# Interval 2: 2021-03-09 16:28:47 to 2021-03-09 16:49:41
#
# Overlap detected for ID 114:
# Interval 1: 2021-03-15 15:40:00 to 2021-03-15 17:40:00
# Interval 2: 2021-03-15 16:16:35 to 2021-03-15 16:29:44
#
# Overlap detected for ID 114:
# Interval 1: 2021-03-16 15:37:00 to 2021-03-16 17:37:00
# Interval 2: 2021-03-16 15:57:27 to 2021-03-16 16:02:31
#
# Overlap detected for ID 114:
# Interval 1: 2021-03-16 15:37:00 to 2021-03-16 17:37:00
# Interval 2: 2021-03-16 16:41:25 to 2021-03-16 16:57:04
#
# Overlap detected for ID 119:
# Interval 1: 2021-05-07 16:20:00 to 2021-05-07 16:50:00
# Interval 2: 2021-05-07 16:43:13 to 2021-05-07 16:49:31
#
# Overlap detected for ID 119:
# Interval 1: 2021-05-08 11:45:00 to 2021-05-08 12:15:00
# Interval 2: 2021-05-08 11:45:58 to 2021-05-08 12:06:51
#
# Overlap detected for ID 119:
# Interval 1: 2021-05-16 11:11:00 to 2021-05-16 11:21:00
# Interval 2: 2021-05-16 11:11:53 to 2021-05-16 11:23:43
#
# Overlap detected for ID 119:
# Interval 1: 2021-05-16 11:55:00 to 2021-05-16 12:10:00
# Interval 2: 2021-05-16 11:55:29 to 2021-05-16 12:12:10
#
# Overlap detected for ID 119:
# Interval 1: 2021-05-16 12:33:00 to 2021-05-16 12:43:00
# Interval 2: 2021-05-16 12:33:06 to 2021-05-16 12:45:19
#
# Overlap detected for ID 122:
# Interval 1: 2021-10-20 17:04:00 to 2021-10-20 18:44:00
# Interval 2: 2021-10-20 18:34:08 to 2021-10-20 18:43:44
#
# Overlap detected for ID 128:
# Interval 1: 2021-06-03 10:08:34 to 2021-06-03 10:51:47
# Interval 2: 2021-06-03 10:10:00 to 2021-06-03 11:00:00
#
# Overlap detected for ID 128:
# Interval 1: 2021-06-03 12:00:00 to 2021-06-03 13:30:00
# Interval 2: 2021-06-03 12:21:49 to 2021-06-03 12:34:43
#
# Overlap detected for ID 131:
# Interval 1: 2021-08-26 21:40:00 to 2021-08-26 22:10:00
# Interval 2: 2021-08-26 21:44:58 to 2021-08-26 22:06:58
#
# Overlap detected for ID 131:
# Interval 1: 2021-08-28 15:17:00 to 2021-08-28 15:37:00
# Interval 2: 2021-08-28 15:28:32 to 2021-08-28 15:48:31
#
# Overlap detected for ID 133:
# Interval 1: 2021-12-02 15:16:03 to 2021-12-02 15:23:18
# Interval 2: 2021-12-02 15:16:49 to 2021-12-02 15:31:49
#
# Overlap detected for ID 133:
# Interval 1: 2021-12-05 14:40:00 to 2021-12-05 15:00:00
# Interval 2: 2021-12-05 14:42:41 to 2021-12-05 15:10:16
#
# Overlap detected for ID 133:
# Interval 1: 2021-12-09 14:30:00 to 2021-12-09 15:00:00
# Interval 2: 2021-12-09 14:50:29 to 2021-12-09 14:57:26
#
# Overlap detected for ID 133:
# Interval 1: 2021-12-10 08:04:53 to 2021-12-10 08:33:35
# Interval 2: 2021-12-10 08:06:00 to 2021-12-10 08:26:00
#
# Overlap detected for ID 133:
# Interval 1: 2021-12-11 07:51:50 to 2021-12-11 08:11:50
# Interval 2: 2021-12-11 07:55:08 to 2021-12-11 08:16:29
#
# Overlap detected for ID 136:
# Interval 1: 2021-09-17 06:49:28 to 2021-09-17 06:58:22
# Interval 2: 2021-09-17 06:50:00 to 2021-09-17 07:00:00
#
# Overlap detected for ID 136:
# Interval 1: 2021-09-17 13:30:00 to 2021-09-17 16:40:00
# Interval 2: 2021-09-17 15:43:27 to 2021-09-17 15:45:20
#
# Overlap detected for ID 136:
# Interval 1: 2021-09-17 13:30:00 to 2021-09-17 16:40:00
# Interval 2: 2021-09-17 16:26:41 to 2021-09-17 16:34:59
#
# Overlap detected for ID 136:
# Interval 1: 2021-09-19 10:00:00 to 2021-09-19 10:15:00
# Interval 2: 2021-09-19 10:08:18 to 2021-09-19 10:16:01
#
# Overlap detected for ID 136:
# Interval 1: 2021-09-21 14:00:00 to 2021-09-21 14:15:00
# Interval 2: 2021-09-21 14:07:43 to 2021-09-21 14:18:07
#
# Overlap detected for ID 140:
# Interval 1: 2021-09-28 15:00:00 to 2021-09-28 17:00:00
# Interval 2: 2021-09-28 15:33:01 to 2021-09-28 15:35:01
#
# Overlap detected for ID 141:
# Interval 1: 2021-09-03 07:41:00 to 2021-09-03 08:26:00
# Interval 2: 2021-09-03 08:00:40 to 2021-09-03 08:17:40
#
# Overlap detected for ID 141:
# Interval 1: 2021-09-04 18:09:00 to 2021-09-04 18:39:00
# Interval 2: 2021-09-04 18:11:58 to 2021-09-04 18:31:34
#
# Overlap detected for ID 141:
# Interval 1: 2021-09-05 14:18:00 to 2021-09-05 15:18:00
# Interval 2: 2021-09-05 14:19:41 to 2021-09-05 14:30:35
#
# Overlap detected for ID 141:
# Interval 1: 2021-09-06 17:40:00 to 2021-09-06 18:40:00
# Interval 2: 2021-09-06 17:41:11 to 2021-09-06 17:49:17
#
# Overlap detected for ID 141:
# Interval 1: 2021-09-08 08:00:00 to 2021-09-08 08:45:00
# Interval 2: 2021-09-08 08:44:51 to 2021-09-08 08:54:52
#
# Overlap detected for ID 147:
# Interval 1: 2021-09-21 15:50:00 to 2021-09-21 16:20:00
# Interval 2: 2021-09-21 16:03:15 to 2021-09-21 16:08:26
#
# Overlap detected for ID 147:
# Interval 1: 2021-09-21 15:50:00 to 2021-09-21 16:20:00
# Interval 2: 2021-09-21 16:08:59 to 2021-09-21 16:17:33
#
# Overlap detected for ID 150:
# Interval 1: 2021-11-27 08:05:00 to 2021-11-27 09:15:00
# Interval 2: 2021-11-27 08:19:01 to 2021-11-27 08:25:37
#
# Overlap detected for ID 153:
# Interval 1: 2021-02-13 15:11:00 to 2021-02-13 17:11:00
# Interval 2: 2021-02-13 15:27:17 to 2021-02-13 15:29:13
#
# Overlap detected for ID 153:
# Interval 1: 2021-02-15 15:31:00 to 2021-02-15 17:31:00
# Interval 2: 2021-02-15 15:35:44 to 2021-02-15 15:39:12
#
# Overlap detected for ID 153:
# Interval 1: 2021-02-16 15:19:00 to 2021-02-16 17:19:00
# Interval 2: 2021-02-16 16:39:11 to 2021-02-16 16:41:44
#
# Overlap detected for ID 154:
# Interval 1: 2021-06-02 13:00:00 to 2021-06-02 14:40:00
# Interval 2: 2021-06-02 13:06:08 to 2021-06-02 13:09:55
#
# Overlap detected for ID 154:
# Interval 1: 2021-06-02 18:00:00 to 2021-06-02 20:00:00
# Interval 2: 2021-06-02 18:00:02 to 2021-06-02 18:09:20
#
# Overlap detected for ID 154:
# Interval 1: 2021-06-02 18:00:00 to 2021-06-02 20:00:00
# Interval 2: 2021-06-02 19:54:55 to 2021-06-02 19:59:26
#
# Overlap detected for ID 165:
# Interval 1: 2021-07-05 08:43:00 to 2021-07-05 09:18:00
# Interval 2: 2021-07-05 08:59:09 to 2021-07-05 09:17:28
#
# Overlap detected for ID 165:
# Interval 1: 2021-07-05 12:00:00 to 2021-07-05 12:20:00
# Interval 2: 2021-07-05 12:07:49 to 2021-07-05 12:29:02
#
# Overlap detected for ID 165:
# Interval 1: 2021-07-10 14:51:00 to 2021-07-10 15:06:00
# Interval 2: 2021-07-10 14:53:27 to 2021-07-10 14:55:13
#
# Overlap detected for ID 165:
# Interval 1: 2021-07-10 14:51:00 to 2021-07-10 15:06:00
# Interval 2: 2021-07-10 14:59:50 to 2021-07-10 15:06:44
#
# Overlap detected for ID 167:
# Interval 1: 2021-03-23 13:30:00 to 2021-03-23 15:15:00
# Interval 2: 2021-03-23 13:33:00 to 2021-03-23 13:39:41
#
# Overlap detected for ID 167:
# Interval 1: 2021-03-23 13:30:00 to 2021-03-23 15:15:00
# Interval 2: 2021-03-23 13:41:53 to 2021-03-23 13:52:31
#
# Overlap detected for ID 167:
# Interval 1: 2021-03-23 13:30:00 to 2021-03-23 15:15:00
# Interval 2: 2021-03-23 14:24:01 to 2021-03-23 14:39:37
#
# Overlap detected for ID 167:
# Interval 1: 2021-03-23 13:30:00 to 2021-03-23 15:15:00
# Interval 2: 2021-03-23 14:48:41 to 2021-03-23 15:18:08
#
# Overlap detected for ID 171:
# Interval 1: 2021-12-29 18:40:00 to 2021-12-29 19:55:00
# Interval 2: 2021-12-29 19:34:06 to 2021-12-29 19:37:08
#
# Overlap detected for ID 171:
# Interval 1: 2022-01-05 18:44:26 to 2022-01-05 19:59:26
# Interval 2: 2022-01-05 18:49:00 to 2022-01-05 18:51:38
#
# Overlap detected for ID 174:
# Interval 1: 2021-10-16 15:15:00 to 2021-10-16 17:00:00
# Interval 2: 2021-10-16 15:16:33 to 2021-10-16 15:17:44
#
# Overlap detected for ID 174:
# Interval 1: 2021-10-16 15:15:00 to 2021-10-16 17:00:00
# Interval 2: 2021-10-16 15:34:59 to 2021-10-16 15:37:08
#
# Overlap detected for ID 174:
# Interval 1: 2021-10-22 15:15:00 to 2021-10-22 17:00:00
# Interval 2: 2021-10-22 15:16:14 to 2021-10-22 15:18:31
#
# Overlap detected for ID 174:
# Interval 1: 2021-10-22 15:15:00 to 2021-10-22 17:00:00
# Interval 2: 2021-10-22 15:27:36 to 2021-10-22 15:32:33
#
# Overlap detected for ID 174:
# Interval 1: 2021-10-22 15:15:00 to 2021-10-22 17:00:00
# Interval 2: 2021-10-22 15:58:54 to 2021-10-22 16:01:19
#
# Overlap detected for ID 177:
# Interval 1: 2021-09-12 19:00:00 to 2021-09-12 20:00:00
# Interval 2: 2021-09-12 19:15:00 to 2021-09-12 19:25:38
#
# Overlap detected for ID 177:
# Interval 1: 2021-09-14 18:24:00 to 2021-09-14 20:24:00
# Interval 2: 2021-09-14 18:24:36 to 2021-09-14 18:29:12
#
# Overlap detected for ID 177:
# Interval 1: 2021-09-15 18:24:31 to 2021-09-15 18:26:22
# Interval 2: 2021-09-15 18:25:00 to 2021-09-15 20:25:00
#
# Overlap detected for ID 181:
# Interval 1: 2021-11-08 16:08:47 to 2021-11-08 16:23:47
# Interval 2: 2021-11-08 16:13:23 to 2021-11-08 16:20:40
#
# Overlap detected for ID 193:
# Interval 1: 2021-04-19 12:00:00 to 2021-04-19 12:45:00
# Interval 2: 2021-04-19 12:23:50 to 2021-04-19 12:32:47
#
# Overlap detected for ID 193:
# Interval 1: 2021-04-20 17:21:00 to 2021-04-20 18:01:00
# Interval 2: 2021-04-20 17:28:01 to 2021-04-20 17:34:51
#
# Overlap detected for ID 193:
# Interval 1: 2021-04-20 17:21:00 to 2021-04-20 18:01:00
# Interval 2: 2021-04-20 17:38:04 to 2021-04-20 17:47:01
#
# Overlap detected for ID 194:
# Interval 1: 2021-11-30 14:30:00 to 2021-11-30 16:50:00
# Interval 2: 2021-11-30 15:20:27 to 2021-11-30 15:26:35
#
# Overlap detected for ID 194:
# Interval 1: 2021-11-30 14:30:00 to 2021-11-30 16:50:00
# Interval 2: 2021-11-30 15:31:11 to 2021-11-30 16:18:50
#
# Overlap detected for ID 194:
# Interval 1: 2021-12-02 14:35:00 to 2021-12-02 15:15:00
# Interval 2: 2021-12-02 15:11:00 to 2021-12-02 15:18:43
#
# Overlap detected for ID 194:
# Interval 1: 2021-12-03 14:15:00 to 2021-12-03 15:00:00
# Interval 2: 2021-12-03 14:22:55 to 2021-12-03 14:34:59
#
# Overlap detected for ID 194:
# Interval 1: 2021-12-03 14:15:00 to 2021-12-03 15:00:00
# Interval 2: 2021-12-03 14:35:11 to 2021-12-03 15:11:09
#
# Overlap detected for ID 195:
# Interval 1: 2021-04-04 13:44:52 to 2021-04-04 13:53:31
# Interval 2: 2021-04-04 13:49:00 to 2021-04-04 15:49:00
#
# Overlap detected for ID 195:
# Interval 1: 2021-04-13 14:50:00 to 2021-04-13 15:10:00
# Interval 2: 2021-04-13 15:01:45 to 2021-04-13 17:12:25
#
# Overlap detected for ID 197:
# Interval 1: 2021-10-28 12:30:00 to 2021-10-28 14:30:00
# Interval 2: 2021-10-28 13:40:01 to 2021-10-28 13:49:59
#
# Overlap detected for ID 197:
# Interval 1: 2021-10-31 08:19:15 to 2021-10-31 12:00:07
# Interval 2: 2021-10-31 08:20:00 to 2021-10-31 12:50:00
#
# Overlap detected for ID 200:
# Interval 1: 2022-07-15 12:20:00 to 2022-07-15 14:20:00
# Interval 2: 2022-07-15 13:03:58 to 2022-07-15 13:11:11
#
# Overlap detected for ID 200:
# Interval 1: 2022-07-15 12:20:00 to 2022-07-15 14:20:00
# Interval 2: 2022-07-15 13:41:07 to 2022-07-15 13:49:03
#
# Overlap detected for ID 202:
# Interval 1: 2022-02-06 12:15:00 to 2022-02-06 15:35:00
# Interval 2: 2022-02-06 15:15:59 to 2022-02-06 15:34:47
#
# Overlap detected for ID 203:
# Interval 1: 2021-11-01 16:30:00 to 2021-11-01 19:30:00
# Interval 2: 2021-11-01 18:36:08 to 2021-11-01 18:43:38
#
# Overlap detected for ID 203:
# Interval 1: 2021-11-04 08:00:00 to 2021-11-04 08:20:00
# Interval 2: 2021-11-04 08:13:23 to 2021-11-04 08:24:14
#
# Overlap detected for ID 203:
# Interval 1: 2021-11-04 17:00:00 to 2021-11-04 19:00:00
# Interval 2: 2021-11-04 17:01:41 to 2021-11-04 17:03:37
#
# Overlap detected for ID 203:
# Interval 1: 2021-11-05 17:00:00 to 2021-11-05 19:00:00
# Interval 2: 2021-11-05 17:05:16 to 2021-11-05 17:09:27
#
# Overlap detected for ID 203:
# Interval 1: 2021-11-05 17:00:00 to 2021-11-05 19:00:00
# Interval 2: 2021-11-05 18:44:41 to 2021-11-05 18:55:26
#
# Overlap detected for ID 205:
# Interval 1: 2021-10-30 15:16:00 to 2021-10-30 16:06:00
# Interval 2: 2021-10-30 15:25:44 to 2021-10-30 15:42:37
#
# Overlap detected for ID 205:
# Interval 1: 2021-10-30 15:16:00 to 2021-10-30 16:06:00
# Interval 2: 2021-10-30 15:42:56 to 2021-10-30 15:47:36
#
# Overlap detected for ID 205:
# Interval 1: 2021-11-02 15:03:00 to 2021-11-02 15:58:00
# Interval 2: 2021-11-02 15:05:00 to 2021-11-02 15:07:42
#
# Overlap detected for ID 205:
# Interval 1: 2021-11-02 15:03:00 to 2021-11-02 15:58:00
# Interval 2: 2021-11-02 15:20:01 to 2021-11-02 15:22:43
#
# Overlap detected for ID 205:
# Interval 1: 2021-11-02 15:03:00 to 2021-11-02 15:58:00
# Interval 2: 2021-11-02 15:24:30 to 2021-11-02 15:29:02
#
# Overlap detected for ID 208:
# Interval 1: 2021-04-07 11:11:46 to 2021-04-07 11:53:10
# Interval 2: 2021-04-07 11:13:00 to 2021-04-07 11:53:00
#
# Overlap detected for ID 208:
# Interval 1: 2021-04-15 13:00:00 to 2021-04-15 15:00:00
# Interval 2: 2021-04-15 14:01:24 to 2021-04-15 14:10:23
#
# Overlap detected for ID 210:
# Interval 1: 2021-05-04 18:00:00 to 2021-05-04 19:30:00
# Interval 2: 2021-05-04 18:27:34 to 2021-05-04 18:36:04
#
# Overlap detected for ID 210:
# Interval 1: 2021-05-10 09:45:00 to 2021-05-10 10:10:00
# Interval 2: 2021-05-10 09:47:29 to 2021-05-10 09:50:12
#
# Overlap detected for ID 211:
# Interval 1: 2021-08-29 06:31:00 to 2021-08-29 06:46:00
# Interval 2: 2021-08-29 06:31:14 to 2021-08-29 06:47:20
#
# Overlap detected for ID 211:
# Interval 1: 2021-09-01 06:56:00 to 2021-09-01 07:11:00
# Interval 2: 2021-09-01 06:56:05 to 2021-09-01 07:11:01
#
# Overlap detected for ID 211:
# Interval 1: 2021-09-02 06:30:00 to 2021-09-02 06:45:00
# Interval 2: 2021-09-02 06:32:01 to 2021-09-02 06:47:31
#
# Overlap detected for ID 211:
# Interval 1: 2021-09-04 06:23:00 to 2021-09-04 06:43:00
# Interval 2: 2021-09-04 06:23:17 to 2021-09-04 06:41:41
#
# Overlap detected for ID 211:
# Interval 1: 2021-09-05 06:24:00 to 2021-09-05 06:44:00
# Interval 2: 2021-09-05 06:34:24 to 2021-09-05 06:51:34
#
# Overlap detected for ID 214:
# Interval 1: 2022-02-11 15:11:00 to 2022-02-11 16:31:00
# Interval 2: 2022-02-11 15:12:38 to 2022-02-11 15:32:58
#
# Overlap detected for ID 214:
# Interval 1: 2022-02-11 15:11:00 to 2022-02-11 16:31:00
# Interval 2: 2022-02-11 15:33:32 to 2022-02-11 15:57:44
#
# Overlap detected for ID 214:
# Interval 1: 2022-02-14 20:28:00 to 2022-02-14 20:58:00
# Interval 2: 2022-02-14 20:28:47 to 2022-02-14 21:01:27
#
# Overlap detected for ID 214:
# Interval 1: 2022-02-18 22:15:00 to 2022-02-18 22:30:00
# Interval 2: 2022-02-18 22:15:22 to 2022-02-18 22:29:41
#
# Overlap detected for ID 225:
# Interval 1: 2021-06-13 14:30:00 to 2021-06-13 16:30:00
# Interval 2: 2021-06-13 16:04:56 to 2021-06-13 16:07:29
#
# Overlap detected for ID 228:
# Interval 1: 2022-01-08 17:57:53 to 2022-01-08 18:26:07
# Interval 2: 2022-01-08 18:26:00 to 2022-01-08 18:41:00
#
# Overlap detected for ID 230:
# Interval 1: 2021-07-10 14:41:50 to 2021-07-10 15:11:50
# Interval 2: 2021-07-10 14:45:58 to 2021-07-10 15:11:40
#
# Overlap detected for ID 231:
# Interval 1: 2021-04-30 18:10:00 to 2021-04-30 18:45:00
# Interval 2: 2021-04-30 18:14:08 to 2021-04-30 18:15:48
#
# Overlap detected for ID 234:
# Interval 1: 2021-07-22 17:57:00 to 2021-07-22 18:12:00
# Interval 2: 2021-07-22 17:57:38 to 2021-07-22 18:14:06
#
# Overlap detected for ID 234:
# Interval 1: 2021-07-23 17:45:00 to 2021-07-23 18:00:00
# Interval 2: 2021-07-23 17:45:38 to 2021-07-23 18:02:36
#
# Overlap detected for ID 234:
# Interval 1: 2021-07-23 19:35:31 to 2021-07-23 20:20:34
# Interval 2: 2021-07-23 19:45:00 to 2021-07-23 20:30:00
#
# Overlap detected for ID 234:
# Interval 1: 2021-07-24 18:14:00 to 2021-07-24 18:29:00
# Interval 2: 2021-07-24 18:14:18 to 2021-07-24 18:30:55
#
# Overlap detected for ID 234:
# Interval 1: 2021-07-24 20:05:00 to 2021-07-24 20:20:00
# Interval 2: 2021-07-24 20:05:47 to 2021-07-24 20:20:13
#
# Overlap detected for ID 239:
# Interval 1: 2021-10-15 18:34:20 to 2021-10-15 18:40:39
# Interval 2: 2021-10-15 18:35:00 to 2021-10-15 19:35:00
#
# Overlap detected for ID 239:
# Interval 1: 2021-10-17 20:00:00 to 2021-10-17 21:30:00
# Interval 2: 2021-10-17 20:36:34 to 2021-10-17 20:43:15
#
# Overlap detected for ID 239:
# Interval 1: 2021-10-17 20:00:00 to 2021-10-17 21:30:00
# Interval 2: 2021-10-17 20:55:51 to 2021-10-17 21:32:10
#
# Overlap detected for ID 239:
# Interval 1: 2021-10-19 13:35:00 to 2021-10-19 14:35:00
# Interval 2: 2021-10-19 14:05:28 to 2021-10-19 14:34:51
#
# Overlap detected for ID 241:
# Interval 1: 2020-12-31 18:10:00 to 2020-12-31 18:40:00
# Interval 2: 2020-12-31 18:10:17 to 2020-12-31 18:42:48
#
# Overlap detected for ID 241:
# Interval 1: 2021-01-01 18:00:00 to 2021-01-01 18:30:00
# Interval 2: 2021-01-01 18:10:16 to 2021-01-01 18:42:52
#
# Overlap detected for ID 241:
# Interval 1: 2021-01-01 18:10:16 to 2021-01-01 18:42:52
# Interval 2: 2021-01-01 18:35:00 to 2021-01-01 19:55:00
#
# Overlap detected for ID 241:
# Interval 1: 2021-01-01 18:35:00 to 2021-01-01 19:55:00
# Interval 2: 2021-01-01 18:53:05 to 2021-01-01 20:13:02
#
# Overlap detected for ID 241:
# Interval 1: 2021-01-06 19:00:00 to 2021-01-06 19:40:00
# Interval 2: 2021-01-06 19:01:36 to 2021-01-06 19:02:11
#
# Overlap detected for ID 242:
# Interval 1: 2021-04-30 15:23:07 to 2021-04-30 15:37:13
# Interval 2: 2021-04-30 15:25:00 to 2021-04-30 15:40:00
#
# Overlap detected for ID 242:
# Interval 1: 2021-05-09 15:26:01 to 2021-05-09 15:40:20
# Interval 2: 2021-05-09 15:32:00 to 2021-05-09 15:57:00
#
# Overlap detected for ID 242:
# Interval 1: 2021-05-09 15:32:00 to 2021-05-09 15:57:00
# Interval 2: 2021-05-09 15:48:25 to 2021-05-09 15:55:41
#
# Overlap detected for ID 244:
# Interval 1: 2022-02-06 15:45:00 to 2022-02-06 18:15:00
# Interval 2: 2022-02-06 17:55:22 to 2022-02-06 18:04:50
#
# Overlap detected for ID 244:
# Interval 1: 2022-02-09 16:30:00 to 2022-02-09 21:30:00
# Interval 2: 2022-02-09 17:23:45 to 2022-02-09 17:39:28
#
# Overlap detected for ID 245:
# Interval 1: 2022-02-07 15:10:00 to 2022-02-07 15:45:00
# Interval 2: 2022-02-07 15:11:24 to 2022-02-07 15:24:59
#
# Overlap detected for ID 245:
# Interval 1: 2022-02-07 15:10:00 to 2022-02-07 15:45:00
# Interval 2: 2022-02-07 15:35:10 to 2022-02-07 15:45:15
#
# Overlap detected for ID 246:
# Interval 1: 2021-09-21 13:21:53 to 2021-09-21 13:29:39
# Interval 2: 2021-09-21 13:25:00 to 2021-09-21 13:35:00
#
# Overlap detected for ID 246:
# Interval 1: 2021-09-23 13:26:00 to 2021-09-23 14:21:00
# Interval 2: 2021-09-23 14:09:37 to 2021-09-23 14:11:16
#
# Overlap detected for ID 246:
# Interval 1: 2021-09-28 14:50:00 to 2021-09-28 15:15:00
# Interval 2: 2021-09-28 14:52:50 to 2021-09-28 15:08:39
#
# Overlap detected for ID 248:
# Interval 1: 2022-04-10 17:00:00 to 2022-04-10 17:30:00
# Interval 2: 2022-04-10 17:07:38 to 2022-04-10 17:13:47
#
# Overlap detected for ID 249:
# Interval 1: 2021-04-03 18:00:00 to 2021-04-03 18:30:00
# Interval 2: 2021-04-03 18:04:38 to 2021-04-03 18:27:48
#
# Overlap detected for ID 254:
# Interval 1: 2021-09-30 15:30:00 to 2021-09-30 17:30:00
# Interval 2: 2021-09-30 15:42:19 to 2021-09-30 15:44:23
#
# Overlap detected for ID 254:
# Interval 1: 2021-10-05 11:38:00 to 2021-10-05 12:13:00
# Interval 2: 2021-10-05 11:50:56 to 2021-10-05 11:57:20
#
# Overlap detected for ID 254:
# Interval 1: 2021-10-05 15:30:00 to 2021-10-05 17:30:00
# Interval 2: 2021-10-05 15:38:19 to 2021-10-05 15:40:33
#
# Overlap detected for ID 254:
# Interval 1: 2021-10-05 15:30:00 to 2021-10-05 17:30:00
# Interval 2: 2021-10-05 17:09:04 to 2021-10-05 17:11:24
#
# Overlap detected for ID 254:
# Interval 1: 2021-10-06 16:20:00 to 2021-10-06 16:35:00
# Interval 2: 2021-10-06 16:26:40 to 2021-10-06 16:28:38
#
# Overlap detected for ID 255:
# Interval 1: 2022-01-09 08:40:00 to 2022-01-09 14:40:00
# Interval 2: 2022-01-09 09:52:17 to 2022-01-09 09:59:05
#
# Overlap detected for ID 255:
# Interval 1: 2022-01-09 08:40:00 to 2022-01-09 14:40:00
# Interval 2: 2022-01-09 10:21:47 to 2022-01-09 10:32:30
#
# Overlap detected for ID 255:
# Interval 1: 2022-01-10 18:40:00 to 2022-01-10 18:55:00
# Interval 2: 2022-01-10 18:47:17 to 2022-01-10 19:01:00
#
# Overlap detected for ID 255:
# Interval 1: 2022-01-12 13:00:00 to 2022-01-12 15:00:00
# Interval 2: 2022-01-12 14:28:23 to 2022-01-12 14:39:50
#
# Overlap detected for ID 255:
# Interval 1: 2022-01-13 08:37:00 to 2022-01-13 12:37:00
# Interval 2: 2022-01-13 08:41:45 to 2022-01-13 08:51:09
#
# Overlap detected for ID 256:
# Interval 1: 2021-05-06 19:38:31 to 2021-05-06 19:55:42
# Interval 2: 2021-05-06 19:44:00 to 2021-05-06 20:14:00
#
# Overlap detected for ID 256:
# Interval 1: 2021-05-06 19:44:00 to 2021-05-06 20:14:00
# Interval 2: 2021-05-06 19:57:55 to 2021-05-06 20:03:49
#
# Overlap detected for ID 256:
# Interval 1: 2021-05-06 20:30:00 to 2021-05-06 21:00:00
# Interval 2: 2021-05-06 20:44:29 to 2021-05-06 20:51:01
#
# Overlap detected for ID 256:
# Interval 1: 2021-05-06 20:30:00 to 2021-05-06 21:00:00
# Interval 2: 2021-05-06 20:52:11 to 2021-05-06 21:15:16
#
# Overlap detected for ID 256:
# Interval 1: 2021-05-07 06:31:00 to 2021-05-07 07:31:00
# Interval 2: 2021-05-07 06:52:42 to 2021-05-07 07:02:07
#
# Overlap detected for ID 258:
# Interval 1: 2021-11-23 16:39:00 to 2021-11-23 17:09:00
# Interval 2: 2021-11-23 16:39:29 to 2021-11-23 16:41:32
#
# Overlap detected for ID 258:
# Interval 1: 2021-11-23 17:30:00 to 2021-11-23 17:45:00
# Interval 2: 2021-11-23 17:35:17 to 2021-11-23 17:49:11
#
# Overlap detected for ID 258:
# Interval 1: 2021-11-24 17:16:00 to 2021-11-24 18:46:00
# Interval 2: 2021-11-24 18:29:35 to 2021-11-24 18:50:54
#
# Overlap detected for ID 258:
# Interval 1: 2021-11-25 11:45:00 to 2021-11-25 12:10:00
# Interval 2: 2021-11-25 11:47:04 to 2021-11-25 12:04:17
#
# Overlap detected for ID 258:
# Interval 1: 2021-11-26 13:15:00 to 2021-11-26 14:30:00
# Interval 2: 2021-11-26 13:39:19 to 2021-11-26 13:49:11
#
# Overlap detected for ID 264:
# Interval 1: 2021-03-06 16:08:32 to 2021-03-06 16:10:18
# Interval 2: 2021-03-06 16:10:00 to 2021-03-06 16:35:00
#
# Overlap detected for ID 264:
# Interval 1: 2021-03-06 16:10:00 to 2021-03-06 16:35:00
# Interval 2: 2021-03-06 16:11:05 to 2021-03-06 16:35:01
#
# Overlap detected for ID 265:
# Interval 1: 2021-09-02 16:00:00 to 2021-09-02 17:00:00
# Interval 2: 2021-09-02 16:30:40 to 2021-09-02 16:33:31
#
# Overlap detected for ID 265:
# Interval 1: 2021-09-02 16:00:00 to 2021-09-02 17:00:00
# Interval 2: 2021-09-02 16:47:56 to 2021-09-02 16:52:44
#
# Overlap detected for ID 265:
# Interval 1: 2021-09-03 16:50:00 to 2021-09-03 17:30:00
# Interval 2: 2021-09-03 17:09:29 to 2021-09-03 17:11:36
#
# Overlap detected for ID 265:
# Interval 1: 2021-09-04 11:00:00 to 2021-09-04 12:05:00
# Interval 2: 2021-09-04 11:58:24 to 2021-09-04 12:00:25
#
# Overlap detected for ID 265:
# Interval 1: 2021-09-08 14:06:00 to 2021-09-08 14:26:00
# Interval 2: 2021-09-08 14:08:10 to 2021-09-08 14:15:25
#
# Overlap detected for ID 270:
# Interval 1: 2021-09-24 16:45:00 to 2021-09-24 18:55:00
# Interval 2: 2021-09-24 18:50:00 to 2021-09-24 19:00:00
#
# Overlap detected for ID 278:
# Interval 1: 2022-02-06 15:00:00 to 2022-02-06 15:35:00
# Interval 2: 2022-02-06 15:03:36 to 2022-02-06 15:14:12
#
# Overlap detected for ID 278:
# Interval 1: 2022-02-06 15:00:00 to 2022-02-06 15:35:00
# Interval 2: 2022-02-06 15:18:50 to 2022-02-06 15:26:03
#
# Overlap detected for ID 278:
# Interval 1: 2022-02-07 18:10:00 to 2022-02-07 18:50:00
# Interval 2: 2022-02-07 18:41:00 to 2022-02-07 18:49:53
#
# Overlap detected for ID 278:
# Interval 1: 2022-02-12 15:00:00 to 2022-02-12 15:30:00
# Interval 2: 2022-02-12 15:04:33 to 2022-02-12 15:13:29
#
# Overlap detected for ID 278:
# Interval 1: 2022-02-12 16:15:00 to 2022-02-12 16:30:00
# Interval 2: 2022-02-12 16:23:09 to 2022-02-12 16:33:24
#
# Overlap detected for ID 284:
# Interval 1: 2020-10-21 13:35:00 to 2020-10-21 14:05:00
# Interval 2: 2020-10-21 13:35:13 to 2020-10-21 13:48:16
#
# Overlap detected for ID 284:
# Interval 1: 2020-12-08 15:35:00 to 2020-12-08 16:00:00
# Interval 2: 2020-12-08 15:42:24 to 2020-12-08 15:50:17
#
# Overlap detected for ID 284:
# Interval 1: 2020-12-14 16:10:00 to 2020-12-14 16:40:00
# Interval 2: 2020-12-14 16:25:04 to 2020-12-14 16:37:40
#
# Overlap detected for ID 288:
# Interval 1: 2021-07-14 12:20:14 to 2021-07-14 13:40:14
# Interval 2: 2021-07-14 12:21:38 to 2021-07-14 12:52:01
#
# Overlap detected for ID 292:
# Interval 1: 2021-09-16 11:00:00 to 2021-09-16 11:30:00
# Interval 2: 2021-09-16 11:27:44 to 2021-09-16 11:34:02
#
# Overlap detected for ID 295:
# Interval 1: 2021-07-02 09:32:00 to 2021-07-02 10:17:00
# Interval 2: 2021-07-02 09:48:39 to 2021-07-02 09:49:42
#
# Overlap detected for ID 301:
# Interval 1: 2021-11-21 17:30:00 to 2021-11-21 20:00:00
# Interval 2: 2021-11-21 17:34:33 to 2021-11-21 17:36:32
#
# Overlap detected for ID 304:
# Interval 1: 2021-02-06 17:00:00 to 2021-02-06 17:30:00
# Interval 2: 2021-02-06 17:13:33 to 2021-02-06 17:24:57
#
# Overlap detected for ID 304:
# Interval 1: 2021-02-06 17:00:00 to 2021-02-06 17:30:00
# Interval 2: 2021-02-06 17:25:15 to 2021-02-06 17:32:10
#
# Overlap detected for ID 304:
# Interval 1: 2021-02-07 15:57:47 to 2021-02-07 16:42:47
# Interval 2: 2021-02-07 16:00:46 to 2021-02-07 16:12:55
#
# Overlap detected for ID 304:
# Interval 1: 2021-02-10 16:21:42 to 2021-02-10 16:41:42
# Interval 2: 2021-02-10 16:23:09 to 2021-02-10 16:33:43
#
# Overlap detected for ID 307:
# Interval 1: 2021-12-14 10:00:00 to 2021-12-14 11:00:00
# Interval 2: 2021-12-14 10:04:34 to 2021-12-14 11:01:12
#
# Overlap detected for ID 307:
# Interval 1: 2021-12-15 10:40:00 to 2021-12-15 11:10:00
# Interval 2: 2021-12-15 10:42:25 to 2021-12-15 10:55:07
#
# Overlap detected for ID 307:
# Interval 1: 2021-12-15 10:40:00 to 2021-12-15 11:10:00
# Interval 2: 2021-12-15 10:57:53 to 2021-12-15 11:13:04
#
# Overlap detected for ID 307:
# Interval 1: 2021-12-17 08:35:00 to 2021-12-17 09:15:00
# Interval 2: 2021-12-17 09:05:51 to 2021-12-17 09:13:30
#
# Overlap detected for ID 307:
# Interval 1: 2021-12-19 10:00:00 to 2021-12-19 11:45:00
# Interval 2: 2021-12-19 10:45:10 to 2021-12-19 10:51:47
#
# Overlap detected for ID 311:
# Interval 1: 2021-09-02 11:00:00 to 2021-09-02 11:10:00
# Interval 2: 2021-09-02 11:06:20 to 2021-09-02 11:09:41
#
# Overlap detected for ID 317:
# Interval 1: 2022-03-28 09:58:40 to 2022-03-28 11:48:40
# Interval 2: 2022-03-28 10:00:00 to 2022-03-28 11:55:00
#
# Overlap detected for ID 318:
# Interval 1: 2022-07-26 10:37:00 to 2022-07-26 11:27:00
# Interval 2: 2022-07-26 10:37:50 to 2022-07-26 11:26:10
#
# Overlap detected for ID 318:
# Interval 1: 2022-07-26 11:30:00 to 2022-07-26 12:00:00
# Interval 2: 2022-07-26 11:30:18 to 2022-07-26 12:02:03
#
# Overlap detected for ID 318:
# Interval 1: 2022-07-27 07:50:00 to 2022-07-27 08:10:00
# Interval 2: 2022-07-27 07:51:16 to 2022-07-27 07:52:50
#
# Overlap detected for ID 318:
# Interval 1: 2022-07-27 07:50:00 to 2022-07-27 08:10:00
# Interval 2: 2022-07-27 07:53:18 to 2022-07-27 08:13:31
#
# Overlap detected for ID 318:
# Interval 1: 2022-07-27 08:30:00 to 2022-07-27 09:20:00
# Interval 2: 2022-07-27 08:32:25 to 2022-07-27 09:18:32
#
# Overlap detected for ID 320:
# Interval 1: 2021-08-08 19:00:00 to 2021-08-08 20:30:00
# Interval 2: 2021-08-08 19:01:07 to 2021-08-08 19:04:10
#
# Overlap detected for ID 320:
# Interval 1: 2021-08-10 13:20:00 to 2021-08-10 15:45:00
# Interval 2: 2021-08-10 14:10:01 to 2021-08-10 14:16:07
#
# Overlap detected for ID 320:
# Interval 1: 2021-08-11 15:00:00 to 2021-08-11 16:15:00
# Interval 2: 2021-08-11 15:11:05 to 2021-08-11 15:17:40
#
# Overlap detected for ID 320:
# Interval 1: 2021-08-11 15:00:00 to 2021-08-11 16:15:00
# Interval 2: 2021-08-11 15:26:38 to 2021-08-11 15:38:18
#
# Overlap detected for ID 320:
# Interval 1: 2021-08-14 10:18:00 to 2021-08-14 11:03:00
# Interval 2: 2021-08-14 10:34:54 to 2021-08-14 10:38:14
#
# Overlap detected for ID 328:
# Interval 1: 2021-11-28 13:01:42 to 2021-11-28 13:36:42
# Interval 2: 2021-11-28 13:06:46 to 2021-11-28 13:08:58
#
# Overlap detected for ID 328:
# Interval 1: 2021-11-29 12:56:25 to 2021-11-29 13:31:25
# Interval 2: 2021-11-29 13:05:56 to 2021-11-29 13:09:25
#
# Overlap detected for ID 328:
# Interval 1: 2021-11-30 13:03:34 to 2021-11-30 13:33:34
# Interval 2: 2021-11-30 13:10:08 to 2021-11-30 13:14:43
#
# Overlap detected for ID 328:
# Interval 1: 2021-12-05 12:54:35 to 2021-12-05 13:24:35
# Interval 2: 2021-12-05 13:04:54 to 2021-12-05 13:10:11
#
# Overlap detected for ID 328:
# Interval 1: 2021-12-05 17:00:00 to 2021-12-05 17:45:00
# Interval 2: 2021-12-05 17:10:11 to 2021-12-05 17:16:35
#
# Overlap detected for ID 332:
# Interval 1: 2022-03-27 09:11:54 to 2022-03-27 09:41:54
# Interval 2: 2022-03-27 09:40:00 to 2022-03-27 10:20:00
#
# Overlap detected for ID 334:
# Interval 1: 2022-01-16 16:41:00 to 2022-01-16 17:01:00
# Interval 2: 2022-01-16 16:46:59 to 2022-01-16 17:00:30
#
# Overlap detected for ID 334:
# Interval 1: 2022-01-17 11:37:00 to 2022-01-17 13:12:00
# Interval 2: 2022-01-17 11:48:52 to 2022-01-17 12:19:05
#
# Overlap detected for ID 340:
# Interval 1: 2022-04-07 12:10:00 to 2022-04-07 12:35:00
# Interval 2: 2022-04-07 12:20:55 to 2022-04-07 12:31:53
#
# Overlap detected for ID 340:
# Interval 1: 2022-04-14 13:15:00 to 2022-04-14 14:30:00
# Interval 2: 2022-04-14 13:19:23 to 2022-04-14 13:26:39
#
# Overlap detected for ID 350:
# Interval 1: 2020-11-28 15:49:00 to 2020-11-28 16:09:00
# Interval 2: 2020-11-28 15:49:10 to 2020-11-28 16:07:48
#
# Overlap detected for ID 350:
# Interval 1: 2020-11-30 20:15:00 to 2020-11-30 20:25:00
# Interval 2: 2020-11-30 20:15:02 to 2020-11-30 20:25:50
#
# Overlap detected for ID 350:
# Interval 1: 2020-12-02 20:32:00 to 2020-12-02 20:42:00
# Interval 2: 2020-12-02 20:32:03 to 2020-12-02 20:41:50
#
# Overlap detected for ID 350:
# Interval 1: 2020-12-03 17:02:00 to 2020-12-03 17:37:00
# Interval 2: 2020-12-03 17:02:34 to 2020-12-03 17:40:53
#
# Overlap detected for ID 354:
# Interval 1: 2021-08-22 16:50:00 to 2021-08-22 17:15:00
# Interval 2: 2021-08-22 16:51:31 to 2021-08-22 17:18:05
#
# Overlap detected for ID 354:
# Interval 1: 2021-08-23 14:30:00 to 2021-08-23 16:30:00
# Interval 2: 2021-08-23 16:14:42 to 2021-08-23 16:24:42
#
# Overlap detected for ID 354:
# Interval 1: 2021-08-24 09:10:00 to 2021-08-24 09:25:00
# Interval 2: 2021-08-24 09:13:04 to 2021-08-24 09:26:41
#
# Overlap detected for ID 354:
# Interval 1: 2021-08-24 19:00:00 to 2021-08-24 20:00:00
# Interval 2: 2021-08-24 19:40:07 to 2021-08-24 19:56:13
#
# Overlap detected for ID 354:
# Interval 1: 2021-08-29 15:20:00 to 2021-08-29 16:10:00
# Interval 2: 2021-08-29 15:23:33 to 2021-08-29 16:14:13
#
# Overlap detected for ID 364:
# Interval 1: 2022-01-27 08:40:00 to 2022-01-27 09:00:00
# Interval 2: 2022-01-27 08:42:35 to 2022-01-27 08:51:51
#
# Overlap detected for ID 365:
# Interval 1: 2021-12-24 18:11:00 to 2021-12-24 18:46:00
# Interval 2: 2021-12-24 18:29:30 to 2021-12-24 18:37:27
#
# Overlap detected for ID 367:
# Interval 1: 2022-03-17 10:45:00 to 2022-03-17 11:00:00
# Interval 2: 2022-03-17 10:57:17 to 2022-03-17 10:59:47
#
# Overlap detected for ID 367:
# Interval 1: 2022-03-18 11:10:00 to 2022-03-18 11:40:00
# Interval 2: 2022-03-18 11:29:25 to 2022-03-18 11:33:44
#
# Overlap detected for ID 367:
# Interval 1: 2022-03-20 01:10:00 to 2022-03-20 02:00:00
# ...
#
# Overlap detected for ID 435:
# Interval 1: 2021-05-14 07:30:00 to 2021-05-14 08:00:00
# Interval 2: 2021-05-14 07:34:10 to 2021-05-14 07:58:23
#
# Overlap detected for ID 435:
# Interval 1: 2021-05-18 07:40:00 to 2021-05-18 08:00:00
# Interval 2: 2021-05-18 07:40:57 to 2021-05-18 07:59:40
#
# Overlap detected for ID 435:
# Interval 1: 2021-05-21 09:45:00 to 2021-05-21 10:35:00
# Interval 2: 2021-05-21 10:22:03 to 2021-05-21 10:28:07
#
# Overlap detected for ID 435:
# Interval 1: 2021-05-22 14:50:00 to 2021-05-22 16:50:00
# Interval 2: 2021-05-22 14:56:20 to 2021-05-22 15:03:50
#
# Overlap detected for ID 439:
# Interval 1: 2021-04-14 17:10:00 to 2021-04-14 17:35:00
# Interval 2: 2021-04-14 17:22:34 to 2021-04-14 17:36:06
#
# Overlap detected for ID 439:
# Interval 1: 2021-04-17 10:30:00 to 2021-04-17 10:55:00
# Interval 2: 2021-04-17 10:32:58 to 2021-04-17 10:57:57
#
# Overlap detected for ID 439:
# Interval 1: 2021-04-18 11:59:33 to 2021-04-18 12:19:42
# Interval 2: 2021-04-18 12:00:00 to 2021-04-18 12:20:00
#
# Overlap detected for ID 439:
# Interval 1: 2021-04-19 16:44:26 to 2021-04-19 17:36:16
# Interval 2: 2021-04-19 16:45:00 to 2021-04-19 17:30:00
#
# Overlap detected for ID 439:
# Interval 1: 2021-04-20 16:55:47 to 2021-04-20 17:03:41
# Interval 2: 2021-04-20 16:56:00 to 2021-04-20 17:11:00
#
# Overlap detected for ID 440:
# Interval 1: 2020-11-11 14:10:22 to 2020-11-11 14:25:22
# Interval 2: 2020-11-11 14:14:33 to 2020-11-11 14:26:41
#
# Overlap detected for ID 440:
# Interval 1: 2020-11-12 11:30:02 to 2020-11-12 11:45:02
# Interval 2: 2020-11-12 11:30:31 to 2020-11-12 11:46:48
#
# Overlap detected for ID 440:
# Interval 1: 2020-11-13 11:34:00 to 2020-11-13 11:49:00
# Interval 2: 2020-11-13 11:37:28 to 2020-11-13 11:51:09
#
# Overlap detected for ID 440:
# Interval 1: 2020-11-18 10:28:35 to 2020-11-18 10:42:46
# Interval 2: 2020-11-18 10:29:14 to 2020-11-18 10:39:14
#
# Overlap detected for ID 440:
# Interval 1: 2020-11-18 19:33:19 to 2020-11-18 19:48:19
# Interval 2: 2020-11-18 19:35:24 to 2020-11-18 19:52:59
#
# Overlap detected for ID 445:
# Interval 1: 2021-05-26 09:19:22 to 2021-05-26 09:54:22
# Interval 2: 2021-05-26 09:29:20 to 2021-05-26 09:31:24
#
# Overlap detected for ID 445:
# Interval 1: 2021-05-27 12:25:00 to 2021-05-27 12:50:00
# Interval 2: 2021-05-27 12:36:02 to 2021-05-27 12:42:20
#
# Overlap detected for ID 445:
# Interval 1: 2021-05-28 08:57:00 to 2021-05-28 09:17:00
# Interval 2: 2021-05-28 08:58:05 to 2021-05-28 09:08:47
#
# Overlap detected for ID 445:
# Interval 1: 2021-05-28 11:50:00 to 2021-05-28 12:15:00
# Interval 2: 2021-05-28 11:59:11 to 2021-05-28 12:19:48
#
# Overlap detected for ID 445:
# Interval 1: 2021-05-29 09:24:00 to 2021-05-29 09:29:00
# Interval 2: 2021-05-29 09:28:44 to 2021-05-29 09:31:15
#
# Overlap detected for ID 446:
# Interval 1: 2022-03-21 19:28:46 to 2022-03-21 20:03:02
# Interval 2: 2022-03-21 19:30:00 to 2022-03-21 20:00:00
#
# Overlap detected for ID 446:
# Interval 1: 2022-03-23 18:41:21 to 2022-03-23 18:56:21
# Interval 2: 2022-03-23 18:52:01 to 2022-03-23 19:02:09
#
# Overlap detected for ID 446:
# Interval 1: 2022-03-26 12:00:00 to 2022-03-26 14:45:00
# Interval 2: 2022-03-26 12:49:45 to 2022-03-26 12:58:56
#
# Overlap detected for ID 446:
# Interval 1: 2022-03-26 17:30:00 to 2022-03-26 18:05:00
# Interval 2: 2022-03-26 17:43:04 to 2022-03-26 17:49:42
#
# Overlap detected for ID 446:
# Interval 1: 2022-03-26 17:30:00 to 2022-03-26 18:05:00
# Interval 2: 2022-03-26 17:54:31 to 2022-03-26 18:04:14
#
# Overlap detected for ID 452:
# Interval 1: 2021-08-25 10:00:00 to 2021-08-25 10:15:00
# Interval 2: 2021-08-25 10:04:58 to 2021-08-25 10:17:00
#
# Overlap detected for ID 452:
# Interval 1: 2021-08-25 20:15:00 to 2021-08-25 20:30:00
# Interval 2: 2021-08-25 20:26:00 to 2021-08-25 20:32:13
#
# Overlap detected for ID 452:
# Interval 1: 2021-08-29 10:00:00 to 2021-08-29 10:15:00
# Interval 2: 2021-08-29 10:00:16 to 2021-08-29 10:15:40
#
# Overlap detected for ID 456:
# Interval 1: 2021-04-30 08:15:00 to 2021-04-30 09:20:00
# Interval 2: 2021-04-30 08:15:44 to 2021-04-30 09:30:25
#
# Overlap detected for ID 456:
# Interval 1: 2021-05-01 12:10:00 to 2021-05-01 18:10:00
# Interval 2: 2021-05-01 12:21:58 to 2021-05-01 12:41:02
#
# Overlap detected for ID 456:
# Interval 1: 2021-05-02 19:33:26 to 2021-05-02 20:00:30
# Interval 2: 2021-05-02 19:35:00 to 2021-05-02 19:55:00
#
# Overlap detected for ID 456:
# Interval 1: 2021-05-02 19:33:26 to 2021-05-02 20:00:30
# Interval 2: 2021-05-02 19:55:00 to 2021-05-02 20:50:00
#
# Overlap detected for ID 456:
# Interval 1: 2021-05-03 07:55:00 to 2021-05-03 09:00:00
# Interval 2: 2021-05-03 07:55:36 to 2021-05-03 09:12:49
#
# Overlap detected for ID 460:
# Interval 1: 2022-03-07 10:20:00 to 2022-03-07 10:40:00
# Interval 2: 2022-03-07 10:29:28 to 2022-03-07 10:41:25
#
# Overlap detected for ID 464:
# Interval 1: 2021-08-05 14:29:35 to 2021-08-05 14:33:12
# Interval 2: 2021-08-05 14:30:00 to 2021-08-05 16:00:00
#
# Overlap detected for ID 464:
# Interval 1: 2021-08-09 14:20:00 to 2021-08-09 15:50:00
# Interval 2: 2021-08-09 14:33:33 to 2021-08-09 14:35:12
#
# Overlap detected for ID 464:
# Interval 1: 2021-08-14 14:28:22 to 2021-08-14 14:31:08
# Interval 2: 2021-08-14 14:30:00 to 2021-08-14 16:00:00
#
# Overlap detected for ID 466:
# Interval 1: 2022-02-09 12:31:54 to 2022-02-09 12:47:30
# Interval 2: 2022-02-09 12:32:00 to 2022-02-09 13:07:00
#
# Overlap detected for ID 466:
# Interval 1: 2022-02-13 09:00:00 to 2022-02-13 12:00:00
# Interval 2: 2022-02-13 09:00:08 to 2022-02-13 09:08:46
#
# Overlap detected for ID 467:
# Interval 1: 2022-01-10 10:00:00 to 2022-01-10 10:10:00
# Interval 2: 2022-01-10 10:00:56 to 2022-01-10 10:10:13
#
# Overlap detected for ID 469:
# Interval 1: 2021-11-07 17:30:00 to 2021-11-07 19:40:00
# Interval 2: 2021-11-07 17:31:16 to 2021-11-07 17:33:25
#
# Overlap detected for ID 469:
# Interval 1: 2021-11-11 17:37:00 to 2021-11-11 18:37:00
# Interval 2: 2021-11-11 17:41:52 to 2021-11-11 17:44:19
#
# Overlap detected for ID 469:
# Interval 1: 2021-11-13 17:40:00 to 2021-11-13 18:40:00
# Interval 2: 2021-11-13 18:23:36 to 2021-11-13 18:28:17
#
# Overlap detected for ID 478:
# Interval 1: 2021-05-11 11:45:00 to 2021-05-11 12:05:00
# Interval 2: 2021-05-11 11:49:09 to 2021-05-11 11:56:27
#
# Overlap detected for ID 479:
# Interval 1: 2021-02-04 14:52:00 to 2021-02-04 15:22:00
# Interval 2: 2021-02-04 14:55:38 to 2021-02-04 15:24:45
#
# Overlap detected for ID 480:
# Interval 1: 2021-10-19 21:16:00 to 2021-10-19 22:01:00
# Interval 2: 2021-10-19 21:24:26 to 2021-10-19 21:46:14
#
# Overlap detected for ID 480:
# Interval 1: 2021-10-19 21:16:00 to 2021-10-19 22:01:00
# Interval 2: 2021-10-19 21:46:31 to 2021-10-19 21:57:05
#
# Overlap detected for ID 480:
# Interval 1: 2021-10-25 20:40:00 to 2021-10-25 20:50:00
# Interval 2: 2021-10-25 20:43:07 to 2021-10-25 20:52:30
#
# Overlap detected for ID 480:
# Interval 1: 2021-10-26 16:35:00 to 2021-10-26 16:45:00
# Interval 2: 2021-10-26 16:41:06 to 2021-10-26 16:47:22
#
# Overlap detected for ID 484:
# Interval 1: 2022-07-08 18:57:59 to 2022-07-08 19:01:18
# Interval 2: 2022-07-08 19:00:00 to 2022-07-08 19:15:00
#
# Overlap detected for ID 484:
# Interval 1: 2022-07-08 19:00:00 to 2022-07-08 19:15:00
# Interval 2: 2022-07-08 19:01:29 to 2022-07-08 19:15:45
#
# Overlap detected for ID 484:
# Interval 1: 2022-07-09 18:50:00 to 2022-07-09 19:45:00
# Interval 2: 2022-07-09 18:58:54 to 2022-07-09 19:41:56
#
# Overlap detected for ID 484:
# Interval 1: 2022-07-11 14:30:00 to 2022-07-11 15:30:00
# Interval 2: 2022-07-11 15:05:45 to 2022-07-11 15:12:24
#
# Overlap detected for ID 484:
# Interval 1: 2022-07-11 19:03:00 to 2022-07-11 19:48:00
# Interval 2: 2022-07-11 19:08:40 to 2022-07-11 19:37:45
#
# Overlap detected for ID 492:
# Interval 1: 2021-08-21 15:45:00 to 2021-08-21 17:15:00
# Interval 2: 2021-08-21 16:43:44 to 2021-08-21 16:59:37
#
# Overlap detected for ID 492:
# Interval 1: 2021-08-24 18:15:00 to 2021-08-24 20:15:00
# Interval 2: 2021-08-24 18:44:33 to 2021-08-24 18:50:31
#
# Overlap detected for ID 492:
# Interval 1: 2021-08-27 18:15:00 to 2021-08-27 20:15:00
# Interval 2: 2021-08-27 18:47:18 to 2021-08-27 18:52:50
#
# Overlap detected for ID 492:
# Interval 1: 2021-08-27 18:15:00 to 2021-08-27 20:15:00
# Interval 2: 2021-08-27 19:33:20 to 2021-08-27 19:40:00
#
# Overlap detected for ID 494:
# Interval 1: 2020-12-13 12:00:00 to 2020-12-13 13:00:00
# Interval 2: 2020-12-13 12:29:37 to 2020-12-13 12:42:47
#
# Overlap detected for ID 494:
# Interval 1: 2020-12-13 15:11:42 to 2020-12-13 15:37:06
# Interval 2: 2020-12-13 15:15:00 to 2020-12-13 15:45:00
#
# Overlap detected for ID 494:
# Interval 1: 2020-12-16 10:30:00 to 2020-12-16 11:15:00
# Interval 2: 2020-12-16 10:58:01 to 2020-12-16 11:05:11
#
# Overlap detected for ID 494:
# Interval 1: 2020-12-22 10:30:00 to 2020-12-22 11:15:00
# Interval 2: 2020-12-22 11:06:18 to 2020-12-22 11:16:02
#
# Overlap detected for ID 496:
# Interval 1: 2021-05-05 17:15:00 to 2021-05-05 17:40:00
# Interval 2: 2021-05-05 17:17:51 to 2021-05-05 17:24:02
#
# Overlap detected for ID 496:
# Interval 1: 2021-05-05 17:15:00 to 2021-05-05 17:40:00
# Interval 2: 2021-05-05 17:28:54 to 2021-05-05 17:35:47
#
# Overlap detected for ID 497:
# Interval 1: 2022-01-28 19:00:00 to 2022-01-28 20:15:00
# Interval 2: 2022-01-28 19:02:01 to 2022-01-28 19:04:02
#
# Overlap detected for ID 498:
# Interval 1: 2021-07-22 10:20:00 to 2021-07-22 10:50:00
# Interval 2: 2021-07-22 10:32:25 to 2021-07-22 10:38:49
#
# Overlap detected for ID 498:
# Interval 1: 2021-07-22 10:20:00 to 2021-07-22 10:50:00
# Interval 2: 2021-07-22 10:41:09 to 2021-07-22 10:47:18
#
# Overlap detected for ID 498:
# Interval 1: 2021-07-24 13:00:00 to 2021-07-24 15:30:00
# Interval 2: 2021-07-24 15:08:21 to 2021-07-24 15:14:16
#
# Overlap detected for ID 501:
# Interval 1: 2021-04-22 19:38:55 to 2021-04-22 19:45:01
# Interval 2: 2021-04-22 19:43:00 to 2021-04-22 19:53:00
#
# Overlap detected for ID 508:
# Interval 1: 2022-06-11 11:40:05 to 2022-06-11 11:46:06
# Interval 2: 2022-06-11 11:45:00 to 2022-06-11 13:30:00
#
# Overlap detected for ID 508:
# Interval 1: 2022-06-11 11:45:00 to 2022-06-11 13:30:00
# Interval 2: 2022-06-11 12:15:35 to 2022-06-11 12:19:47
#
# Overlap detected for ID 508:
# Interval 1: 2022-06-11 11:45:00 to 2022-06-11 13:30:00
# Interval 2: 2022-06-11 12:20:15 to 2022-06-11 12:22:40
#
# Overlap detected for ID 508:
# Interval 1: 2022-06-11 11:45:00 to 2022-06-11 13:30:00
# Interval 2: 2022-06-11 12:46:02 to 2022-06-11 13:02:32
#
# Overlap detected for ID 508:
# Interval 1: 2022-06-15 11:50:00 to 2022-06-15 13:00:00
# Interval 2: 2022-06-15 11:56:46 to 2022-06-15 12:18:24
#
# Overlap detected for ID 510:
# Interval 1: 2021-12-25 23:00:00 to 2021-12-26 00:30:00
# Interval 2: 2021-12-26 00:03:34 to 2021-12-26 00:10:17
#
# Overlap detected for ID 510:
# Interval 1: 2021-12-26 17:30:00 to 2021-12-26 18:15:00
# Interval 2: 2021-12-26 17:34:14 to 2021-12-26 18:19:06
#
# Overlap detected for ID 510:
# Interval 1: 2021-12-27 08:35:00 to 2021-12-27 08:45:00
# Interval 2: 2021-12-27 08:36:21 to 2021-12-27 08:43:13
#
# Overlap detected for ID 510:
# Interval 1: 2021-12-28 10:28:00 to 2021-12-28 10:38:00
# Interval 2: 2021-12-28 10:32:49 to 2021-12-28 10:39:30
#
# Overlap detected for ID 510:
# Interval 1: 2021-12-30 16:40:00 to 2021-12-30 17:40:00
# Interval 2: 2021-12-30 16:50:10 to 2021-12-30 17:42:07
#
# Overlap detected for ID 515:
# Interval 1: 2021-09-24 12:54:00 to 2021-09-24 14:04:00
# Interval 2: 2021-09-24 12:59:11 to 2021-09-24 14:11:51
#
# Overlap detected for ID 515:
# Interval 1: 2021-09-25 15:13:07 to 2021-09-25 16:13:07
# Interval 2: 2021-09-25 15:17:51 to 2021-09-25 15:29:00
#
# Overlap detected for ID 515:
# Interval 1: 2021-09-25 15:13:07 to 2021-09-25 16:13:07
# Interval 2: 2021-09-25 15:55:24 to 2021-09-25 16:05:29
#
# Overlap detected for ID 515:
# Interval 1: 2021-09-28 20:45:30 to 2021-09-28 21:20:30
# Interval 2: 2021-09-28 20:52:04 to 2021-09-28 21:29:43
#
# Overlap detected for ID 515:
# Interval 1: 2021-09-29 19:22:00 to 2021-09-29 19:42:00
# Interval 2: 2021-09-29 19:39:37 to 2021-09-29 20:28:23
#
# Overlap detected for ID 516:
# Interval 1: 2021-05-16 19:00:00 to 2021-05-16 20:00:00
# Interval 2: 2021-05-16 19:41:14 to 2021-05-16 19:49:48
#
# Overlap detected for ID 516:
# Interval 1: 2021-05-17 07:30:00 to 2021-05-17 13:00:00
# Interval 2: 2021-05-17 10:23:31 to 2021-05-17 10:30:45
#
# Overlap detected for ID 516:
# Interval 1: 2021-05-18 07:20:00 to 2021-05-18 13:20:00
# Interval 2: 2021-05-18 10:14:23 to 2021-05-18 10:20:47
#
# Overlap detected for ID 517:
# Interval 1: 2021-09-01 11:30:00 to 2021-09-01 12:30:00
# Interval 2: 2021-09-01 12:13:24 to 2021-09-01 12:53:24
#
# Overlap detected for ID 518:
# Interval 1: 2021-07-31 15:45:00 to 2021-07-31 16:05:00
# Interval 2: 2021-07-31 15:47:25 to 2021-07-31 16:06:59
#
# Overlap detected for ID 518:
# Interval 1: 2021-07-31 16:50:00 to 2021-07-31 17:15:00
# Interval 2: 2021-07-31 16:53:29 to 2021-07-31 17:19:44
#
# Overlap detected for ID 518:
# Interval 1: 2021-08-01 13:39:00 to 2021-08-01 13:59:00
# Interval 2: 2021-08-01 13:39:34 to 2021-08-01 13:59:55
#
# Overlap detected for ID 518:
# Interval 1: 2021-08-01 14:47:00 to 2021-08-01 15:12:00
# Interval 2: 2021-08-01 14:47:30 to 2021-08-01 16:37:21
#
# Overlap detected for ID 518:
# Interval 1: 2021-08-02 13:34:00 to 2021-08-02 13:49:00
# Interval 2: 2021-08-02 13:34:53 to 2021-08-02 13:48:51
#
# Overlap detected for ID 520:
# Interval 1: 2021-10-31 18:15:00 to 2021-11-01 00:15:00
# Interval 2: 2021-10-31 19:18:59 to 2021-10-31 19:25:37
#
# Overlap detected for ID 520:
# Interval 1: 2021-11-01 16:11:49 to 2021-11-01 16:22:19
# Interval 2: 2021-11-01 16:15:00 to 2021-11-01 18:30:00
#
# Overlap detected for ID 520:
# Interval 1: 2021-11-03 08:42:06 to 2021-11-03 20:58:52
# Interval 2: 2021-11-03 20:21:32 to 2021-11-03 20:41:32
#
# Overlap detected for ID 521:
# Interval 1: 2022-03-24 07:56:50 to 2022-03-24 08:07:37
# Interval 2: 2022-03-24 08:00:00 to 2022-03-24 08:40:00
#
# Overlap detected for ID 522:
# Interval 1: 2020-11-25 18:40:00 to 2020-11-25 19:05:00
# Interval 2: 2020-11-25 18:52:31 to 2020-11-25 19:03:12
#
# Overlap detected for ID 522:
# Interval 1: 2020-11-26 15:34:00 to 2020-11-26 16:04:00
# Interval 2: 2020-11-26 15:38:54 to 2020-11-26 15:51:52
#
# Overlap detected for ID 522:
# Interval 1: 2020-11-26 15:34:00 to 2020-11-26 16:04:00
# Interval 2: 2020-11-26 15:55:46 to 2020-11-26 16:04:16
#
# Overlap detected for ID 522:
# Interval 1: 2020-11-28 15:37:00 to 2020-11-28 16:22:00
# Interval 2: 2020-11-28 16:07:05 to 2020-11-28 16:14:10
#
# Overlap detected for ID 522:
# Interval 1: 2020-12-01 19:20:00 to 2020-12-01 19:50:00
# Interval 2: 2020-12-01 19:24:49 to 2020-12-01 19:35:36
#
# Overlap detected for ID 525:
# Interval 1: 2021-03-12 15:43:00 to 2021-03-12 16:33:00
# Interval 2: 2021-03-12 15:48:01 to 2021-03-12 16:06:21
#
# Overlap detected for ID 526:
# Interval 1: 2022-04-30 19:15:00 to 2022-04-30 19:45:00
# Interval 2: 2022-04-30 19:36:04 to 2022-04-30 19:42:08
#
# Overlap detected for ID 526:
# Interval 1: 2022-05-06 15:51:00 to 2022-05-06 17:51:00
# Interval 2: 2022-05-06 16:06:18 to 2022-05-06 16:12:43
#
# Overlap detected for ID 526:
# Interval 1: 2022-05-06 15:51:00 to 2022-05-06 17:51:00
# Interval 2: 2022-05-06 16:45:28 to 2022-05-06 17:08:53
#
# Overlap detected for ID 533:
# Interval 1: 2021-06-27 13:59:28 to 2021-06-27 14:01:18
# Interval 2: 2021-06-27 14:00:00 to 2021-06-27 15:00:00
#
# Overlap detected for ID 533:
# Interval 1: 2021-06-28 13:05:00 to 2021-06-28 13:15:00
# Interval 2: 2021-06-28 13:07:13 to 2021-06-28 13:17:16
#
# Overlap detected for ID 535:
# Interval 1: 2021-10-07 10:25:00 to 2021-10-07 11:25:00
# Interval 2: 2021-10-07 11:02:59 to 2021-10-07 11:11:14
#
# Overlap detected for ID 535:
# Interval 1: 2021-10-12 12:30:00 to 2021-10-12 14:10:00
# Interval 2: 2021-10-12 13:38:39 to 2021-10-12 14:06:37
#
# Overlap detected for ID 535:
# Interval 1: 2021-10-14 10:00:00 to 2021-10-14 11:00:00
# Interval 2: 2021-10-14 10:06:57 to 2021-10-14 10:22:02
#
# Overlap detected for ID 540:
# Interval 1: 2021-05-12 18:08:41 to 2021-05-12 18:23:49
# Interval 2: 2021-05-12 18:10:00 to 2021-05-12 18:25:00
#
# Overlap detected for ID 540:
# Interval 1: 2021-05-15 20:30:00 to 2021-05-15 20:40:00
# Interval 2: 2021-05-15 20:32:49 to 2021-05-15 20:38:17
#
# Overlap detected for ID 540:
# Interval 1: 2021-05-16 18:43:35 to 2021-05-16 18:56:09
# Interval 2: 2021-05-16 18:45:00 to 2021-05-16 19:00:00
#
# Overlap detected for ID 540:
# Interval 1: 2021-05-17 14:50:00 to 2021-05-17 16:35:00
# Interval 2: 2021-05-17 15:57:13 to 2021-05-17 16:03:26

# %%
exdi.shape[0]
# Out:
# 5988

# %% [markdown]
# ### 4.1.3. Convert intensity

# %%
# Mappings
intensity_dict = {'Low: Pretty easy': 0, 
                  'Feeling the burn - Mild':0,
                  'Mild: Working a bit':0,
                  'Moderate: Working to keep up':1,
                  'Heavy: Hard to keep going but did it':2,
                  'Exhaustive: Too tough/Had to stop':2
                  }
# Replace
exdi.intensity = exdi.intensity.replace(intensity_dict)

# %%
# Reset index
exdi.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 4.1.5. Type of exercise

# %%
# Convert form_of_exercise
exdi['form_of_exercise'] = exdi.type_of_exercise.apply(lambda x: 
                                                       preprocess_helper.divide_exercise_into_type(x))
# Out:
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# other
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# other
# other
# other
# other
# other
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# other
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor
# physical labor

# %%
# Removing bouts that aren't really exercise
#exdi.dropna(subset=['form_of_exercise'], inplace=True)

# %%
exdi.shape
# Out:
# (5988, 11)

# %% [markdown]
# ## 4.2. Clean and combine CGM files

# %%
# Upload directory for individual data
lb = pd.read_csv(directory+'lb.csv')

# Select CGM readings
cgm = lb.loc[lb['LBCAT']=='CGM']

# Convert timestamp to datetime
cgm['LBDTC'] = pd.to_datetime(cgm['LBDTC'])

# Select and rename columns 
cgm = cgm[['USUBJID', 'LBDTC', 'LBORRES']]
cgm.columns = ['ID', 'time', 'glc']

# Drop any null 
cgm.dropna(inplace=True)

# Convert glucose to mg/dl
cgm['glc'] = (cgm['glc']/18).round(2)

# ID to int for concatenation
cgm['ID'] = cgm['ID'].astype(int)

# %%
visualizations.glucose_trace(cgm, 107)

# %% [markdown]
# ## 4.3. Lab & demographic data

# %%
# Read file
demographics = pd.read_csv(directory+'dm.csv')

# Select and rename columns
demo = demographics[['USUBJID', 'AGE', 'SEX', 'RACE']]
demo.columns = ['ID', 'age', 'sex', 'race']

demo = demo.dropna(subset=['ID'])
# Replace m/f values
demo['sex'] = demo['sex'].replace({'M':'male', 'F':'female'})

# ID as int for concatenation
demo['ID'] = demo['ID'].astype(int)

# %% [markdown]
# ### 4.3.1. Calculate hba1c

# %%
# Select the hba1c results from the tests file
hba1c = lb.loc[lb['LBTESTCD']=='HBA1C']

# Make id int for concatenation
hba1c['USUBJID'] = hba1c['USUBJID'].astype(int)

# Select and rename columns
hba1c = hba1c[['USUBJID', 'LBORRES']]
hba1c.columns = ['ID', 'hba1c']

# Convert to mmol/mol
hba1c['hba1c'] =(hba1c['hba1c'] -2.15)*10.929

# %% [markdown]
# ### 4.3.2. Calculate diabetes onset

# %%
# Set up list for results
fa_data = []

# Read file
fa = pd.read_sas(directory+'FA.xpt', encoding='utf-8',chunksize=10000, iterator=True)

# %%
# Read the file in chunks because it's so massive
for chunk in fa:
    chunk = chunk.loc[chunk['FAOBJ']== "DIABETES ONSET"]
    if chunk.shape[0]==0:
        continue
    fa_data.append(chunk[['USUBJID', 'FASTRESN']])

# %%
# Concat all the chunks
fa_data=pd.concat(fa_data)

# Rename coluns
fa_data.columns = ['ID', 'years_since_diagnosis']

# Make id int for concatenation
fa_data['ID'] = fa_data['ID'].astype(int)

# %% [markdown]
# ### 4.3.3. Calculate BMI

# %%
# Set up list for results
vs_data=[]

# Read file
vs = pd.read_sas(directory+'VS.xpt', encoding='utf-8',chunksize=10000, iterator=True)

# %%
# Read the file in chunks because it's so massive
for chunk in vs:
    chunk = chunk.loc[(chunk['VSTESTCD']== 'HEIGHT') | (chunk['VSTESTCD']=='WEIGHT')]
    if chunk.shape[0]==0:
        continue
    vs_data.append(chunk[['USUBJID', 'VSTESTCD', 'VSORRES']])

# %%
# Concat all the chunks
vs_data= pd.concat(vs_data)

# Make it the right way round
vs_data_adj = vs_data.pivot(columns='VSTESTCD', index='USUBJID')

vs_data_adj.columns = ['h', 'w']

#Calculate bmi
vs_data_adj['bmi'] = (703*vs_data_adj['w'])/(vs_data_adj['h']*vs_data_adj['h'])

# Reset index
vs_data_adj = vs_data_adj.reset_index()

# Select only id and bmi and rename
bmi = vs_data_adj[['USUBJID', 'bmi']]
bmi.columns = ['ID', 'bmi']

# Make id int for concatenatin
bmi['ID'] = bmi['ID'].astype(int)

# %% [markdown]
# ## 4.4. Insulin modality

# %%
# Read file
dx = pd.read_sas(directory+'DX.xpt', encoding='utf-8')

# %%
# Rename values
insulin_modality = dx[dx['DXCAT']=='INSULIN MODALITY'][['USUBJID', 'DXTRT']].replace({'MULTIPLE DAILY INJECTIONS': 'mdi', 
                                                                                      'INSULIN PUMP':'pump', 
                                                                                      'CLOSED LOOP INSULIN PUMP':'closed_loop'})

# %%
# Rename columns
insulin_modality.columns = ['ID', 'insulin_modality']

# Convert ID to int for concatenation
insulin_modality['ID'] = insulin_modality['ID'].astype(int)

# %% [markdown]
# ## 4.5. Combine all dfs

# %%
# List of all dfs
dfs = [demo, hba1c, bmi, fa_data, insulin_modality]

# Merge them all
demo_lab = ft.reduce(lambda left, right: pd.merge(left, right, on='ID', how='outer'), dfs)

# %%
# Add 'dexip' to IDs to make them unique
for i in [exdi, cgm, demo_lab]:
    i['ID'] = i['ID'].apply(lambda row: 'dexip_'+str(row))

# %% [markdown]
# ## 2.4. Save files

# %%
df_directory = '../../data/tidy_data/dexip/'
exdi.to_csv(df_directory+'exercise.csv', index=False)
cgm.to_csv(df_directory+'cgm.csv', index=False)
demo_lab.to_csv(df_directory+'demo_lab.csv', index=False)
