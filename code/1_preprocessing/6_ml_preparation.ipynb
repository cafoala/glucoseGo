# %% [markdown]
# # 6. Final preparation for machine learning
# Before delving into the machine learning modeling, it's pivotal to ensure that the data is adequately cleaned, processed, and formatted. This section delineates the steps undertaken to finalize the data in preparation for model training and validation.
# Highlights:
#
# * Data Importing: Leveraging libraries such as pandas and numpy, the DEXIP study data is loaded and initialized.
#
# * Target Variables: Two distinct binary target variables (y & y_3) are crafted, stemming from glucose level thresholds. Additionally, a 'stratify' column is introduced, marrying participant ID with the y_3 target, to aid in stratified sampling later on.
#
# * Data Trimming: Emphasis is placed on data quality. Rows deficient in data (less than 60% sufficiency) are pruned, and columns with over 20% missing data are cast aside. Furthermore, rows lacking key columns like start_glc and duration are eradicated.
#
# * Data Refinement: Innovative features like 'season' are derived from existing ones, offering richer data for modeling. Certain columns, mostly timestamps, are processed and converted to a numeric format.
#
# * Tidying & Saving Data: A series of operations—including resetting indices, discarding superfluous columns, replacing infinite values, creating dummy variables for categorical columns, and employing KNN imputation for missing values—culminates in the final data. The finished dataframe, along with other critical components like feature matrix (X) and target vector (y), is archived for subsequent use.
#
# With the data now in its prime, it paves the way for the ensuing phase: machine learning modeling.

# %% [markdown]
# ## 6.0. Import packages and load data

# %%
import pandas as pd
import numpy as np
import preprocess_helper
import sys
from sklearn.impute import KNNImputer
path = "../../diametrics"
sys.path.append(path)

# %%
df = pd.read_csv('../../data/tidy_data/data_with_targets_dexip.csv')

# %%
df[(df['duration']>=10) | (df['duration']<=120)].shape
# Out:
# (20420, 853)

# %%
[i for i in df.columns]
# Out:
# ['ID',
#  'start_datetime',
#  'finish_datetime',
#  'intensity',
#  'type_of_exercise',
#  'starting_glucose',
#  'finishing_glucose',
#  'month',
#  'day',
#  'day_of_week',
#  'time_of_day',
#  'duration',
#  'form_of_exercise',
#  'interval',
#  'study',
#  'bout_id',
#  'start_glc',
#  'start_roc',
#  'y',
#  'age',
#  'sex',
#  'race',
#  'hba1c',
#  'bmi',
#  'years_since_diagnosis',
#  'insulin_modality',
#  'urine_cpep',
#  'urine_creat',
#  'chol',
#  'cpep',
#  'h_index',
#  'hdl',
#  'ldl',
#  'nhdl',
#  'trig',
#  'data_suff_during',
#  'before_data_suff',
#  'Average glucose (mmol/L)',
#  'eA1c (%)',
#  'SD (mmol/L)',
#  'CV (%)',
#  'AUC (mmol h/L)',
#  'LBGI',
#  'HBGI',
#  'MAGE (mmol/L)',
#  'TIR normal (%)',
#  'TIR normal 1 (%)',
#  'TIR normal 2 (%)',
#  'TIR level 1 hypoglycemia (%)',
#  'TIR level 2 hypoglycemia (%)',
#  'TIR level 1 hyperglycemia (%)',
#  'TIR level 2 hyperglycemia (%)',
#  'Total number hypoglycemic events',
#  'Number LV1 hypoglycemic events',
#  'Number LV2 hypoglycemic events',
#  'Number prolonged hypoglycemic events',
#  'Avg. length of hypoglycemic events',
#  'Total time spent in hypoglycemic events',
#  'Total number hyperglycemic events',
#  'Number LV1 hyperglycemic events',
#  'Number LV2 hyperglycemic events',
#  'Number prolonged hyperglycemic events',
#  'Avg. length of hyperglycemic events',
#  'Total time spent in hyperglycemic events',
#  'glc__variance_larger_than_standard_deviation',
#  'glc__has_duplicate_max',
#  'glc__has_duplicate_min',
#  'glc__has_duplicate',
#  'glc__sum_values',
#  'glc__abs_energy',
#  'glc__mean_abs_change',
#  'glc__mean_change',
#  'glc__mean_second_derivative_central',
#  'glc__median',
#  'glc__mean',
#  'glc__length',
#  'glc__standard_deviation',
#  'glc__variation_coefficient',
#  'glc__variance',
#  'glc__skewness',
#  'glc__kurtosis',
#  'glc__root_mean_square',
#  'glc__absolute_sum_of_changes',
#  'glc__longest_strike_below_mean',
#  'glc__longest_strike_above_mean',
#  'glc__count_above_mean',
#  'glc__count_below_mean',
#  'glc__last_location_of_maximum',
#  'glc__first_location_of_maximum',
#  'glc__last_location_of_minimum',
#  'glc__first_location_of_minimum',
#  'glc__percentage_of_reoccurring_values_to_all_values',
#  'glc__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'glc__sum_of_reoccurring_values',
#  'glc__sum_of_reoccurring_data_points',
#  'glc__ratio_value_number_to_time_series_length',
#  'glc__sample_entropy',
#  'glc__maximum',
#  'glc__absolute_maximum',
#  'glc__minimum',
#  'glc__benford_correlation',
#  'glc__time_reversal_asymmetry_statistic__lag_1',
#  'glc__time_reversal_asymmetry_statistic__lag_2',
#  'glc__time_reversal_asymmetry_statistic__lag_3',
#  'glc__c3__lag_1',
#  'glc__c3__lag_2',
#  'glc__c3__lag_3',
#  'glc__cid_ce__normalize_True',
#  'glc__cid_ce__normalize_False',
#  'glc__symmetry_looking__r_0.0',
#  'glc__symmetry_looking__r_0.05',
#  'glc__symmetry_looking__r_0.1',
#  'glc__symmetry_looking__r_0.15000000000000002',
#  'glc__symmetry_looking__r_0.2',
#  'glc__symmetry_looking__r_0.25',
#  'glc__symmetry_looking__r_0.30000000000000004',
#  'glc__symmetry_looking__r_0.35000000000000003',
#  'glc__symmetry_looking__r_0.4',
#  'glc__symmetry_looking__r_0.45',
#  'glc__symmetry_looking__r_0.5',
#  'glc__symmetry_looking__r_0.55',
#  'glc__symmetry_looking__r_0.6000000000000001',
#  'glc__symmetry_looking__r_0.65',
#  'glc__symmetry_looking__r_0.7000000000000001',
#  'glc__symmetry_looking__r_0.75',
#  'glc__symmetry_looking__r_0.8',
#  'glc__symmetry_looking__r_0.8500000000000001',
#  'glc__symmetry_looking__r_0.9',
#  'glc__symmetry_looking__r_0.9500000000000001',
#  'glc__large_standard_deviation__r_0.05',
#  'glc__large_standard_deviation__r_0.1',
#  'glc__large_standard_deviation__r_0.15000000000000002',
#  'glc__large_standard_deviation__r_0.2',
#  'glc__large_standard_deviation__r_0.25',
#  'glc__large_standard_deviation__r_0.30000000000000004',
#  'glc__large_standard_deviation__r_0.35000000000000003',
#  'glc__large_standard_deviation__r_0.4',
#  'glc__large_standard_deviation__r_0.45',
#  'glc__large_standard_deviation__r_0.5',
#  'glc__large_standard_deviation__r_0.55',
#  'glc__large_standard_deviation__r_0.6000000000000001',
#  'glc__large_standard_deviation__r_0.65',
#  'glc__large_standard_deviation__r_0.7000000000000001',
#  'glc__large_standard_deviation__r_0.75',
#  'glc__large_standard_deviation__r_0.8',
#  'glc__large_standard_deviation__r_0.8500000000000001',
#  'glc__large_standard_deviation__r_0.9',
#  'glc__large_standard_deviation__r_0.9500000000000001',
#  'glc__quantile__q_0.1',
#  'glc__quantile__q_0.2',
#  'glc__quantile__q_0.3',
#  'glc__quantile__q_0.4',
#  'glc__quantile__q_0.6',
#  'glc__quantile__q_0.7',
#  'glc__quantile__q_0.8',
#  'glc__quantile__q_0.9',
#  'glc__autocorrelation__lag_0',
#  'glc__autocorrelation__lag_1',
#  'glc__autocorrelation__lag_2',
#  'glc__autocorrelation__lag_3',
#  'glc__autocorrelation__lag_4',
#  'glc__autocorrelation__lag_5',
#  'glc__autocorrelation__lag_6',
#  'glc__autocorrelation__lag_7',
#  'glc__autocorrelation__lag_8',
#  'glc__autocorrelation__lag_9',
#  'glc__agg_autocorrelation__f_agg_"mean"__maxlag_40',
#  'glc__agg_autocorrelation__f_agg_"median"__maxlag_40',
#  'glc__agg_autocorrelation__f_agg_"var"__maxlag_40',
#  'glc__partial_autocorrelation__lag_0',
#  'glc__partial_autocorrelation__lag_1',
#  'glc__partial_autocorrelation__lag_2',
#  'glc__partial_autocorrelation__lag_3',
#  'glc__partial_autocorrelation__lag_4',
#  'glc__partial_autocorrelation__lag_5',
#  'glc__partial_autocorrelation__lag_6',
#  'glc__partial_autocorrelation__lag_7',
#  'glc__partial_autocorrelation__lag_8',
#  'glc__partial_autocorrelation__lag_9',
#  'glc__number_cwt_peaks__n_1',
#  'glc__number_cwt_peaks__n_5',
#  'glc__number_peaks__n_1',
#  'glc__number_peaks__n_3',
#  'glc__number_peaks__n_5',
#  'glc__number_peaks__n_10',
#  'glc__number_peaks__n_50',
#  'glc__binned_entropy__max_bins_10',
#  'glc__index_mass_quantile__q_0.1',
#  'glc__index_mass_quantile__q_0.2',
#  'glc__index_mass_quantile__q_0.3',
#  'glc__index_mass_quantile__q_0.4',
#  'glc__index_mass_quantile__q_0.6',
#  'glc__index_mass_quantile__q_0.7',
#  'glc__index_mass_quantile__q_0.8',
#  'glc__index_mass_quantile__q_0.9',
#  'glc__cwt_coefficients__coeff_0__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_0__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_1__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_2__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_2__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_3__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_4__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_5__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_5__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_6__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_6__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_7__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_7__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_8__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_8__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_9__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_9__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_10__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_11__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_11__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_12__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_12__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_12__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_13__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_13__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_13__w_20__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_14__w_2__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_14__w_5__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_14__w_10__widths_(2, 5, 10, 20)',
#  'glc__cwt_coefficients__coeff_14__w_20__widths_(2, 5, 10, 20)',
#  'glc__spkt_welch_density__coeff_2',
#  'glc__spkt_welch_density__coeff_5',
#  'glc__spkt_welch_density__coeff_8',
#  'glc__ar_coefficient__coeff_0__k_10',
#  'glc__ar_coefficient__coeff_1__k_10',
#  'glc__ar_coefficient__coeff_2__k_10',
#  'glc__ar_coefficient__coeff_3__k_10',
#  'glc__ar_coefficient__coeff_4__k_10',
#  'glc__ar_coefficient__coeff_5__k_10',
#  'glc__ar_coefficient__coeff_6__k_10',
#  'glc__ar_coefficient__coeff_7__k_10',
#  'glc__ar_coefficient__coeff_8__k_10',
#  'glc__ar_coefficient__coeff_9__k_10',
#  'glc__ar_coefficient__coeff_10__k_10',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.2',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.2',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.2',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.4',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.4',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.6',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.6',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.6',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  'glc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8',
#  'glc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#  'glc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  'glc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#  'glc__fft_coefficient__attr_"real"__coeff_0',
#  'glc__fft_coefficient__attr_"real"__coeff_1',
#  'glc__fft_coefficient__attr_"real"__coeff_2',
#  'glc__fft_coefficient__attr_"real"__coeff_3',
#  'glc__fft_coefficient__attr_"real"__coeff_4',
#  'glc__fft_coefficient__attr_"real"__coeff_5',
#  'glc__fft_coefficient__attr_"real"__coeff_6',
#  'glc__fft_coefficient__attr_"real"__coeff_7',
#  'glc__fft_coefficient__attr_"real"__coeff_8',
#  'glc__fft_coefficient__attr_"real"__coeff_9',
#  'glc__fft_coefficient__attr_"real"__coeff_10',
#  'glc__fft_coefficient__attr_"real"__coeff_11',
#  'glc__fft_coefficient__attr_"real"__coeff_12',
#  'glc__fft_coefficient__attr_"real"__coeff_13',
#  'glc__fft_coefficient__attr_"real"__coeff_14',
#  'glc__fft_coefficient__attr_"real"__coeff_15',
#  'glc__fft_coefficient__attr_"real"__coeff_16',
#  'glc__fft_coefficient__attr_"real"__coeff_17',
#  'glc__fft_coefficient__attr_"real"__coeff_18',
#  'glc__fft_coefficient__attr_"real"__coeff_19',
#  'glc__fft_coefficient__attr_"real"__coeff_20',
#  'glc__fft_coefficient__attr_"real"__coeff_21',
#  'glc__fft_coefficient__attr_"real"__coeff_22',
#  'glc__fft_coefficient__attr_"real"__coeff_23',
#  'glc__fft_coefficient__attr_"real"__coeff_24',
#  'glc__fft_coefficient__attr_"real"__coeff_25',
#  'glc__fft_coefficient__attr_"real"__coeff_26',
#  'glc__fft_coefficient__attr_"real"__coeff_27',
#  'glc__fft_coefficient__attr_"real"__coeff_28',
#  'glc__fft_coefficient__attr_"real"__coeff_29',
#  'glc__fft_coefficient__attr_"real"__coeff_30',
#  'glc__fft_coefficient__attr_"real"__coeff_31',
#  'glc__fft_coefficient__attr_"real"__coeff_32',
#  'glc__fft_coefficient__attr_"real"__coeff_33',
#  'glc__fft_coefficient__attr_"real"__coeff_34',
#  'glc__fft_coefficient__attr_"real"__coeff_35',
#  'glc__fft_coefficient__attr_"real"__coeff_36',
#  'glc__fft_coefficient__attr_"real"__coeff_37',
#  'glc__fft_coefficient__attr_"real"__coeff_38',
#  'glc__fft_coefficient__attr_"real"__coeff_39',
#  'glc__fft_coefficient__attr_"real"__coeff_40',
#  'glc__fft_coefficient__attr_"real"__coeff_41',
#  'glc__fft_coefficient__attr_"real"__coeff_42',
#  'glc__fft_coefficient__attr_"real"__coeff_43',
#  'glc__fft_coefficient__attr_"real"__coeff_44',
#  'glc__fft_coefficient__attr_"real"__coeff_45',
#  'glc__fft_coefficient__attr_"real"__coeff_46',
#  'glc__fft_coefficient__attr_"real"__coeff_47',
#  'glc__fft_coefficient__attr_"real"__coeff_48',
#  'glc__fft_coefficient__attr_"real"__coeff_49',
#  'glc__fft_coefficient__attr_"real"__coeff_50',
#  'glc__fft_coefficient__attr_"real"__coeff_51',
#  'glc__fft_coefficient__attr_"real"__coeff_52',
#  'glc__fft_coefficient__attr_"real"__coeff_53',
#  'glc__fft_coefficient__attr_"real"__coeff_54',
#  'glc__fft_coefficient__attr_"real"__coeff_55',
#  'glc__fft_coefficient__attr_"real"__coeff_56',
#  'glc__fft_coefficient__attr_"real"__coeff_57',
#  'glc__fft_coefficient__attr_"real"__coeff_58',
#  'glc__fft_coefficient__attr_"real"__coeff_59',
#  'glc__fft_coefficient__attr_"real"__coeff_60',
#  'glc__fft_coefficient__attr_"real"__coeff_61',
#  'glc__fft_coefficient__attr_"real"__coeff_62',
#  'glc__fft_coefficient__attr_"real"__coeff_63',
#  'glc__fft_coefficient__attr_"real"__coeff_64',
#  'glc__fft_coefficient__attr_"real"__coeff_65',
#  'glc__fft_coefficient__attr_"real"__coeff_66',
#  'glc__fft_coefficient__attr_"real"__coeff_67',
#  'glc__fft_coefficient__attr_"real"__coeff_68',
#  'glc__fft_coefficient__attr_"real"__coeff_69',
#  'glc__fft_coefficient__attr_"real"__coeff_70',
#  'glc__fft_coefficient__attr_"real"__coeff_71',
#  'glc__fft_coefficient__attr_"real"__coeff_72',
#  'glc__fft_coefficient__attr_"real"__coeff_73',
#  'glc__fft_coefficient__attr_"real"__coeff_74',
#  'glc__fft_coefficient__attr_"real"__coeff_75',
#  'glc__fft_coefficient__attr_"real"__coeff_76',
#  'glc__fft_coefficient__attr_"real"__coeff_77',
#  'glc__fft_coefficient__attr_"real"__coeff_78',
#  'glc__fft_coefficient__attr_"real"__coeff_79',
#  'glc__fft_coefficient__attr_"real"__coeff_80',
#  'glc__fft_coefficient__attr_"real"__coeff_81',
#  'glc__fft_coefficient__attr_"real"__coeff_82',
#  'glc__fft_coefficient__attr_"real"__coeff_83',
#  'glc__fft_coefficient__attr_"real"__coeff_84',
#  'glc__fft_coefficient__attr_"real"__coeff_85',
#  'glc__fft_coefficient__attr_"real"__coeff_86',
#  'glc__fft_coefficient__attr_"real"__coeff_87',
#  'glc__fft_coefficient__attr_"real"__coeff_88',
#  'glc__fft_coefficient__attr_"real"__coeff_89',
#  'glc__fft_coefficient__attr_"real"__coeff_90',
#  'glc__fft_coefficient__attr_"real"__coeff_91',
#  'glc__fft_coefficient__attr_"real"__coeff_92',
#  'glc__fft_coefficient__attr_"real"__coeff_93',
#  'glc__fft_coefficient__attr_"real"__coeff_94',
#  'glc__fft_coefficient__attr_"real"__coeff_95',
#  'glc__fft_coefficient__attr_"real"__coeff_96',
#  'glc__fft_coefficient__attr_"real"__coeff_97',
#  'glc__fft_coefficient__attr_"real"__coeff_98',
#  'glc__fft_coefficient__attr_"real"__coeff_99',
#  'glc__fft_coefficient__attr_"imag"__coeff_0',
#  'glc__fft_coefficient__attr_"imag"__coeff_1',
#  'glc__fft_coefficient__attr_"imag"__coeff_2',
#  'glc__fft_coefficient__attr_"imag"__coeff_3',
#  'glc__fft_coefficient__attr_"imag"__coeff_4',
#  'glc__fft_coefficient__attr_"imag"__coeff_5',
#  'glc__fft_coefficient__attr_"imag"__coeff_6',
#  'glc__fft_coefficient__attr_"imag"__coeff_7',
#  'glc__fft_coefficient__attr_"imag"__coeff_8',
#  'glc__fft_coefficient__attr_"imag"__coeff_9',
#  'glc__fft_coefficient__attr_"imag"__coeff_10',
#  'glc__fft_coefficient__attr_"imag"__coeff_11',
#  'glc__fft_coefficient__attr_"imag"__coeff_12',
#  'glc__fft_coefficient__attr_"imag"__coeff_13',
#  'glc__fft_coefficient__attr_"imag"__coeff_14',
#  'glc__fft_coefficient__attr_"imag"__coeff_15',
#  'glc__fft_coefficient__attr_"imag"__coeff_16',
#  'glc__fft_coefficient__attr_"imag"__coeff_17',
#  'glc__fft_coefficient__attr_"imag"__coeff_18',
#  'glc__fft_coefficient__attr_"imag"__coeff_19',
#  'glc__fft_coefficient__attr_"imag"__coeff_20',
#  'glc__fft_coefficient__attr_"imag"__coeff_21',
#  'glc__fft_coefficient__attr_"imag"__coeff_22',
#  'glc__fft_coefficient__attr_"imag"__coeff_23',
#  'glc__fft_coefficient__attr_"imag"__coeff_24',
#  'glc__fft_coefficient__attr_"imag"__coeff_25',
#  'glc__fft_coefficient__attr_"imag"__coeff_26',
#  'glc__fft_coefficient__attr_"imag"__coeff_27',
#  'glc__fft_coefficient__attr_"imag"__coeff_28',
#  'glc__fft_coefficient__attr_"imag"__coeff_29',
#  'glc__fft_coefficient__attr_"imag"__coeff_30',
#  'glc__fft_coefficient__attr_"imag"__coeff_31',
#  'glc__fft_coefficient__attr_"imag"__coeff_32',
#  'glc__fft_coefficient__attr_"imag"__coeff_33',
#  'glc__fft_coefficient__attr_"imag"__coeff_34',
#  'glc__fft_coefficient__attr_"imag"__coeff_35',
#  'glc__fft_coefficient__attr_"imag"__coeff_36',
#  'glc__fft_coefficient__attr_"imag"__coeff_37',
#  'glc__fft_coefficient__attr_"imag"__coeff_38',
#  'glc__fft_coefficient__attr_"imag"__coeff_39',
#  'glc__fft_coefficient__attr_"imag"__coeff_40',
#  'glc__fft_coefficient__attr_"imag"__coeff_41',
#  'glc__fft_coefficient__attr_"imag"__coeff_42',
#  'glc__fft_coefficient__attr_"imag"__coeff_43',
#  'glc__fft_coefficient__attr_"imag"__coeff_44',
#  'glc__fft_coefficient__attr_"imag"__coeff_45',
#  'glc__fft_coefficient__attr_"imag"__coeff_46',
#  'glc__fft_coefficient__attr_"imag"__coeff_47',
#  'glc__fft_coefficient__attr_"imag"__coeff_48',
#  'glc__fft_coefficient__attr_"imag"__coeff_49',
#  'glc__fft_coefficient__attr_"imag"__coeff_50',
#  'glc__fft_coefficient__attr_"imag"__coeff_51',
#  'glc__fft_coefficient__attr_"imag"__coeff_52',
#  'glc__fft_coefficient__attr_"imag"__coeff_53',
#  'glc__fft_coefficient__attr_"imag"__coeff_54',
#  'glc__fft_coefficient__attr_"imag"__coeff_55',
#  'glc__fft_coefficient__attr_"imag"__coeff_56',
#  'glc__fft_coefficient__attr_"imag"__coeff_57',
#  'glc__fft_coefficient__attr_"imag"__coeff_58',
#  'glc__fft_coefficient__attr_"imag"__coeff_59',
#  'glc__fft_coefficient__attr_"imag"__coeff_60',
#  'glc__fft_coefficient__attr_"imag"__coeff_61',
#  'glc__fft_coefficient__attr_"imag"__coeff_62',
#  'glc__fft_coefficient__attr_"imag"__coeff_63',
#  'glc__fft_coefficient__attr_"imag"__coeff_64',
#  'glc__fft_coefficient__attr_"imag"__coeff_65',
#  'glc__fft_coefficient__attr_"imag"__coeff_66',
#  'glc__fft_coefficient__attr_"imag"__coeff_67',
#  'glc__fft_coefficient__attr_"imag"__coeff_68',
#  'glc__fft_coefficient__attr_"imag"__coeff_69',
#  'glc__fft_coefficient__attr_"imag"__coeff_70',
#  'glc__fft_coefficient__attr_"imag"__coeff_71',
#  'glc__fft_coefficient__attr_"imag"__coeff_72',
#  'glc__fft_coefficient__attr_"imag"__coeff_73',
#  'glc__fft_coefficient__attr_"imag"__coeff_74',
#  'glc__fft_coefficient__attr_"imag"__coeff_75',
#  'glc__fft_coefficient__attr_"imag"__coeff_76',
#  'glc__fft_coefficient__attr_"imag"__coeff_77',
#  'glc__fft_coefficient__attr_"imag"__coeff_78',
#  'glc__fft_coefficient__attr_"imag"__coeff_79',
#  'glc__fft_coefficient__attr_"imag"__coeff_80',
#  'glc__fft_coefficient__attr_"imag"__coeff_81',
#  'glc__fft_coefficient__attr_"imag"__coeff_82',
#  'glc__fft_coefficient__attr_"imag"__coeff_83',
#  'glc__fft_coefficient__attr_"imag"__coeff_84',
#  'glc__fft_coefficient__attr_"imag"__coeff_85',
#  'glc__fft_coefficient__attr_"imag"__coeff_86',
#  'glc__fft_coefficient__attr_"imag"__coeff_87',
#  'glc__fft_coefficient__attr_"imag"__coeff_88',
#  'glc__fft_coefficient__attr_"imag"__coeff_89',
#  'glc__fft_coefficient__attr_"imag"__coeff_90',
#  'glc__fft_coefficient__attr_"imag"__coeff_91',
#  'glc__fft_coefficient__attr_"imag"__coeff_92',
#  'glc__fft_coefficient__attr_"imag"__coeff_93',
#  'glc__fft_coefficient__attr_"imag"__coeff_94',
#  'glc__fft_coefficient__attr_"imag"__coeff_95',
#  'glc__fft_coefficient__attr_"imag"__coeff_96',
#  'glc__fft_coefficient__attr_"imag"__coeff_97',
#  'glc__fft_coefficient__attr_"imag"__coeff_98',
#  'glc__fft_coefficient__attr_"imag"__coeff_99',
#  'glc__fft_coefficient__attr_"abs"__coeff_0',
#  'glc__fft_coefficient__attr_"abs"__coeff_1',
#  'glc__fft_coefficient__attr_"abs"__coeff_2',
#  'glc__fft_coefficient__attr_"abs"__coeff_3',
#  'glc__fft_coefficient__attr_"abs"__coeff_4',
#  'glc__fft_coefficient__attr_"abs"__coeff_5',
#  'glc__fft_coefficient__attr_"abs"__coeff_6',
#  'glc__fft_coefficient__attr_"abs"__coeff_7',
#  'glc__fft_coefficient__attr_"abs"__coeff_8',
#  'glc__fft_coefficient__attr_"abs"__coeff_9',
#  'glc__fft_coefficient__attr_"abs"__coeff_10',
#  'glc__fft_coefficient__attr_"abs"__coeff_11',
#  'glc__fft_coefficient__attr_"abs"__coeff_12',
#  'glc__fft_coefficient__attr_"abs"__coeff_13',
#  'glc__fft_coefficient__attr_"abs"__coeff_14',
#  'glc__fft_coefficient__attr_"abs"__coeff_15',
#  'glc__fft_coefficient__attr_"abs"__coeff_16',
#  'glc__fft_coefficient__attr_"abs"__coeff_17',
#  'glc__fft_coefficient__attr_"abs"__coeff_18',
#  'glc__fft_coefficient__attr_"abs"__coeff_19',
#  'glc__fft_coefficient__attr_"abs"__coeff_20',
#  'glc__fft_coefficient__attr_"abs"__coeff_21',
#  'glc__fft_coefficient__attr_"abs"__coeff_22',
#  'glc__fft_coefficient__attr_"abs"__coeff_23',
#  'glc__fft_coefficient__attr_"abs"__coeff_24',
#  'glc__fft_coefficient__attr_"abs"__coeff_25',
#  'glc__fft_coefficient__attr_"abs"__coeff_26',
#  'glc__fft_coefficient__attr_"abs"__coeff_27',
#  'glc__fft_coefficient__attr_"abs"__coeff_28',
#  'glc__fft_coefficient__attr_"abs"__coeff_29',
#  'glc__fft_coefficient__attr_"abs"__coeff_30',
#  'glc__fft_coefficient__attr_"abs"__coeff_31',
#  'glc__fft_coefficient__attr_"abs"__coeff_32',
#  'glc__fft_coefficient__attr_"abs"__coeff_33',
#  'glc__fft_coefficient__attr_"abs"__coeff_34',
#  'glc__fft_coefficient__attr_"abs"__coeff_35',
#  'glc__fft_coefficient__attr_"abs"__coeff_36',
#  'glc__fft_coefficient__attr_"abs"__coeff_37',
#  'glc__fft_coefficient__attr_"abs"__coeff_38',
#  'glc__fft_coefficient__attr_"abs"__coeff_39',
#  'glc__fft_coefficient__attr_"abs"__coeff_40',
#  'glc__fft_coefficient__attr_"abs"__coeff_41',
#  'glc__fft_coefficient__attr_"abs"__coeff_42',
#  'glc__fft_coefficient__attr_"abs"__coeff_43',
#  'glc__fft_coefficient__attr_"abs"__coeff_44',
#  'glc__fft_coefficient__attr_"abs"__coeff_45',
#  'glc__fft_coefficient__attr_"abs"__coeff_46',
#  'glc__fft_coefficient__attr_"abs"__coeff_47',
#  'glc__fft_coefficient__attr_"abs"__coeff_48',
#  'glc__fft_coefficient__attr_"abs"__coeff_49',
#  'glc__fft_coefficient__attr_"abs"__coeff_50',
#  'glc__fft_coefficient__attr_"abs"__coeff_51',
#  'glc__fft_coefficient__attr_"abs"__coeff_52',
#  'glc__fft_coefficient__attr_"abs"__coeff_53',
#  'glc__fft_coefficient__attr_"abs"__coeff_54',
#  'glc__fft_coefficient__attr_"abs"__coeff_55',
#  'glc__fft_coefficient__attr_"abs"__coeff_56',
#  'glc__fft_coefficient__attr_"abs"__coeff_57',
#  'glc__fft_coefficient__attr_"abs"__coeff_58',
#  'glc__fft_coefficient__attr_"abs"__coeff_59',
#  'glc__fft_coefficient__attr_"abs"__coeff_60',
#  'glc__fft_coefficient__attr_"abs"__coeff_61',
#  'glc__fft_coefficient__attr_"abs"__coeff_62',
#  'glc__fft_coefficient__attr_"abs"__coeff_63',
#  'glc__fft_coefficient__attr_"abs"__coeff_64',
#  'glc__fft_coefficient__attr_"abs"__coeff_65',
#  'glc__fft_coefficient__attr_"abs"__coeff_66',
#  'glc__fft_coefficient__attr_"abs"__coeff_67',
#  'glc__fft_coefficient__attr_"abs"__coeff_68',
#  'glc__fft_coefficient__attr_"abs"__coeff_69',
#  'glc__fft_coefficient__attr_"abs"__coeff_70',
#  'glc__fft_coefficient__attr_"abs"__coeff_71',
#  'glc__fft_coefficient__attr_"abs"__coeff_72',
#  'glc__fft_coefficient__attr_"abs"__coeff_73',
#  'glc__fft_coefficient__attr_"abs"__coeff_74',
#  'glc__fft_coefficient__attr_"abs"__coeff_75',
#  'glc__fft_coefficient__attr_"abs"__coeff_76',
#  'glc__fft_coefficient__attr_"abs"__coeff_77',
#  'glc__fft_coefficient__attr_"abs"__coeff_78',
#  'glc__fft_coefficient__attr_"abs"__coeff_79',
#  'glc__fft_coefficient__attr_"abs"__coeff_80',
#  'glc__fft_coefficient__attr_"abs"__coeff_81',
#  'glc__fft_coefficient__attr_"abs"__coeff_82',
#  'glc__fft_coefficient__attr_"abs"__coeff_83',
#  'glc__fft_coefficient__attr_"abs"__coeff_84',
#  'glc__fft_coefficient__attr_"abs"__coeff_85',
#  'glc__fft_coefficient__attr_"abs"__coeff_86',
#  'glc__fft_coefficient__attr_"abs"__coeff_87',
#  'glc__fft_coefficient__attr_"abs"__coeff_88',
#  'glc__fft_coefficient__attr_"abs"__coeff_89',
#  'glc__fft_coefficient__attr_"abs"__coeff_90',
#  'glc__fft_coefficient__attr_"abs"__coeff_91',
#  'glc__fft_coefficient__attr_"abs"__coeff_92',
#  'glc__fft_coefficient__attr_"abs"__coeff_93',
#  'glc__fft_coefficient__attr_"abs"__coeff_94',
#  'glc__fft_coefficient__attr_"abs"__coeff_95',
#  'glc__fft_coefficient__attr_"abs"__coeff_96',
#  'glc__fft_coefficient__attr_"abs"__coeff_97',
#  'glc__fft_coefficient__attr_"abs"__coeff_98',
#  'glc__fft_coefficient__attr_"abs"__coeff_99',
#  'glc__fft_coefficient__attr_"angle"__coeff_0',
#  'glc__fft_coefficient__attr_"angle"__coeff_1',
#  'glc__fft_coefficient__attr_"angle"__coeff_2',
#  'glc__fft_coefficient__attr_"angle"__coeff_3',
#  'glc__fft_coefficient__attr_"angle"__coeff_4',
#  'glc__fft_coefficient__attr_"angle"__coeff_5',
#  'glc__fft_coefficient__attr_"angle"__coeff_6',
#  'glc__fft_coefficient__attr_"angle"__coeff_7',
#  'glc__fft_coefficient__attr_"angle"__coeff_8',
#  'glc__fft_coefficient__attr_"angle"__coeff_9',
#  'glc__fft_coefficient__attr_"angle"__coeff_10',
#  'glc__fft_coefficient__attr_"angle"__coeff_11',
#  'glc__fft_coefficient__attr_"angle"__coeff_12',
#  'glc__fft_coefficient__attr_"angle"__coeff_13',
#  'glc__fft_coefficient__attr_"angle"__coeff_14',
#  'glc__fft_coefficient__attr_"angle"__coeff_15',
#  'glc__fft_coefficient__attr_"angle"__coeff_16',
#  'glc__fft_coefficient__attr_"angle"__coeff_17',
#  'glc__fft_coefficient__attr_"angle"__coeff_18',
#  'glc__fft_coefficient__attr_"angle"__coeff_19',
#  'glc__fft_coefficient__attr_"angle"__coeff_20',
#  'glc__fft_coefficient__attr_"angle"__coeff_21',
#  'glc__fft_coefficient__attr_"angle"__coeff_22',
#  'glc__fft_coefficient__attr_"angle"__coeff_23',
#  'glc__fft_coefficient__attr_"angle"__coeff_24',
#  'glc__fft_coefficient__attr_"angle"__coeff_25',
#  'glc__fft_coefficient__attr_"angle"__coeff_26',
#  'glc__fft_coefficient__attr_"angle"__coeff_27',
#  'glc__fft_coefficient__attr_"angle"__coeff_28',
#  'glc__fft_coefficient__attr_"angle"__coeff_29',
#  'glc__fft_coefficient__attr_"angle"__coeff_30',
#  'glc__fft_coefficient__attr_"angle"__coeff_31',
#  'glc__fft_coefficient__attr_"angle"__coeff_32',
#  'glc__fft_coefficient__attr_"angle"__coeff_33',
#  'glc__fft_coefficient__attr_"angle"__coeff_34',
#  'glc__fft_coefficient__attr_"angle"__coeff_35',
#  'glc__fft_coefficient__attr_"angle"__coeff_36',
#  'glc__fft_coefficient__attr_"angle"__coeff_37',
#  'glc__fft_coefficient__attr_"angle"__coeff_38',
#  'glc__fft_coefficient__attr_"angle"__coeff_39',
#  'glc__fft_coefficient__attr_"angle"__coeff_40',
#  'glc__fft_coefficient__attr_"angle"__coeff_41',
#  'glc__fft_coefficient__attr_"angle"__coeff_42',
#  'glc__fft_coefficient__attr_"angle"__coeff_43',
#  'glc__fft_coefficient__attr_"angle"__coeff_44',
#  'glc__fft_coefficient__attr_"angle"__coeff_45',
#  'glc__fft_coefficient__attr_"angle"__coeff_46',
#  'glc__fft_coefficient__attr_"angle"__coeff_47',
#  'glc__fft_coefficient__attr_"angle"__coeff_48',
#  'glc__fft_coefficient__attr_"angle"__coeff_49',
#  'glc__fft_coefficient__attr_"angle"__coeff_50',
#  'glc__fft_coefficient__attr_"angle"__coeff_51',
#  'glc__fft_coefficient__attr_"angle"__coeff_52',
#  'glc__fft_coefficient__attr_"angle"__coeff_53',
#  'glc__fft_coefficient__attr_"angle"__coeff_54',
#  'glc__fft_coefficient__attr_"angle"__coeff_55',
#  'glc__fft_coefficient__attr_"angle"__coeff_56',
#  'glc__fft_coefficient__attr_"angle"__coeff_57',
#  'glc__fft_coefficient__attr_"angle"__coeff_58',
#  'glc__fft_coefficient__attr_"angle"__coeff_59',
#  'glc__fft_coefficient__attr_"angle"__coeff_60',
#  'glc__fft_coefficient__attr_"angle"__coeff_61',
#  'glc__fft_coefficient__attr_"angle"__coeff_62',
#  'glc__fft_coefficient__attr_"angle"__coeff_63',
#  'glc__fft_coefficient__attr_"angle"__coeff_64',
#  'glc__fft_coefficient__attr_"angle"__coeff_65',
#  'glc__fft_coefficient__attr_"angle"__coeff_66',
#  'glc__fft_coefficient__attr_"angle"__coeff_67',
#  'glc__fft_coefficient__attr_"angle"__coeff_68',
#  'glc__fft_coefficient__attr_"angle"__coeff_69',
#  'glc__fft_coefficient__attr_"angle"__coeff_70',
#  'glc__fft_coefficient__attr_"angle"__coeff_71',
#  'glc__fft_coefficient__attr_"angle"__coeff_72',
#  'glc__fft_coefficient__attr_"angle"__coeff_73',
#  'glc__fft_coefficient__attr_"angle"__coeff_74',
#  'glc__fft_coefficient__attr_"angle"__coeff_75',
#  'glc__fft_coefficient__attr_"angle"__coeff_76',
#  'glc__fft_coefficient__attr_"angle"__coeff_77',
#  'glc__fft_coefficient__attr_"angle"__coeff_78',
#  'glc__fft_coefficient__attr_"angle"__coeff_79',
#  'glc__fft_coefficient__attr_"angle"__coeff_80',
#  'glc__fft_coefficient__attr_"angle"__coeff_81',
#  'glc__fft_coefficient__attr_"angle"__coeff_82',
#  'glc__fft_coefficient__attr_"angle"__coeff_83',
#  'glc__fft_coefficient__attr_"angle"__coeff_84',
#  'glc__fft_coefficient__attr_"angle"__coeff_85',
#  'glc__fft_coefficient__attr_"angle"__coeff_86',
#  'glc__fft_coefficient__attr_"angle"__coeff_87',
#  'glc__fft_coefficient__attr_"angle"__coeff_88',
#  'glc__fft_coefficient__attr_"angle"__coeff_89',
#  'glc__fft_coefficient__attr_"angle"__coeff_90',
#  'glc__fft_coefficient__attr_"angle"__coeff_91',
#  'glc__fft_coefficient__attr_"angle"__coeff_92',
#  'glc__fft_coefficient__attr_"angle"__coeff_93',
#  'glc__fft_coefficient__attr_"angle"__coeff_94',
#  'glc__fft_coefficient__attr_"angle"__coeff_95',
#  'glc__fft_coefficient__attr_"angle"__coeff_96',
#  'glc__fft_coefficient__attr_"angle"__coeff_97',
#  'glc__fft_coefficient__attr_"angle"__coeff_98',
#  'glc__fft_coefficient__attr_"angle"__coeff_99',
#  'glc__fft_aggregated__aggtype_"centroid"',
#  'glc__fft_aggregated__aggtype_"variance"',
#  'glc__fft_aggregated__aggtype_"skew"',
#  'glc__fft_aggregated__aggtype_"kurtosis"',
#  'glc__value_count__value_0',
#  'glc__value_count__value_1',
#  'glc__value_count__value_-1',
#  'glc__range_count__max_1__min_-1',
#  'glc__range_count__max_0__min_-1000000000000.0',
#  'glc__range_count__max_1000000000000.0__min_0',
#  'glc__approximate_entropy__m_2__r_0.1',
#  'glc__approximate_entropy__m_2__r_0.3',
#  'glc__approximate_entropy__m_2__r_0.5',
#  'glc__approximate_entropy__m_2__r_0.7',
#  'glc__approximate_entropy__m_2__r_0.9',
#  'glc__friedrich_coefficients__coeff_0__m_3__r_30',
#  'glc__friedrich_coefficients__coeff_1__m_3__r_30',
#  'glc__friedrich_coefficients__coeff_2__m_3__r_30',
#  'glc__friedrich_coefficients__coeff_3__m_3__r_30',
#  'glc__max_langevin_fixed_point__m_3__r_30',
#  'glc__linear_trend__attr_"pvalue"',
#  'glc__linear_trend__attr_"rvalue"',
#  'glc__linear_trend__attr_"intercept"',
#  'glc__linear_trend__attr_"slope"',
#  'glc__linear_trend__attr_"stderr"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"var"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"max"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"min"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"mean"',
#  'glc__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"var"',
#  'glc__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"',
#  'glc__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"',
#  'glc__augmented_dickey_fuller__attr_"usedlag"__autolag_"AIC"',
#  'glc__number_crossing_m__m_0',
#  'glc__number_crossing_m__m_-1',
#  'glc__number_crossing_m__m_1',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_1',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_2',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_4',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_5',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_6',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_8',
#  'glc__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#  'glc__ratio_beyond_r_sigma__r_0.5',
#  'glc__ratio_beyond_r_sigma__r_1',
#  'glc__ratio_beyond_r_sigma__r_1.5',
#  'glc__ratio_beyond_r_sigma__r_2',
#  'glc__ratio_beyond_r_sigma__r_2.5',
#  'glc__ratio_beyond_r_sigma__r_3',
#  'glc__ratio_beyond_r_sigma__r_5',
#  'glc__ratio_beyond_r_sigma__r_6',
#  'glc__ratio_beyond_r_sigma__r_7',
#  'glc__ratio_beyond_r_sigma__r_10',
#  'glc__count_above__t_0',
#  'glc__count_below__t_0',
#  'glc__lempel_ziv_complexity__bins_2',
#  'glc__lempel_ziv_complexity__bins_3',
#  'glc__lempel_ziv_complexity__bins_5',
#  'glc__lempel_ziv_complexity__bins_10',
#  'glc__lempel_ziv_complexity__bins_100',
#  'glc__fourier_entropy__bins_2',
#  'glc__fourier_entropy__bins_3',
#  'glc__fourier_entropy__bins_5',
#  'glc__fourier_entropy__bins_10',
#  'glc__fourier_entropy__bins_100',
#  'glc__permutation_entropy__dimension_3__tau_1',
#  'glc__permutation_entropy__dimension_4__tau_1',
#  'glc__permutation_entropy__dimension_5__tau_1',
#  'glc__permutation_entropy__dimension_6__tau_1',
#  'glc__permutation_entropy__dimension_7__tau_1',
#  'glc__query_similarity_count__query_None__threshold_0.0',
#  'glc__matrix_profile__feature_"min"__threshold_0.98',
#  'glc__matrix_profile__feature_"max"__threshold_0.98',
#  'glc__matrix_profile__feature_"mean"__threshold_0.98',
#  'glc__matrix_profile__feature_"median"__threshold_0.98',
#  'glc__matrix_profile__feature_"25"__threshold_0.98',
#  'glc__matrix_profile__feature_"75"__threshold_0.98',
#  'glc__mean_n_absolute_max__number_of_maxima_7']

# %% [markdown]
# ## 6.1. Prepare target variables

# %% [markdown]
# # Target variable for 5mmol/L
# df['y'] = df['tir_below_5']>0
#
# # Target variable for 3.9mmol/L
# df['y_3'] = df['tir_below_3']>0

# %%
# Create column for stratifying based on ID and target (3.9)
df['stratify'] = df['ID']+ '_'+ df['y'].astype(str)

# %% [markdown]
# ## 6.2. Cutting data

# %%
# Drop any instances without start glucose and duration
df = df.dropna(subset=['start_glc', 'duration']).reset_index()

# %%
df.shape
# Out:
# (18180, 855)

# %%
# Drop columns with < 60% data sufficiency
df = df.loc[df['data_suff_during']>=60]

# %%
# Drop columns with < 60% data sufficiency
df = df.loc[df['before_data_suff']>=40]

# %%
df.shape
# Out:
# (17657, 855)

# %%
# Drop columns with less than 80% data available
df_dropped = df.loc[:, df.isnull().mean() < .2]

# %%
df.shape
# Out:
# (17657, 855)

# %%
df.shape
# Out:
# (17657, 855)

# %% [markdown]
# ## 6.3. Data adjustments

# %%
# Create 'season' variable
df['season'] = (df.month%12 // 3 + 1).astype(str)

# %%
# Make datetime cols numeric
cols = ['Avg. length of hypoglycemic events', 
        'Total time spent in hypoglycemic events',
         'Avg. length of hyperglycemic events',
         'Total time spent in hyperglycemic events', ]

for col in cols:
    df_dropped[col] = df_dropped[col].apply(lambda x: preprocess_helper.make_numeric(x)).astype(float)

# %% [markdown]
# ## Get rid of weird bouts

# %%
# Convert form_of_exercise
df_dropped['form_of_exercise'] = df_dropped.type_of_exercise.apply(lambda x: 
                                                       preprocess_helper.divide_exercise_into_type(x))
# Out:
# hit
# hit
# hit
# step class
# step class
# hit
# hit
# hit
# hit
# boot camp
# painting
# 2.6
# circuits
# circuits
# moving fence panels
# nk (teaching?)
# sheep weighing
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# strawberry picking
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# holiday decorating indoor and out
# snow shoveling
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# loading a moving truck
# outdoor chores
# shovelling snow
# outdoor chores
# work
# work
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# power plate-works
# mat science 1.
# mow lawn
# mow lawn
# outdoor chores
# mow lawn
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# shoveling
# shoveling
# other outside
# other outside
# other outside
# outdoor
# outdoor chores
# snow shoveling
# shovel snow
# shovel snow
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# weeding
# cutting the grass
# cutting the grass
# cutting the grass
# cutting the grass
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# moving
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# raking leaves
# raking leaves
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# yard work
# vacuming and mopping floors
# vacuming and mopping floors
# vacuming and mopping floors
# vacuming and mopping floors
# outdoor chores
# outdoor chores
# outdoor chores
# work
# work
# outdoor chores
# outdoor chores
# outdoor chores
# mowing lawn
# mowing lawn
# mowing lawn
# chasing children at a playground
# chasing children at a playground
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# sanding and painting
# sanding and painting
# sanding and painting
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# painting
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# helped someone move
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# shoveling snow
# outdoor chores
# outdoor chores
# physical work for job
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# string trimmer and mowing lawn
# wash car
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# moving furniture
# outdoor chores
# shoveling
# shoveling
# shoveling
# shoveling
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# active play with kids at work
# active play with kids at work
# active play with kids at work
# active play with kids at work
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# shoveling
# shoveling
# outdoor chores
# packing and loading for travel
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# mowing grass
# outdoor chores
# outdoor chores
# outdoor chores
# violin performing
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# painting
# painting
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# yard work, raking leaves
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# sledding
# other (indoor)
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# snow shoveling
# snow shoveling
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cut grass
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# scrubbing outdoor dock & deck
# scrubbing outdoor dock & deck
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# furniture moving
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# work/lifting - pts around 150lbs-300lbs
# work/lifting - pts around 150lbs-300lbs
# work/lifting - pts around 150lbs-300lbs
# building furniture
# mowing grasss
# moving furniture & building a wallbed
# oculus
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores

# %%
df_dropped = df_dropped.dropna(subset=['form_of_exercise'])

# %%
df_dropped.shape
# Out:
# (16490, 414)

# %%
df_dropped=df_dropped.drop_duplicates(['bout_id', 'start_datetime'])

# %%
df_dropped.shape
# Out:
# (16477, 414)

# %% [markdown]
# ## 6.4. Adjust and tidy data

# %%
# Save df for demographics table
df_dropped.to_csv('../../data/tidy_data/demographics_df.csv', index=False)

# %%
# Save id, bout id etc as a key
df_dropped[['ID', 'bout_id', 'start_datetime','finish_datetime']].to_csv('../1_preprocessing/id_key_dexip.csv', index=False)

# %%
# Reset index after dropping
df_dropped.reset_index(inplace=True, drop=True)

# %%
# Drop columns that arent needed
cols_to_drop = ['start_datetime', 'finish_datetime', 'type_of_exercise',
               'data_suff_during', # 'interval', 'tir_below_5', 'tir_below_3',
             'month', 'day',  'ID',  'index']

df = df_dropped.drop(columns=cols_to_drop)

# %%
# Repace infs in tsfresh with nan
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Create X 
X = df.drop(columns=['study','interval', 'stratify', 'bout_id', 'y'])

# Get dummies
X = pd.get_dummies(X)

# Fill missing data
imputer = KNNImputer(n_neighbors=5, missing_values=np.nan)
X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns)

# Round intensity back to ordinal after imputing
X.intensity = X.intensity.round()

# Set y as 3.9mmol/L
y = df['y']

# %%
# Save everything
df.to_csv('../../data/tidy_data/final_df/df.csv', index=False)
df['stratify'].to_csv('../../data/tidy_data/final_df/strat.csv', index=False)
X.to_csv('../../data/tidy_data/final_df/X.csv', index=False)
y.to_csv('../../data/tidy_data/final_df/y.csv', index=False)
