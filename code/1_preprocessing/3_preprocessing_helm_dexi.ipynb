# %% [markdown]
# # 3. Preprocessing JAEB T1-DEXI dataset

# %% [markdown]
# The goal of this notebook is to prepare the EXTOD education data for machine learning - predicting euglycemia during and around exercise.
#
# EXTOD education was a pilot study in which 106 participants were randomly allocated to either standard care or an education programme teaching them how better to manage blood glucose around exercise.
#
# The data used will be demographic, lab, clinical and physiological if available.
#
# ### Objectives:
# 1. Clean and combine the exercise diaries
# 2. Preprocess demographic data
# 3. Preprcoess lab data
# 4. Prepare CGM data

# %% [markdown]
# ## 3.0. Import packages

# %%
# Import packages and upload dataset
import pandas as pd
from datetime import timedelta as time
import warnings
import preprocess_helper
import functools as ft

warnings.filterwarnings('ignore')

# %%
# Set the directory
directory = '../../data/raw_data/helmsley/'

# %% [markdown]
# ## 3.1. Clean and combine exercise diaries

# %% [markdown]
# ### 3.1.1. Load files and rename columns

# %%
# Read file
exercise = pd.read_csv(directory+'pr_dexi.csv')

# %%
# Convert the start time to datetime
exercise['PRSTDTC'] = pd.to_datetime(exercise['PRSTDTC'])

# %%
exercise
# Out:
#       STUDYID DOMAIN  USUBJID         PRSEQ                       PRTRT  \
# 0      T1DEXI     PR      1.0  1.000000e+00  Biking (Indoor or Outdoor)
# 1      T1DEXI     PR      1.0  2.000000e+00  Biking (Indoor or Outdoor)
# 2      T1DEXI     PR      1.0  3.000000e+00  Biking (Indoor or Outdoor)
# 3      T1DEXI     PR      1.0  4.000000e+00  Biking (Indoor or Outdoor)
# 4      T1DEXI     PR      1.0  5.000000e+00  Biking (Indoor or Outdoor)
# ...       ...    ...      ...           ...                         ...
# 15195     NaN    NaN      NaN  3.687825e-40                         NaN
# 15196     NaN    NaN      NaN  3.687825e-40                         NaN
# 15197     NaN    NaN      NaN  3.687825e-40                         NaN
# 15198     NaN    NaN      NaN  3.687825e-40                         NaN
# 15199     NaN    NaN      NaN  3.687825e-40                         NaN
#
#                             PRCAT                      PRSCAT  \
# 0      Biking (Indoor or Outdoor)  Biking (Indoor or Outdoor)
# 1      Biking (Indoor or Outdoor)  Biking (Indoor or Outdoor)
# 2      Biking (Indoor or Outdoor)  Biking (Indoor or Outdoor)
# 3      Biking (Indoor or Outdoor)  Biking (Indoor or Outdoor)
# 4      Biking (Indoor or Outdoor)  Biking (Indoor or Outdoor)
# ...                           ...                         ...
# 15195        Walking, Dog Walking        Walking, Dog Walking
# 15196        Walking, Dog Walking        Walking, Dog Walking
# 15197        Walking, Dog Walking        Walking, Dog Walking
# 15198        Walking, Dog Walking        Walking, Dog Walking
# 15199        Walking, Dog Walking        Walking, Dog Walking
#
#                   PRSTDTC                      PRTRTC  PLNEXDUR  EXCINTSY  \
# 0     2020-05-16 10:03:30  Biking (Indoor or Outdoor)       180         1
# 1     2020-05-18 10:30:37  Biking (Indoor or Outdoor)        88         1
# 2     2020-05-30 09:46:11  Biking (Indoor or Outdoor)       228         1
# 3     2020-06-01 13:13:19  Biking (Indoor or Outdoor)        87         1
# 4     2020-06-03 10:19:19  Biking (Indoor or Outdoor)       135         1
# ...                   ...                         ...       ...       ...
# 15195 2021-04-07 12:29:33        Walking, Dog Walking        25         1
# 15196 2021-04-07 12:29:33        Walking, Dog Walking        25         1
# 15197 2021-04-07 12:29:33        Walking, Dog Walking        25         1
# 15198 2021-04-07 12:29:33        Walking, Dog Walking        25         1
# 15199 2021-04-07 12:29:33        Walking, Dog Walking        25         1
#
#        HRSLSTML  EXCOMP  SNKBEFEX  INUSDTDY  BETAGTDY  RESQCARB
# 0       2 hours       0         1         0         0         0
# 1      >4 hours       0         1         0         0         0
# 2       <1 hour       0         1         0         0         0
# 3       <1 hour       0         1         0         0         0
# 4       <1 hour       0         1         0         0         1
# ...         ...     ...       ...       ...       ...       ...
# 15195   <1 hour       0         0         0         0         0
# 15196   <1 hour       0         0         0         0         0
# 15197   <1 hour       0         0         0         0         0
# 15198   <1 hour       0         0         0         0         0
# 15199   <1 hour       0         0         0         0         0
#
# [15200 rows x 17 columns]

# %%
# Select and rename columns
exdi = exercise[['USUBJID', 'PRSTDTC', 'PLNEXDUR', 'EXCINTSY', 'PRTRTC']] 
exdi.columns = ['ID', 'start_datetime', 'duration', 'intensity', 'type_of_exercise']

# %%
exdi.dropna(subset=['ID'], inplace=True)

# %%
# ID as int for concatenation
exdi['ID'] = exdi['ID'].astype(int)

# %%
exdi.shape
# Out:
# (15104, 5)

# %%
len(exdi.ID.unique())
# Out:
# 502

# %% [markdown]
# ### 3.1.2. Adjust date columns

# %%
# Calculate end time from start and duration 
exdi['finish_datetime'] = exdi.apply(lambda row: row['start_datetime'] + time(minutes=row['duration']), axis=1)

# %%
# Collect date information from start_datetime
exdi = preprocess_helper.date_preprocessing(exdi, 'start_datetime', False, True, True)

# %%
# Drop any instances with no id, start time or duration
exdi = exdi.dropna(subset=['ID', 'start_datetime', 'duration'])

# %%
# Make sure there's no minus durations
exdi = exdi.loc[exdi['duration']>0]

# %%
exdi.shape[0]
# Out:
# 15098

# %%
def handle_overlaps(group):
    # Sort by start_datetime
    group = group.sort_values(by='start_datetime')
    
    non_overlapping = []
    overlap_count = 0  # Counter to limit the number of printed overlaps
    for _, row in group.iterrows():
        if non_overlapping:
            last_interval = non_overlapping[-1]
            # Check for overlap
            if row['start_datetime'] < last_interval['finish_datetime']:
                # Print the overlapping intervals (limited to a few for brevity)
                if overlap_count < 5:
                    print(f"Overlap detected for ID {group['ID'].iloc[0]}:")
                    print(f"Interval 1: {last_interval['start_datetime']} to {last_interval['finish_datetime']}")
                    print(f"Interval 2: {row['start_datetime']} to {row['finish_datetime']}\n")
                    overlap_count += 1

                curr_duration = (row['finish_datetime'] - row['start_datetime']).seconds / 60
                last_duration = (last_interval['finish_datetime'] - last_interval['start_datetime']).seconds / 60
                
                # Decide which interval to keep
                if (curr_duration >= 10 and curr_duration <= 120) and (last_duration < 10 or last_duration > 120):
                    non_overlapping[-1] = row
                elif (last_duration >= 10 and last_duration <= 120) and (curr_duration < 10 or curr_duration > 120):
                    continue
                elif curr_duration > last_duration:
                    non_overlapping[-1] = row
            else:
                non_overlapping.append(row)
        else:
            non_overlapping.append(row)
    
    return pd.DataFrame(non_overlapping)

# Apply the function to each group
exdi = exdi.groupby('ID').apply(handle_overlaps).reset_index(drop=True)
# Out:
# Overlap detected for ID 67:
# Interval 1: 2020-07-08 09:40:30 to 2020-07-08 11:00:30
# Interval 2: 2020-07-08 11:00:24 to 2020-07-08 12:03:24
#
# Overlap detected for ID 67:
# Interval 1: 2020-07-20 08:30:46 to 2020-07-20 09:00:46
# Interval 2: 2020-07-20 09:00:33 to 2020-07-20 09:30:33
#
# Overlap detected for ID 80:
# Interval 1: 2019-12-29 18:59:30 to 2019-12-29 19:13:30
# Interval 2: 2019-12-29 19:13:29 to 2019-12-29 19:18:29
#
# Overlap detected for ID 290:
# Interval 1: 2020-02-18 18:52:12 to 2020-02-18 19:17:12
# Interval 2: 2020-02-18 19:16:59 to 2020-02-18 19:46:59
#
# Overlap detected for ID 317:
# Interval 1: 2019-03-24 07:33:30 to 2019-03-24 08:03:30
# Interval 2: 2019-03-24 07:57:45 to 2019-03-24 07:59:45
#
# Overlap detected for ID 393:
# Interval 1: 2020-03-01 19:47:16 to 2020-03-01 20:07:16
# Interval 2: 2020-03-01 20:05:28 to 2020-03-01 20:55:28
#
# Overlap detected for ID 393:
# Interval 1: 2020-03-18 19:45:38 to 2020-03-18 20:15:38
# Interval 2: 2020-03-18 20:15:12 to 2020-03-18 20:40:12
#
# Overlap detected for ID 398:
# Interval 1: 2019-09-26 16:40:04 to 2019-09-26 17:00:04
# Interval 2: 2019-09-26 17:00:00 to 2019-09-26 17:25:00
#
# Overlap detected for ID 398:
# Interval 1: 2019-10-09 06:30:32 to 2019-10-09 06:50:32
# Interval 2: 2019-10-09 06:50:01 to 2019-10-09 07:00:01
#
# Overlap detected for ID 398:
# Interval 1: 2019-10-10 06:30:51 to 2019-10-10 06:45:51
# Interval 2: 2019-10-10 06:45:09 to 2019-10-10 07:20:09
#
# Overlap detected for ID 419:
# Interval 1: 2020-03-02 12:41:59 to 2020-03-02 13:11:59
# Interval 2: 2020-03-02 13:10:49 to 2020-03-02 13:30:49
#
# Overlap detected for ID 422:
# Interval 1: 2019-11-28 17:27:45 to 2019-11-28 17:47:45
# Interval 2: 2019-11-28 17:45:15 to 2019-11-28 18:25:15
#
# Overlap detected for ID 446:
# Interval 1: 2019-10-04 15:28:37 to 2019-10-04 17:28:37
# Interval 2: 2019-10-04 17:14:55 to 2019-10-04 17:44:55
#
# Overlap detected for ID 468:
# Interval 1: 2020-08-01 10:34:02 to 2020-08-01 10:59:02
# Interval 2: 2020-08-01 10:55:19 to 2020-08-01 11:10:19
#
# Overlap detected for ID 469:
# Interval 1: 2020-03-16 15:56:29 to 2020-03-16 16:22:29
# Interval 2: 2020-03-16 16:20:51 to 2020-03-16 16:45:51
#
# Overlap detected for ID 469:
# Interval 1: 2020-03-19 15:17:17 to 2020-03-19 15:52:17
# Interval 2: 2020-03-19 15:50:53 to 2020-03-19 16:20:53
#
# Overlap detected for ID 469:
# Interval 1: 2020-03-23 16:32:32 to 2020-03-23 17:00:32
# Interval 2: 2020-03-23 16:57:50 to 2020-03-23 17:22:50
#
# Overlap detected for ID 486:
# Interval 1: 2020-04-10 07:10:46 to 2020-04-10 07:20:46
# Interval 2: 2020-04-10 07:15:27 to 2020-04-10 07:35:27
#
# Overlap detected for ID 486:
# Interval 1: 2020-04-12 07:40:59 to 2020-04-12 08:00:59
# Interval 2: 2020-04-12 08:00:00 to 2020-04-12 08:15:00
#
# Overlap detected for ID 486:
# Interval 1: 2020-04-16 07:32:25 to 2020-04-16 08:22:25
# Interval 2: 2020-04-16 08:17:01 to 2020-04-16 08:37:01
#
# Overlap detected for ID 499:
# Interval 1: 2020-02-17 15:35:58 to 2020-02-17 16:05:58
# Interval 2: 2020-02-17 16:05:00 to 2020-02-17 16:25:00
#
# Overlap detected for ID 549:
# Interval 1: 2019-06-03 09:07:28 to 2019-06-03 09:30:28
# Interval 2: 2019-06-03 09:28:58 to 2019-06-03 10:28:58
#
# Overlap detected for ID 603:
# Interval 1: 2020-06-07 17:40:00 to 2020-06-07 18:01:00
# Interval 2: 2020-06-07 18:00:00 to 2020-06-07 18:25:00
#
# Overlap detected for ID 614:
# Interval 1: 2020-02-27 13:30:39 to 2020-02-27 14:00:39
# Interval 2: 2020-02-27 13:57:00 to 2020-02-27 14:27:00
#
# Overlap detected for ID 646:
# Interval 1: 2019-07-27 19:03:15 to 2019-07-27 19:13:15
# Interval 2: 2019-07-27 19:12:32 to 2019-07-27 19:32:32
#
# Overlap detected for ID 646:
# Interval 1: 2019-07-28 15:18:39 to 2019-07-28 15:26:39
# Interval 2: 2019-07-28 15:25:51 to 2019-07-28 15:55:51
#
# Overlap detected for ID 729:
# Interval 1: 2019-09-11 10:10:51 to 2019-09-11 10:35:51
# Interval 2: 2019-09-11 10:35:21 to 2019-09-11 10:50:21
#
# Overlap detected for ID 729:
# Interval 1: 2019-09-13 07:15:40 to 2019-09-13 07:30:40
# Interval 2: 2019-09-13 07:30:15 to 2019-09-13 07:55:15
#
# Overlap detected for ID 766:
# Interval 1: 2020-11-03 10:22:36 to 2020-11-03 10:37:36
# Interval 2: 2020-11-03 10:30:40 to 2020-11-03 10:45:40
#
# Overlap detected for ID 769:
# Interval 1: 2020-09-26 17:30:52 to 2020-09-26 17:55:52
# Interval 2: 2020-09-26 17:55:34 to 2020-09-26 18:10:34
#
# Overlap detected for ID 771:
# Interval 1: 2020-10-06 06:05:25 to 2020-10-06 06:30:25
# Interval 2: 2020-10-06 06:27:15 to 2020-10-06 06:32:15
#
# Overlap detected for ID 812:
# Interval 1: 2021-02-25 19:20:10 to 2021-02-25 19:47:10
# Interval 2: 2021-02-25 19:46:04 to 2021-02-25 20:42:04
#
# Overlap detected for ID 834:
# Interval 1: 2020-06-24 06:49:06 to 2020-06-24 07:22:06
# Interval 2: 2020-06-24 07:22:03 to 2020-06-24 07:38:03
#
# Overlap detected for ID 834:
# Interval 1: 2020-07-08 18:28:00 to 2020-07-08 18:55:00
# Interval 2: 2020-07-08 18:54:00 to 2020-07-08 19:11:00
#
# Overlap detected for ID 900:
# Interval 1: 2019-12-14 11:50:58 to 2019-12-14 12:15:58
# Interval 2: 2019-12-14 12:15:33 to 2019-12-14 12:35:33
#
# Overlap detected for ID 900:
# Interval 1: 2019-12-25 14:00:11 to 2019-12-25 16:00:11
# Interval 2: 2019-12-25 16:00:06 to 2019-12-25 17:00:06
#
# Overlap detected for ID 956:
# Interval 1: 2020-03-18 10:15:34 to 2020-03-18 10:30:34
# Interval 2: 2020-03-18 10:30:09 to 2020-03-18 12:00:09
#
# Overlap detected for ID 1020:
# Interval 1: 2019-09-10 06:15:42 to 2019-09-10 06:40:42
# Interval 2: 2019-09-10 06:40:00 to 2019-09-10 07:05:00
#
# Overlap detected for ID 1033:
# Interval 1: 2019-04-09 17:39:57 to 2019-04-09 17:55:57
# Interval 2: 2019-04-09 17:55:11 to 2019-04-09 18:27:11
#
# Overlap detected for ID 1033:
# Interval 1: 2019-04-13 18:26:40 to 2019-04-13 18:34:40
# Interval 2: 2019-04-13 18:34:39 to 2019-04-13 19:07:39
#
# Overlap detected for ID 1072:
# Interval 1: 2021-02-01 05:55:00 to 2021-02-01 09:31:00
# Interval 2: 2021-02-01 09:24:00 to 2021-02-01 12:09:00
#
# Overlap detected for ID 1100:
# Interval 1: 2020-02-14 10:05:26 to 2020-02-14 10:25:26
# Interval 2: 2020-02-14 10:25:23 to 2020-02-14 10:40:23
#
# Overlap detected for ID 1100:
# Interval 1: 2020-02-16 18:06:48 to 2020-02-16 18:36:48
# Interval 2: 2020-02-16 18:36:39 to 2020-02-16 18:49:39
#
# Overlap detected for ID 1100:
# Interval 1: 2020-03-05 11:32:58 to 2020-03-05 11:48:58
# Interval 2: 2020-03-05 11:47:28 to 2020-03-05 11:58:28
#
# Overlap detected for ID 1100:
# Interval 1: 2020-03-08 20:30:32 to 2020-03-08 20:42:32
# Interval 2: 2020-03-08 20:42:05 to 2020-03-08 21:43:05
#
# Overlap detected for ID 1100:
# Interval 1: 2020-03-11 17:51:34 to 2020-03-11 18:06:34
# Interval 2: 2020-03-11 18:06:15 to 2020-03-11 18:16:15
#
# Overlap detected for ID 1146:
# Interval 1: 2020-10-06 15:09:28 to 2020-10-06 17:09:28
# Interval 2: 2020-10-06 17:09:07 to 2020-10-06 17:39:07
#
# Overlap detected for ID 1170:
# Interval 1: 2020-11-23 17:55:09 to 2020-11-23 18:25:09
# Interval 2: 2020-11-23 18:25:00 to 2020-11-23 18:50:00
#
# Overlap detected for ID 1193:
# Interval 1: 2020-04-28 18:55:43 to 2020-04-28 19:28:43
# Interval 2: 2020-04-28 19:25:57 to 2020-04-28 19:45:57
#
# Overlap detected for ID 1206:
# Interval 1: 2020-08-21 11:12:07 to 2020-08-21 12:10:07
# Interval 2: 2020-08-21 12:10:00 to 2020-08-21 13:15:00
#
# Overlap detected for ID 1206:
# Interval 1: 2020-09-04 11:07:00 to 2020-09-04 12:07:00
# Interval 2: 2020-09-04 12:05:00 to 2020-09-04 12:57:00
#
# Overlap detected for ID 1221:
# Interval 1: 2020-07-31 14:54:05 to 2020-07-31 15:24:05
# Interval 2: 2020-07-31 15:22:15 to 2020-07-31 15:52:15
#
# Overlap detected for ID 1247:
# Interval 1: 2020-01-18 18:45:51 to 2020-01-18 19:05:51
# Interval 2: 2020-01-18 19:05:37 to 2020-01-18 19:20:37
#
# Overlap detected for ID 1265:
# Interval 1: 2020-05-30 17:35:26 to 2020-05-30 17:45:26
# Interval 2: 2020-05-30 17:45:12 to 2020-05-30 18:15:12
#
# Overlap detected for ID 1297:
# Interval 1: 2020-10-04 09:30:43 to 2020-10-04 10:00:43
# Interval 2: 2020-10-04 10:00:05 to 2020-10-04 10:30:05
#
# Overlap detected for ID 1304:
# Interval 1: 2020-04-19 11:36:14 to 2020-04-19 12:01:14
# Interval 2: 2020-04-19 12:00:16 to 2020-04-19 12:24:16
#
# Overlap detected for ID 1335:
# Interval 1: 2020-10-12 17:47:12 to 2020-10-12 18:00:12
# Interval 2: 2020-10-12 18:00:02 to 2020-10-12 18:11:02
#
# Overlap detected for ID 1396:
# Interval 1: 2020-04-21 16:40:20 to 2020-04-21 17:10:20
# Interval 2: 2020-04-21 17:10:06 to 2020-04-21 17:30:06
#
# Overlap detected for ID 1433:
# Interval 1: 2019-11-16 09:05:46 to 2019-11-16 09:40:46
# Interval 2: 2019-11-16 09:40:11 to 2019-11-16 10:00:11
#
# Overlap detected for ID 1490:
# Interval 1: 2020-06-18 16:16:02 to 2020-06-18 16:21:02
# Interval 2: 2020-06-18 16:20:27 to 2020-06-18 16:25:27
#
# Overlap detected for ID 1503:
# Interval 1: 2020-11-28 16:50:39 to 2020-11-28 17:20:39
# Interval 2: 2020-11-28 17:20:24 to 2020-11-28 17:40:24
#
# Overlap detected for ID 1517:
# Interval 1: 2020-08-21 17:38:35 to 2020-08-21 17:58:35
# Interval 2: 2020-08-21 17:58:25 to 2020-08-21 18:03:25
#
# Overlap detected for ID 1535:
# Interval 1: 2020-03-21 11:03:03 to 2020-03-21 13:03:03
# Interval 2: 2020-03-21 12:49:27 to 2020-03-21 13:34:27
#
# Overlap detected for ID 1536:
# Interval 1: 2020-06-05 09:00:50 to 2020-06-05 10:30:50
# Interval 2: 2020-06-05 10:28:24 to 2020-06-05 10:58:24
#
# Overlap detected for ID 1543:
# Interval 1: 2020-03-23 14:50:42 to 2020-03-23 15:00:42
# Interval 2: 2020-03-23 15:00:28 to 2020-03-23 15:10:28
#
# Overlap detected for ID 1559:
# Interval 1: 2019-09-20 15:50:28 to 2019-09-20 16:35:28
# Interval 2: 2019-09-20 16:30:53 to 2019-09-20 16:50:53
#
# Overlap detected for ID 1586:
# Interval 1: 2020-04-30 16:50:28 to 2020-04-30 17:24:28
# Interval 2: 2020-04-30 17:23:32 to 2020-04-30 17:43:32
#
# Overlap detected for ID 1606:
# Interval 1: 2021-01-13 07:00:53 to 2021-01-13 07:30:53
# Interval 2: 2021-01-13 07:12:38 to 2021-01-13 07:32:38
#
# Overlap detected for ID 1649:
# Interval 1: 2020-10-16 15:36:50 to 2020-10-16 16:06:50
# Interval 2: 2020-10-16 16:06:13 to 2020-10-16 16:36:13
#
# Overlap detected for ID 1666:
# Interval 1: 2021-04-23 15:36:53 to 2021-04-23 17:06:53
# Interval 2: 2021-04-23 17:06:35 to 2021-04-23 18:06:35
#
# Overlap detected for ID 1668:
# Interval 1: 2020-03-07 11:12:44 to 2020-03-07 16:12:44
# Interval 2: 2020-03-07 16:05:37 to 2020-03-07 17:05:37
#
# Overlap detected for ID 1689:
# Interval 1: 2020-09-16 09:09:11 to 2020-09-16 09:12:11
# Interval 2: 2020-09-16 09:12:00 to 2020-09-16 10:12:00
#
# Overlap detected for ID 1717:
# Interval 1: 2020-10-20 14:00:51 to 2020-10-20 14:30:51
# Interval 2: 2020-10-20 14:30:12 to 2020-10-20 15:00:12
#
# Overlap detected for ID 1722:
# Interval 1: 2020-09-28 14:40:30 to 2020-09-28 15:10:30
# Interval 2: 2020-09-28 15:10:09 to 2020-09-28 15:30:09

# %%
exdi.shape[0]
# Out:
# 15024

# %% [markdown]
# ### 3.1.3. Type of exercise

# %%
# Convert form_of_exercise
exdi['form_of_exercise'] = exdi.type_of_exercise.apply(lambda x: 
                                                       preprocess_helper.divide_exercise_into_type(x))
# Out:
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# packing and loading for travel
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# shoveling snow
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# building furniture
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# loading moving truck
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# painting
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# helped someone move
# helped someone move
# outdoor chores
# outdoor chores
# cleaning/housework
# shoveling snow
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# gardening
# gardening
# cleaning/housework
# tubing
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# gardening
# gardening
# shoveling snow
# cleaning/housework
# yard work
# yard work
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# physical work for job
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# string trimmer and mowing lawn
# wash car
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# moving furniture
# waiting tables
# outdoor chores
# waiting tables
# waiting tables
# waiting tables
# shoveling
# shoveling
# shoveling
# shoveling
# shoveling
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# gardening
# gardening
# gardening
# gardening
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# active play with kids at work
# active play with kids at work
# active play with kids at work
# active play with kids at work
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# grocery shopping
# grocery shopping
# grocery shopping
# grocery shopping
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# shoveling
# shoveling
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# mowing grass
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# violin performing
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# painting
# painting
# cleaning/housework
# gardening
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# mowing lawn
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# yard work, raking leaves
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# sledding
# other (indoor)
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# snow shoveling
# cleaning/housework
# cleaning/housework
# snow shoveling
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cut grass
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# shopping at meijer & costco
# shopping at kroger
# cleaning/housework
# scrubbing outdoor dock & deck
# scrubbing outdoor dock & deck
# scrubbing outdoor dock & deck
# cleaning/housework
# shopping at kroger
# scrubbing outdoor dock & deck
# shopping at kroger
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# furniture moving
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# shopping
# outdoor chores
# work/lifting - pts around 150lbs-300lbs
# cleaning/housework
# work/lifting - pts around 150lbs-300lbs
# work/lifting - pts around 150lbs-300lbs
# gardening
# gardening
# outdoor chores
# outdoor chores
# outdoor chores
# mowing grasss
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# moving furniture & building a wallbed
# moving furniture & building a wallbed
# oculus
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# grocery shopping
# grocery shopping
# outdoor chores
# outdoor chores
# grocery shopping
# outdoor chores
# outdoor chores
# grocery shopping
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# curling ice shed clean out
# outdoor chores
# outdoor chores
# outdoor chores
# strawberry picking
# outdoor chores
# shopping
# cleaning/housework
# shopping
# cleaning/housework
# outdoor chores
# outdoor chores
# fly fishing, wading
# fly fishing, wading
# fly fishing, wading
# outdoor chores
# outdoor chores
# shopping
# shopping
# shopping
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# holiday decorating indoor and out
# snow shoveling
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# loading a moving truck
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# shovelling snow
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# work
# work
# work
# work
# work
# work
# work
# work
# work
# work
# work
# work
# work
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# power plate-works
# mat science 1.
# moving (apartments)
# cleaning/housework
# mow lawn
# mow lawn
# outdoor chores
# cleaning/housework
# mow lawn
# cleaning/housework
# cleaning/housework
# gardening
# gardening
# cleaning/housework
# gardening
# gardening
# gardening
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# shoveling
# shoveling
# other outside
# other outside
# other outside
# cleaning/housework
# outdoor
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# snow shoveling
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# shovel snow
# shovel snow
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# weeding
# cpr
# cleaning/housework
# cutting the grass
# cleaning/housework
# cutting the grass
# cutting the grass
# cleaning/housework
# cutting the grass
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# moving
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# ma task cleaning/transporting pt
# ma task cleaning/transporting pt
# ma task cleaning/transporting pt
# ma task cleaning/transporting pt
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# raking leaves
# raking leaves
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# yard work
# vacuming and mopping floors
# vacuming and mopping floors
# vacuming and mopping floors
# cleaning/housework
# vacuming and mopping floors
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# work
# work
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# warehouse work (job)
# mowing lawn
# mowing lawn
# mowing lawn
# cleaning/housework
# yard work
# chasing children at a playground
# chasing children at a playground
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# cleaning/housework
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# gardening
# outdoor chores
# outdoor chores
# outdoor chores
# cleaning/housework
# outdoor chores
# cleaning/housework
# outdoor chores
# sanding and painting
# cleaning/housework
# cleaning/housework
# cleaning/housework
# sanding and painting
# sanding and painting
# sanding and painting
# cleaning/housework
# gardening
# cleaning/housework
# cleaning/housework
# cleaning/housework
# outdoor chores
# gardening
# gardening
# outdoor chores

# %%
# Removing bouts that aren't really exercise
#exdi.dropna(subset=['form_of_exercise'], inplace=True)

# %%
exdi.shape
# Out:
# (15024, 11)

# %% [markdown]
# ## 3.2. Clean and combine CGM files

# %%
# Upload directory for CGM data
lb = pd.read_csv(directory+'lb_dexi.csv')

# Select CGM readings
cgm = lb.loc[lb['LBCAT']=='CGM']

# Convert timestamp to datetime
cgm['LBDTC'] = pd.to_datetime(cgm['LBDTC'])

# Select and rename columns 
cgm = cgm[['USUBJID', 'LBDTC', 'LBORRES']]
cgm.columns = ['ID', 'time', 'glc']

# Drop any null 
cgm.dropna(inplace=True)

# Convert glucose to mg/dl
cgm['glc'] = (cgm['glc']/18).round(2)

# ID to int for concatenation
cgm['ID'] = cgm['ID'].astype(int)

# %% [markdown]
# ## 3.3. Lab & demographic data

# %%
# Read file
demographics = pd.read_csv(directory+'dm_dexi.csv')

# Select and rename columns
demo = demographics[['USUBJID', 'AGE', 'SEX', 'RACE']]
demo.columns = ['ID', 'age', 'sex', 'race']

# Replace m/f values
demo['sex'] = demo['sex'].replace({'M':'male', 'F':'female'})

# ID as int for concatenation
demo['ID'] = demo['ID'].astype(int)

# %% [markdown]
# ### 3.3.1. Calculate hba1c

# %%
# Select the hba1c results from the tests file
hba1c = lb.loc[lb['LBTESTCD']=='HBA1C']

# Make id int for concatenation
hba1c['USUBJID'] = hba1c['USUBJID'].astype(int)


# Select and rename columns
hba1c = hba1c[['USUBJID', 'LBORRES']]
hba1c.columns = ['ID', 'hba1c']

# Convert to mmol/mol
hba1c['hba1c'] =(hba1c['hba1c'] -2.15)*10.929

# %% [markdown]
# ### 3.3.2. Calculate diabetes onset

# %%
# Set up list for results
fa_data = []

# Read file
fa = pd.read_sas(directory+'FA.xpt', encoding='utf-8',chunksize=10000, iterator=True)

# %%
# Read the file in chunks because it's so massive
for chunk in fa:
    chunk = chunk.loc[chunk['FAOBJ']== "DIABETES ONSET"]
    if chunk.shape[0]==0:
        continue
    fa_data.append(chunk[['USUBJID', 'FASTRESN']])

# %%
# Concat all the chunks
fa_data=pd.concat(fa_data)

# Rename coluns
fa_data.columns = ['ID', 'years_since_diagnosis']

# Make id int for concatenation
fa_data['ID'] = fa_data['ID'].astype(int)

# %% [markdown]
# ### 3.3.3. Calculate BMI

# %%
# Set up list for results
vs_data=[]

# Read file
vs = pd.read_sas(directory+'VS.xpt', encoding='utf-8',chunksize=10000, iterator=True)

# %%
# Read the file in chunks because it's so massive
for chunk in vs:
    chunk = chunk.loc[(chunk['VSTESTCD']== 'HEIGHT') | (chunk['VSTESTCD']=='WEIGHT')]
    if chunk.shape[0]==0:
        continue
    vs_data.append(chunk[['USUBJID', 'VSTESTCD', 'VSORRES']])

# %%
# Concat all the chunks
vs_data= pd.concat(vs_data)

# Make it the right way round
vs_data_adj = vs_data.pivot(columns='VSTESTCD', index='USUBJID')

vs_data_adj.columns = ['h', 'w']

#Calculate bmi
vs_data_adj['bmi'] = (703*vs_data_adj['w'])/(vs_data_adj['h']*vs_data_adj['h'])

# Reset index
vs_data_adj = vs_data_adj.reset_index()

# Select only id and bmi and rename
bmi = vs_data_adj[['USUBJID', 'bmi']]
bmi.columns = ['ID', 'bmi']

# Make id int for concatenatin
bmi['ID'] = bmi['ID'].astype(int)

# %% [markdown]
# ## 3.4. Insulin modality

# %%
# Read file
dx = pd.read_sas(directory+'DX.xpt', encoding='utf-8')

# %%
# Rename values
insulin_modality = dx[dx['DXCAT']=='INSULIN MODALITY'][['USUBJID', 'DXTRT']].replace({'MULTIPLE DAILY INJECTIONS': 'mdi', 
                                                                                      'INSULIN PUMP':'pump', 
                                                                                      'CLOSED LOOP INSULIN PUMP':'closed_loop'})

# %%
# Rename columns
insulin_modality.columns = ['ID', 'insulin_modality']

# Convert ID to int for concatenation
insulin_modality['ID'] = insulin_modality['ID'].astype(int)

# %% [markdown]
# ## 3.5. Combine all dfs

# %%
# List of all dfs
dfs = [demo, hba1c, bmi, fa_data, insulin_modality]

# Merge them all
demo_lab = ft.reduce(lambda left, right: pd.merge(left, right, on='ID', how='outer'), dfs)

# %%
# Add 'helm' to IDs to make them unique
for i in [exdi, cgm, demo_lab]:
    i['ID'] = i['ID'].apply(lambda row: 'helm_'+str(row))

# %% [markdown]
# ## 3.6. Save files

# %%
df_directory = '../../data/tidy_data/helmsley/'
exdi.to_csv(df_directory+'exercise.csv', index=False)
cgm.to_csv(df_directory+'cgm.csv', index=False)
demo_lab.to_csv(df_directory+'demo_lab.csv', index=False)
